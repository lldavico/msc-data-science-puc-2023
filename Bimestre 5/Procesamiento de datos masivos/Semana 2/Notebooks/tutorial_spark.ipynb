# %%
sc
# Out:
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="/?o=6288621065484677#setting/sparkui/0123-155106-fd9ezxaq/driver-4098225302316574884">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.3.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[8]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Databricks Shell</code></dd>
#             </dl>
#         </div>

# %%
text_file = sc.textFile("/FileStore/tables/demo_file_spark.txt")

# %%
text_file
# Out:
# Out[22]: /FileStore/tables/demo_file_spark.txt MapPartitionsRDD[186] at textFile at NativeMethodAccessorImpl.java:0

# %%
text_file.collect()
# Out:
# Out[23]: ['Deer Bear River', 'Car Car River', 'Deer Car Bear']

# %%
text_file.map(lambda line: line.split(" ")).collect()
# Out:
# Out[24]: [['Deer', 'Bear', 'River'], ['Car', 'Car', 'River'], ['Deer', 'Car', 'Bear']]

# %%
text_file.flatMap(lambda line: line.split(" ")).collect()
# Out:
# Out[25]: ['Deer', 'Bear', 'River', 'Car', 'Car', 'River', 'Deer', 'Car', 'Bear']

# %%
counts = text_file.flatMap(lambda line: line.split(" ")) \
             .map(lambda word: (word, 1)) \
             .reduceByKey(lambda a, b: a + b)
counts.collect()
# Out:
# Out[28]: [('Bear', 2), ('Deer', 2), ('River', 2), ('Car', 3)]
