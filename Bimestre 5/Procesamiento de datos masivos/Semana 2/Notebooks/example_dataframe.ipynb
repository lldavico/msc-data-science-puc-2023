# %%
sc
# Out:
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="/?o=6288621065484677#setting/sparkui/0123-155106-fd9ezxaq/driver-4098225302316574884">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.3.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[8]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Databricks Shell</code></dd>
#             </dl>
#         </div>

# %%
from pyspark.sql import Row
from pyspark.sql.functions import col

textFile = sc.textFile("/FileStore/tables/logs.txt")

# Creamos un DataFrame con una única columna llamada line
df = textFile.map(lambda r: Row(r)).toDF(["line"])

# Filtramos por las que contengan el texto Error
errors = df.filter(col("line").like("%Error%"))

errors.count()
# Out:
# Out[10]: 218

# %%
errors.collect()
# Out:
# Out[11]: [Row(line='Error de la base de datos en la operación 10'),
#  Row(line='Error de la aplicación web de tipo 500 en la operación 14'),
#  Row(line='Error de la base de datos en la operación 15'),
#  Row(line='Error de la aplicación web de tipo 500 en la operación 17'),
#  Row(line='Error de la aplicación web de tipo 400 en la operación 27'),
#  Row(line='Error de la aplicación web de tipo 500 en la operación 28'),
#  Row(line='Error de la base de datos en la operación 31'),
#  Row(line='Error de la aplicación web de tipo 400 en la operación 35'),
#  Row(line='Error de la base de datos en la operación 37'),
#  Row(line='Error de la aplicación web de tipo 400 en la operación 39'),
#  Row(line='Error de la aplicación web de tipo 500 en la operación 40'),
#  Row(line='Error de la base de datos en la operación 41'),
#  Row(line='Error de la base de datos en la operación 42'),
#  Row(line='Error de la aplicación web de tipo 500 en la operación 43'),
#  Row(line='Error de la base de datos en la operación 45'),
#  Row(line='Error de la base de datos en la operación 46'),
#  Row(line='Error de la base de datos en la operación 49'),
#  Row(line='Error de la base de datos en la operación 50'),
#  Row(line='Error de la base de datos en la operación 53'),
#  Row(line='Error de la base de datos en la operación 56'),
#  Row(line='Error de la aplicación web de tipo 400 en la operación 60'),
#  Row(line='Error de la base de datos en la operación 62'),
#  Row(line='Error de la aplicación web de tipo 400 en la operación 65'),
#  Row(line='Error de la aplicación web de tipo 400 en la operación 67'),
#  Row(line='Error de la base de datos en la operación 68'),
#  Row(line='Error de la aplicación web de tipo 500 en la operación 70'),
#  Row(line='Error de la aplicación web de tipo 500 en la operación 78'),
#  Row(line='Error de la base de datos en la operación 83'),
#  Row(line='Error de la base de datos en la operación 86'),
#  Row(line='Error de la base de datos en la operación 91'),
#  Row(line='Error de la base de datos en la operación 101'),
#  Row(line='Error de la aplicación web de tipo 500 en la operación 102'),
#  Row(line='Error de la base de datos en la operación 109'),
#  Row(line='Error de la aplicación web de tipo 400 en la operación 115'),
#  Row(line='Error de la aplicación web de tipo 400 en la operación 118'),
#  Row(line='Error de la base de datos en la operación 126'),
#  Row(line='Error de la aplicación web de tipo 500 en la operación 133'),
#  Row(line='Error de la aplicación web de tipo 400 en la operación 140'),
#  Row(line='Error de la base de datos en la operación 143'),
#  Row(line='Error de la aplicación web de tipo 500 en la operación 159'),
#  Row(line='Error de la aplicación web de tipo 400 en la operación 165'),
#  Row(line='Error de la aplicación web de tipo 500 en la operación 166'),
#  Row(line='Error de la base de datos en la operación 185'),
#  Row(line='Error de la base de datos en la operación 188'),
#  Row(line='Error de la base de datos en la operación 195'),
#  Row(line='Error de la base de datos en la operación 210'),
#  Row(line='Error de la base de datos en la operación 219'),
#  Row(line='Error de la base de datos en la operación 222'),
#  Row(line='Error de la aplicación web de tipo 500 en la operación 227'),
#  Row(line='Error de la base de datos en la operación 228'),
#  Row(line='Error de la aplicación web de tipo 400 en la operación 238'),
#  Row(line='Error de la aplicación web de tipo 500 en la operación 239'),
#  Row(line='Error de la base de datos en la operación 241'),
#  Row(line='Error de la base de datos en la operación 243'),
#  Row(line='Error de la base de datos en la operación 246'),
#  Row(line='Error de la base de datos en la operación 247'),
#  Row(line='Error de la base de datos en la operación 253'),
#  Row(line='Error de la aplicación web de tipo 400 en la operación 261'),
#  Row(line='Error de la aplicación web de tipo 500 en la operación 267'),
#  Row(line='Error de la aplicación web de tipo 500 en la operación 268'),
#  Row(line='Error de la aplicación web de tipo 400 en la operación 276'),
#  Row(line='Error de la base de datos en la operación 280'),
#  Row(line='Error de la aplicación web de tipo 400 en la operación 282'),
#  Row(line='Error de la base de datos en la operación 287'),
#  Row(line='Error de la base de datos en la operación 290'),
#  Row(line='Error de la aplicación web de tipo 500 en la operación 292'),
#  Row(line='Error de la aplicación web de tipo 500 en la operación 297'),
#  Row(line='Error de la aplicación web de tipo 500 en la operación 301'),
#  Row(line='Error de la aplicación web de tipo 500 en la operación 302'),
#  Row(line='Error de la base de datos en la operación 307'),
#  Row(line='Error de la aplicación web de tipo 400 en la operación 308'),
#  Row(line='Error de la aplicación web de tipo 500 en la operación 313'),
#  Row(line='Error de la base de datos en la operación 315'),
#  Row(line='Error de la base de datos en la operación 322'),
#  Row(line='Error de la aplicación web de tipo 400 en la operación 324'),
#  Row(line='Error de la base de datos en la operación 338'),
#  Row(line='Error de la base de datos en la operación 339'),
#  Row(line='Error de la base de datos en la operación 340'),
#  Row(line='Error de la base de datos en la operación 341'),
#  Row(line='Error de la base de datos en la operación 345'),
#  Row(line='Error de la base de datos en la operación 347'),
#  Row(line='Error de la base de datos en la operación 349'),
#  Row(line='Error de la base de datos en la operación 350'),
#  Row(line='Error de la base de datos en la operación 354'),
#  Row(line='Error de la base de datos en la operación 358'),
#  Row(line='Error de la base de datos en la operación 360'),
#  Row(line='Error de la base de datos en la operación 364'),
#  Row(line='Error de la base de datos en la operación 368'),
#  Row(line='Error de la aplicación web de tipo 500 en la operación 369'),
#  Row(line='Error de la aplicación web de tipo 500 en la operación 374'),
#  Row(line='Error de la base de datos en la operación 378'),
#  Row(line='Error de la aplicación web de tipo 400 en la operación 380'),
#  Row(line='Error de la aplicación web de tipo 400 en la operación 405'),
#  Row(line='Error de la base de datos en la operación 406'),
#  Row(line='Error de la base de datos en la operación 411'),
#  Row(line='Error de la base de datos en la operación 422'),
#  Row(line='Error de la base de datos en la operación 428'),
#  Row(line='Error de la base de datos en la operación 429'),
#  Row(line='Error de la aplicación web de tipo 500 en la operación 442'),
#  Row(line='Error de la aplicación web de tipo 500 en la operación 445'),
#  Row(line='Error de la aplicación web de tipo 500 en la operación 449'),
#  Row(line='Error de la base de datos en la operación 452'),
#  Row(line='Error de la base de datos en la operación 458'),
#  Row(line='Error de la base de datos en la operación 465'),
#  Row(line='Error de la base de datos en la operación 471'),
#  Row(line='Error de la base de datos en la operación 474'),
#  Row(line='Error de la base de datos en la operación 476'),
#  Row(line='Error de la aplicación web de tipo 400 en la operación 484'),
#  Row(line='Error de la base de datos en la operación 485'),
#  Row(line='Error de la aplicación web de tipo 400 en la operación 488'),
#  Row(line='Error de la base de datos en la operación 496'),
#  Row(line='Error de la aplicación web de tipo 400 en la operación 504'),
#  Row(line='Error de la base de datos en la operación 505'),
#  Row(line='Error de la base de datos en la operación 506'),
#  Row(line='Error de la aplicación web de tipo 500 en la operación 507'),
#  Row(line='Error de la aplicación web de tipo 500 en la operación 511'),
#  Row(line='Error de la aplicación web de tipo 500 en la operación 512'),
#  Row(line='Error de la aplicación web de tipo 500 en la operación 513'),
#  Row(line='Error de la aplicación web de tipo 500 en la operación 516'),
#  Row(line='Error de la base de datos en la operación 523'),
#  Row(line='Error de la aplicación web de tipo 500 en la operación 526'),
#  Row(line='Error de la base de datos en la operación 527'),
#  Row(line='Error de la base de datos en la operación 542'),
#  Row(line='Error de la aplicación web de tipo 500 en la operación 554'),
#  Row(line='Error de la aplicación web de tipo 400 en la operación 561'),
#  Row(line='Error de la aplicación web de tipo 400 en la operación 565'),
#  Row(line='Error de la base de datos en la operación 571'),
#  Row(line='Error de la base de datos en la operación 578'),
#  Row(line='Error de la base de datos en la operación 590'),
#  Row(line='Error de la aplicación web de tipo 400 en la operación 593'),
#  Row(line='Error de la aplicación web de tipo 400 en la operación 610'),
#  Row(line='Error de la base de datos en la operación 613'),
#  Row(line='Error de la aplicación web de tipo 500 en la operación 615'),
#  Row(line='Error de la base de datos en la operación 624'),
#  Row(line='Error de la base de datos en la operación 627'),
#  Row(line='Error de la aplicación web de tipo 500 en la operación 629'),
#  Row(line='Error de la base de datos en la operación 632'),
#  Row(line='Error de la base de datos en la operación 639'),
#  Row(line='Error de la aplicación web de tipo 400 en la operación 651'),
#  Row(line='Error de la aplicación web de tipo 400 en la operación 656'),
#  Row(line='Error de la base de datos en la operación 660'),
#  Row(line='Error de la base de datos en la operación 662'),
#  Row(line='Error de la base de datos en la operación 664'),
#  Row(line='Error de la aplicación web de tipo 400 en la operación 666'),
#  Row(line='Error de la base de datos en la operación 667'),
#  Row(line='Error de la base de datos en la operación 678'),
#  Row(line='Error de la base de datos en la operación 682'),
#  Row(line='Error de la base de datos en la operación 684'),
#  Row(line='Error de la base de datos en la operación 689'),
#  Row(line='Error de la base de datos en la operación 703'),
#  Row(line='Error de la base de datos en la operación 704'),
#  Row(line='Error de la base de datos en la operación 709'),
#  Row(line='Error de la base de datos en la operación 710'),
#  Row(line='Error de la aplicación web de tipo 500 en la operación 717'),
#  Row(line='Error de la aplicación web de tipo 500 en la operación 719'),
#  Row(line='Error de la base de datos en la operación 722'),
#  Row(line='Error de la base de datos en la operación 723'),
#  Row(line='Error de la base de datos en la operación 734'),
#  Row(line='Error de la aplicación web de tipo 500 en la operación 736'),
#  Row(line='Error de la aplicación web de tipo 500 en la operación 742'),
#  Row(line='Error de la base de datos en la operación 750'),
#  Row(line='Error de la aplicación web de tipo 500 en la operación 751'),
#  Row(line='Error de la base de datos en la operación 754'),
#  Row(line='Error de la base de datos en la operación 760'),
#  Row(line='Error de la base de datos en la operación 769'),
#  Row(line='Error de la aplicación web de tipo 400 en la operación 771'),
#  Row(line='Error de la aplicación web de tipo 500 en la operación 779'),
#  Row(line='Error de la aplicación web de tipo 500 en la operación 782'),
#  Row(line='Error de la base de datos en la operación 784'),
#  Row(line='Error de la base de datos en la operación 790'),
#  Row(line='Error de la base de datos en la operación 805'),
#  Row(line='Error de la aplicación web de tipo 400 en la operación 806'),
#  Row(line='Error de la aplicación web de tipo 400 en la operación 807'),
#  Row(line='Error de la aplicación web de tipo 500 en la operación 810'),
#  Row(line='Error de la base de datos en la operación 812'),
#  Row(line='Error de la aplicación web de tipo 500 en la operación 813'),
#  Row(line='Error de la aplicación web de tipo 500 en la operación 817'),
#  Row(line='Error de la base de datos en la operación 820'),
#  Row(line='Error de la base de datos en la operación 825'),
#  Row(line='Error de la base de datos en la operación 827'),
#  Row(line='Error de la base de datos en la operación 831'),
#  Row(line='Error de la base de datos en la operación 832'),
#  Row(line='Error de la base de datos en la operación 835'),
#  Row(line='Error de la aplicación web de tipo 500 en la operación 839'),
#  Row(line='Error de la base de datos en la operación 845'),
#  Row(line='Error de la base de datos en la operación 863'),
#  Row(line='Error de la base de datos en la operación 864'),
#  Row(line='Error de la base de datos en la operación 865'),
#  Row(line='Error de la base de datos en la operación 867'),
#  Row(line='Error de la aplicación web de tipo 400 en la operación 879'),
#  Row(line='Error de la base de datos en la operación 888'),
#  Row(line='Error de la base de datos en la operación 896'),
#  Row(line='Error de la base de datos en la operación 902'),
#  Row(line='Error de la base de datos en la operación 903'),
#  Row(line='Error de la aplicación web de tipo 400 en la operación 908'),
#  Row(line='Error de la base de datos en la operación 909'),
#  Row(line='Error de la base de datos en la operación 911'),
#  Row(line='Error de la base de datos en la operación 912'),
#  Row(line='Error de la base de datos en la operación 923'),
#  Row(line='Error de la base de datos en la operación 926'),
#  Row(line='Error de la base de datos en la operación 927'),
#  Row(line='Error de la aplicación web de tipo 500 en la operación 928'),
#  Row(line='Error de la aplicación web de tipo 400 en la operación 931'),
#  Row(line='Error de la aplicación web de tipo 400 en la operación 933'),
#  Row(line='Error de la aplicación web de tipo 400 en la operación 934'),
#  Row(line='Error de la base de datos en la operación 935'),
#  Row(line='Error de la base de datos en la operación 940'),
#  Row(line='Error de la base de datos en la operación 942'),
#  Row(line='Error de la base de datos en la operación 947'),
#  Row(line='Error de la base de datos en la operación 949'),
#  Row(line='Error de la base de datos en la operación 951'),
#  Row(line='Error de la aplicación web de tipo 500 en la operación 955'),
#  Row(line='Error de la aplicación web de tipo 400 en la operación 971'),
#  Row(line='Error de la base de datos en la operación 972'),
#  Row(line='Error de la aplicación web de tipo 500 en la operación 973'),
#  Row(line='Error de la base de datos en la operación 983'),
#  Row(line='Error de la base de datos en la operación 988'),
#  Row(line='Error de la aplicación web de tipo 500 en la operación 990')]
