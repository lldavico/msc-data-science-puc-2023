# %%
sc
# Out:
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="/?o=6288621065484677#setting/sparkui/0123-155106-fd9ezxaq/driver-4098225302316574884">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.3.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[8]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Databricks Shell</code></dd>
#             </dl>
#         </div>

# %%
text_file = sc.textFile("/FileStore/tables/logs.txt")
text_file.collect()
# Out:
# Out[3]: ['Operación 0 ejecutada en la aplicación web',
#  'Operación 1 ejecutada en la aplicación web',
#  'Operación 2 ejecutada en la aplicación web',
#  'Operación 3 ejecutada en la aplicación web',
#  'Operación 4 ejecutada en la base de datos',
#  'Operación 5 ejecutada en la base de datos',
#  'Operación 6 ejecutada en la aplicación web',
#  'Operación 7 ejecutada en la base de datos',
#  'Operación 8 ejecutada en la base de datos',
#  'Operación 9 ejecutada en la base de datos',
#  'Error de la base de datos en la operación 10',
#  'Operación 11 ejecutada en la base de datos',
#  'Operación 12 ejecutada en la aplicación web',
#  'Operación 13 ejecutada en la base de datos',
#  'Error de la aplicación web de tipo 500 en la operación 14',
#  'Error de la base de datos en la operación 15',
#  'Operación 16 ejecutada en la aplicación web',
#  'Error de la aplicación web de tipo 500 en la operación 17',
#  'Operación 18 ejecutada en la aplicación web',
#  'Operación 19 ejecutada en la base de datos',
#  'Operación 20 ejecutada en la aplicación web',
#  'Operación 21 ejecutada en la aplicación web',
#  'Operación 22 ejecutada en la aplicación web',
#  'Operación 23 ejecutada en la aplicación web',
#  'Operación 24 ejecutada en la aplicación web',
#  'Operación 25 ejecutada en la aplicación web',
#  'Operación 26 ejecutada en la base de datos',
#  'Error de la aplicación web de tipo 400 en la operación 27',
#  'Error de la aplicación web de tipo 500 en la operación 28',
#  'Operación 29 ejecutada en la aplicación web',
#  'Operación 30 ejecutada en la aplicación web',
#  'Error de la base de datos en la operación 31',
#  'Operación 32 ejecutada en la base de datos',
#  'Operación 33 ejecutada en la aplicación web',
#  'Operación 34 ejecutada en la base de datos',
#  'Error de la aplicación web de tipo 400 en la operación 35',
#  'Operación 36 ejecutada en la aplicación web',
#  'Error de la base de datos en la operación 37',
#  'Operación 38 ejecutada en la aplicación web',
#  'Error de la aplicación web de tipo 400 en la operación 39',
#  'Error de la aplicación web de tipo 500 en la operación 40',
#  'Error de la base de datos en la operación 41',
#  'Error de la base de datos en la operación 42',
#  'Error de la aplicación web de tipo 500 en la operación 43',
#  'Operación 44 ejecutada en la aplicación web',
#  'Error de la base de datos en la operación 45',
#  'Error de la base de datos en la operación 46',
#  'Operación 47 ejecutada en la aplicación web',
#  'Operación 48 ejecutada en la base de datos',
#  'Error de la base de datos en la operación 49',
#  'Error de la base de datos en la operación 50',
#  'Operación 51 ejecutada en la aplicación web',
#  'Operación 52 ejecutada en la base de datos',
#  'Error de la base de datos en la operación 53',
#  'Operación 54 ejecutada en la aplicación web',
#  'Operación 55 ejecutada en la aplicación web',
#  'Error de la base de datos en la operación 56',
#  'Operación 57 ejecutada en la base de datos',
#  'Operación 58 ejecutada en la aplicación web',
#  'Operación 59 ejecutada en la aplicación web',
#  'Error de la aplicación web de tipo 400 en la operación 60',
#  'Operación 61 ejecutada en la aplicación web',
#  'Error de la base de datos en la operación 62',
#  'Operación 63 ejecutada en la aplicación web',
#  'Operación 64 ejecutada en la base de datos',
#  'Error de la aplicación web de tipo 400 en la operación 65',
#  'Operación 66 ejecutada en la base de datos',
#  'Error de la aplicación web de tipo 400 en la operación 67',
#  'Error de la base de datos en la operación 68',
#  'Operación 69 ejecutada en la base de datos',
#  'Error de la aplicación web de tipo 500 en la operación 70',
#  'Operación 71 ejecutada en la aplicación web',
#  'Operación 72 ejecutada en la base de datos',
#  'Operación 73 ejecutada en la aplicación web',
#  'Operación 74 ejecutada en la aplicación web',
#  'Operación 75 ejecutada en la aplicación web',
#  'Operación 76 ejecutada en la base de datos',
#  'Operación 77 ejecutada en la aplicación web',
#  'Error de la aplicación web de tipo 500 en la operación 78',
#  'Operación 79 ejecutada en la base de datos',
#  'Operación 80 ejecutada en la aplicación web',
#  'Operación 81 ejecutada en la aplicación web',
#  'Operación 82 ejecutada en la aplicación web',
#  'Error de la base de datos en la operación 83',
#  'Operación 84 ejecutada en la base de datos',
#  'Operación 85 ejecutada en la aplicación web',
#  'Error de la base de datos en la operación 86',
#  'Operación 87 ejecutada en la aplicación web',
#  'Operación 88 ejecutada en la base de datos',
#  'Operación 89 ejecutada en la aplicación web',
#  'Operación 90 ejecutada en la aplicación web',
#  'Error de la base de datos en la operación 91',
#  'Operación 92 ejecutada en la aplicación web',
#  'Operación 93 ejecutada en la aplicación web',
#  'Operación 94 ejecutada en la base de datos',
#  'Operación 95 ejecutada en la aplicación web',
#  'Operación 96 ejecutada en la base de datos',
#  'Operación 97 ejecutada en la aplicación web',
#  'Operación 98 ejecutada en la base de datos',
#  'Operación 99 ejecutada en la base de datos',
#  'Operación 100 ejecutada en la aplicación web',
#  'Error de la base de datos en la operación 101',
#  'Error de la aplicación web de tipo 500 en la operación 102',
#  'Operación 103 ejecutada en la base de datos',
#  'Operación 104 ejecutada en la base de datos',
#  'Operación 105 ejecutada en la aplicación web',
#  'Operación 106 ejecutada en la aplicación web',
#  'Operación 107 ejecutada en la base de datos',
#  'Operación 108 ejecutada en la aplicación web',
#  'Error de la base de datos en la operación 109',
#  'Operación 110 ejecutada en la aplicación web',
#  'Operación 111 ejecutada en la base de datos',
#  'Operación 112 ejecutada en la aplicación web',
#  'Operación 113 ejecutada en la base de datos',
#  'Operación 114 ejecutada en la aplicación web',
#  'Error de la aplicación web de tipo 400 en la operación 115',
#  'Operación 116 ejecutada en la aplicación web',
#  'Operación 117 ejecutada en la base de datos',
#  'Error de la aplicación web de tipo 400 en la operación 118',
#  'Operación 119 ejecutada en la aplicación web',
#  'Operación 120 ejecutada en la aplicación web',
#  'Operación 121 ejecutada en la aplicación web',
#  'Operación 122 ejecutada en la base de datos',
#  'Operación 123 ejecutada en la aplicación web',
#  'Operación 124 ejecutada en la aplicación web',
#  'Operación 125 ejecutada en la base de datos',
#  'Error de la base de datos en la operación 126',
#  'Operación 127 ejecutada en la base de datos',
#  'Operación 128 ejecutada en la aplicación web',
#  'Operación 129 ejecutada en la aplicación web',
#  'Operación 130 ejecutada en la base de datos',
#  'Operación 131 ejecutada en la base de datos',
#  'Operación 132 ejecutada en la aplicación web',
#  'Error de la aplicación web de tipo 500 en la operación 133',
#  'Operación 134 ejecutada en la base de datos',
#  'Operación 135 ejecutada en la aplicación web',
#  'Operación 136 ejecutada en la base de datos',
#  'Operación 137 ejecutada en la aplicación web',
#  'Operación 138 ejecutada en la aplicación web',
#  'Operación 139 ejecutada en la base de datos',
#  'Error de la aplicación web de tipo 400 en la operación 140',
#  'Operación 141 ejecutada en la base de datos',
#  'Operación 142 ejecutada en la base de datos',
#  'Error de la base de datos en la operación 143',
#  'Operación 144 ejecutada en la aplicación web',
#  'Operación 145 ejecutada en la aplicación web',
#  'Operación 146 ejecutada en la aplicación web',
#  'Operación 147 ejecutada en la aplicación web',
#  'Operación 148 ejecutada en la base de datos',
#  'Operación 149 ejecutada en la base de datos',
#  'Operación 150 ejecutada en la aplicación web',
#  'Operación 151 ejecutada en la base de datos',
#  'Operación 152 ejecutada en la base de datos',
#  'Operación 153 ejecutada en la aplicación web',
#  'Operación 154 ejecutada en la aplicación web',
#  'Operación 155 ejecutada en la aplicación web',
#  'Operación 156 ejecutada en la aplicación web',
#  'Operación 157 ejecutada en la aplicación web',
#  'Operación 158 ejecutada en la aplicación web',
#  'Error de la aplicación web de tipo 500 en la operación 159',
#  'Operación 160 ejecutada en la base de datos',
#  'Operación 161 ejecutada en la aplicación web',
#  'Operación 162 ejecutada en la aplicación web',
#  'Operación 163 ejecutada en la aplicación web',
#  'Operación 164 ejecutada en la aplicación web',
#  'Error de la aplicación web de tipo 400 en la operación 165',
#  'Error de la aplicación web de tipo 500 en la operación 166',
#  'Operación 167 ejecutada en la aplicación web',
#  'Operación 168 ejecutada en la aplicación web',
#  'Operación 169 ejecutada en la aplicación web',
#  'Operación 170 ejecutada en la aplicación web',
#  'Operación 171 ejecutada en la base de datos',
#  'Operación 172 ejecutada en la aplicación web',
#  'Operación 173 ejecutada en la aplicación web',
#  'Operación 174 ejecutada en la aplicación web',
#  'Operación 175 ejecutada en la aplicación web',
#  'Operación 176 ejecutada en la aplicación web',
#  'Operación 177 ejecutada en la aplicación web',
#  'Operación 178 ejecutada en la aplicación web',
#  'Operación 179 ejecutada en la aplicación web',
#  'Operación 180 ejecutada en la aplicación web',
#  'Operación 181 ejecutada en la aplicación web',
#  'Operación 182 ejecutada en la aplicación web',
#  'Operación 183 ejecutada en la aplicación web',
#  'Operación 184 ejecutada en la base de datos',
#  'Error de la base de datos en la operación 185',
#  'Operación 186 ejecutada en la base de datos',
#  'Operación 187 ejecutada en la aplicación web',
#  'Error de la base de datos en la operación 188',
#  'Operación 189 ejecutada en la aplicación web',
#  'Operación 190 ejecutada en la aplicación web',
#  'Operación 191 ejecutada en la base de datos',
#  'Operación 192 ejecutada en la base de datos',
#  'Operación 193 ejecutada en la aplicación web',
#  'Operación 194 ejecutada en la aplicación web',
#  'Error de la base de datos en la operación 195',
#  'Operación 196 ejecutada en la aplicación web',
#  'Operación 197 ejecutada en la aplicación web',
#  'Operación 198 ejecutada en la aplicación web',
#  'Operación 199 ejecutada en la aplicación web',
#  'Operación 200 ejecutada en la aplicación web',
#  'Operación 201 ejecutada en la aplicación web',
#  'Operación 202 ejecutada en la aplicación web',
#  'Operación 203 ejecutada en la aplicación web',
#  'Operación 204 ejecutada en la aplicación web',
#  'Operación 205 ejecutada en la aplicación web',
#  'Operación 206 ejecutada en la base de datos',
#  'Operación 207 ejecutada en la base de datos',
#  'Operación 208 ejecutada en la base de datos',
#  'Operación 209 ejecutada en la aplicación web',
#  'Error de la base de datos en la operación 210',
#  'Operación 211 ejecutada en la aplicación web',
#  'Operación 212 ejecutada en la base de datos',
#  'Operación 213 ejecutada en la base de datos',
#  'Operación 214 ejecutada en la aplicación web',
#  'Operación 215 ejecutada en la base de datos',
#  'Operación 216 ejecutada en la aplicación web',
#  'Operación 217 ejecutada en la base de datos',
#  'Operación 218 ejecutada en la base de datos',
#  'Error de la base de datos en la operación 219',
#  'Operación 220 ejecutada en la base de datos',
#  'Operación 221 ejecutada en la aplicación web',
#  'Error de la base de datos en la operación 222',
#  'Operación 223 ejecutada en la aplicación web',
#  'Operación 224 ejecutada en la aplicación web',
#  'Operación 225 ejecutada en la base de datos',
#  'Operación 226 ejecutada en la aplicación web',
#  'Error de la aplicación web de tipo 500 en la operación 227',
#  'Error de la base de datos en la operación 228',
#  'Operación 229 ejecutada en la aplicación web',
#  'Operación 230 ejecutada en la base de datos',
#  'Operación 231 ejecutada en la aplicación web',
#  'Operación 232 ejecutada en la base de datos',
#  'Operación 233 ejecutada en la aplicación web',
#  'Operación 234 ejecutada en la base de datos',
#  'Operación 235 ejecutada en la aplicación web',
#  'Operación 236 ejecutada en la aplicación web',
#  'Operación 237 ejecutada en la base de datos',
#  'Error de la aplicación web de tipo 400 en la operación 238',
#  'Error de la aplicación web de tipo 500 en la operación 239',
#  'Operación 240 ejecutada en la base de datos',
#  'Error de la base de datos en la operación 241',
#  'Operación 242 ejecutada en la aplicación web',
#  'Error de la base de datos en la operación 243',
#  'Operación 244 ejecutada en la aplicación web',
#  'Operación 245 ejecutada en la base de datos',
#  'Error de la base de datos en la operación 246',
#  'Error de la base de datos en la operación 247',
#  'Operación 248 ejecutada en la base de datos',
#  'Operación 249 ejecutada en la aplicación web',
#  'Operación 250 ejecutada en la base de datos',
#  'Operación 251 ejecutada en la aplicación web',
#  'Operación 252 ejecutada en la aplicación web',
#  'Error de la base de datos en la operación 253',
#  'Operación 254 ejecutada en la base de datos',
#  'Operación 255 ejecutada en la aplicación web',
#  'Operación 256 ejecutada en la aplicación web',
#  'Operación 257 ejecutada en la aplicación web',
#  'Operación 258 ejecutada en la base de datos',
#  'Operación 259 ejecutada en la aplicación web',
#  'Operación 260 ejecutada en la base de datos',
#  'Error de la aplicación web de tipo 400 en la operación 261',
#  'Operación 262 ejecutada en la base de datos',
#  'Operación 263 ejecutada en la base de datos',
#  'Operación 264 ejecutada en la base de datos',
#  'Operación 265 ejecutada en la base de datos',
#  'Operación 266 ejecutada en la base de datos',
#  'Error de la aplicación web de tipo 500 en la operación 267',
#  'Error de la aplicación web de tipo 500 en la operación 268',
#  'Operación 269 ejecutada en la aplicación web',
#  'Operación 270 ejecutada en la base de datos',
#  'Operación 271 ejecutada en la base de datos',
#  'Operación 272 ejecutada en la base de datos',
#  'Operación 273 ejecutada en la aplicación web',
#  'Operación 274 ejecutada en la aplicación web',
#  'Operación 275 ejecutada en la aplicación web',
#  'Error de la aplicación web de tipo 400 en la operación 276',
#  'Operación 277 ejecutada en la base de datos',
#  'Operación 278 ejecutada en la base de datos',
#  'Operación 279 ejecutada en la aplicación web',
#  'Error de la base de datos en la operación 280',
#  'Operación 281 ejecutada en la aplicación web',
#  'Error de la aplicación web de tipo 400 en la operación 282',
#  'Operación 283 ejecutada en la base de datos',
#  'Operación 284 ejecutada en la aplicación web',
#  'Operación 285 ejecutada en la aplicación web',
#  'Operación 286 ejecutada en la aplicación web',
#  'Error de la base de datos en la operación 287',
#  'Operación 288 ejecutada en la base de datos',
#  'Operación 289 ejecutada en la base de datos',
#  'Error de la base de datos en la operación 290',
#  'Operación 291 ejecutada en la aplicación web',
#  'Error de la aplicación web de tipo 500 en la operación 292',
#  'Operación 293 ejecutada en la aplicación web',
#  'Operación 294 ejecutada en la aplicación web',
#  'Operación 295 ejecutada en la aplicación web',
#  'Operación 296 ejecutada en la base de datos',
#  'Error de la aplicación web de tipo 500 en la operación 297',
#  'Operación 298 ejecutada en la aplicación web',
#  'Operación 299 ejecutada en la aplicación web',
#  'Operación 300 ejecutada en la aplicación web',
#  'Error de la aplicación web de tipo 500 en la operación 301',
#  'Error de la aplicación web de tipo 500 en la operación 302',
#  'Operación 303 ejecutada en la aplicación web',
#  'Operación 304 ejecutada en la aplicación web',
#  'Operación 305 ejecutada en la aplicación web',
#  'Operación 306 ejecutada en la aplicación web',
#  'Error de la base de datos en la operación 307',
#  'Error de la aplicación web de tipo 400 en la operación 308',
#  'Operación 309 ejecutada en la base de datos',
#  'Operación 310 ejecutada en la base de datos',
#  'Operación 311 ejecutada en la base de datos',
#  'Operación 312 ejecutada en la aplicación web',
#  'Error de la aplicación web de tipo 500 en la operación 313',
#  'Operación 314 ejecutada en la base de datos',
#  'Error de la base de datos en la operación 315',
#  'Operación 316 ejecutada en la aplicación web',
#  'Operación 317 ejecutada en la aplicación web',
#  'Operación 318 ejecutada en la aplicación web',
#  'Operación 319 ejecutada en la aplicación web',
#  'Operación 320 ejecutada en la aplicación web',
#  'Operación 321 ejecutada en la aplicación web',
#  'Error de la base de datos en la operación 322',
#  'Operación 323 ejecutada en la aplicación web',
#  'Error de la aplicación web de tipo 400 en la operación 324',
#  'Operación 325 ejecutada en la aplicación web',
#  'Operación 326 ejecutada en la aplicación web',
#  'Operación 327 ejecutada en la aplicación web',
#  'Operación 328 ejecutada en la base de datos',
#  'Operación 329 ejecutada en la base de datos',
#  'Operación 330 ejecutada en la base de datos',
#  'Operación 331 ejecutada en la base de datos',
#  'Operación 332 ejecutada en la base de datos',
#  'Operación 333 ejecutada en la base de datos',
#  'Operación 334 ejecutada en la aplicación web',
#  'Operación 335 ejecutada en la aplicación web',
#  'Operación 336 ejecutada en la aplicación web',
#  'Operación 337 ejecutada en la aplicación web',
#  'Error de la base de datos en la operación 338',
#  'Error de la base de datos en la operación 339',
#  'Error de la base de datos en la operación 340',
#  'Error de la base de datos en la operación 341',
#  'Operación 342 ejecutada en la aplicación web',
#  'Operación 343 ejecutada en la aplicación web',
#  'Operación 344 ejecutada en la aplicación web',
#  'Error de la base de datos en la operación 345',
#  'Operación 346 ejecutada en la aplicación web',
#  'Error de la base de datos en la operación 347',
#  'Operación 348 ejecutada en la aplicación web',
#  'Error de la base de datos en la operación 349',
#  'Error de la base de datos en la operación 350',
#  'Operación 351 ejecutada en la aplicación web',
#  'Operación 352 ejecutada en la aplicación web',
#  'Operación 353 ejecutada en la aplicación web',
#  'Error de la base de datos en la operación 354',
#  'Operación 355 ejecutada en la base de datos',
#  'Operación 356 ejecutada en la aplicación web',
#  'Operación 357 ejecutada en la aplicación web',
#  'Error de la base de datos en la operación 358',
#  'Operación 359 ejecutada en la aplicación web',
#  'Error de la base de datos en la operación 360',
#  'Operación 361 ejecutada en la aplicación web',
#  'Operación 362 ejecutada en la aplicación web',
#  'Operación 363 ejecutada en la base de datos',
#  'Error de la base de datos en la operación 364',
#  'Operación 365 ejecutada en la base de datos',
#  'Operación 366 ejecutada en la base de datos',
#  'Operación 367 ejecutada en la aplicación web',
#  'Error de la base de datos en la operación 368',
#  'Error de la aplicación web de tipo 500 en la operación 369',
#  'Operación 370 ejecutada en la base de datos',
#  'Operación 371 ejecutada en la aplicación web',
#  'Operación 372 ejecutada en la base de datos',
#  'Operación 373 ejecutada en la base de datos',
#  'Error de la aplicación web de tipo 500 en la operación 374',
#  'Operación 375 ejecutada en la aplicación web',
#  'Operación 376 ejecutada en la base de datos',
#  'Operación 377 ejecutada en la aplicación web',
#  'Error de la base de datos en la operación 378',
#  'Operación 379 ejecutada en la aplicación web',
#  'Error de la aplicación web de tipo 400 en la operación 380',
#  'Operación 381 ejecutada en la aplicación web',
#  'Operación 382 ejecutada en la aplicación web',
#  'Operación 383 ejecutada en la aplicación web',
#  'Operación 384 ejecutada en la base de datos',
#  'Operación 385 ejecutada en la base de datos',
#  'Operación 386 ejecutada en la aplicación web',
#  'Operación 387 ejecutada en la aplicación web',
#  'Operación 388 ejecutada en la aplicación web',
#  'Operación 389 ejecutada en la base de datos',
#  'Operación 390 ejecutada en la aplicación web',
#  'Operación 391 ejecutada en la base de datos',
#  'Operación 392 ejecutada en la base de datos',
#  'Operación 393 ejecutada en la aplicación web',
#  'Operación 394 ejecutada en la aplicación web',
#  'Operación 395 ejecutada en la base de datos',
#  'Operación 396 ejecutada en la aplicación web',
#  'Operación 397 ejecutada en la aplicación web',
#  'Operación 398 ejecutada en la aplicación web',
#  'Operación 399 ejecutada en la aplicación web',
#  'Operación 400 ejecutada en la aplicación web',
#  'Operación 401 ejecutada en la aplicación web',
#  'Operación 402 ejecutada en la aplicación web',
#  'Operación 403 ejecutada en la aplicación web',
#  'Operación 404 ejecutada en la base de datos',
#  'Error de la aplicación web de tipo 400 en la operación 405',
#  'Error de la base de datos en la operación 406',
#  'Operación 407 ejecutada en la aplicación web',
#  'Operación 408 ejecutada en la aplicación web',
#  'Operación 409 ejecutada en la aplicación web',
#  'Operación 410 ejecutada en la aplicación web',
#  'Error de la base de datos en la operación 411',
#  'Operación 412 ejecutada en la base de datos',
#  'Operación 413 ejecutada en la base de datos',
#  'Operación 414 ejecutada en la base de datos',
#  'Operación 415 ejecutada en la aplicación web',
#  'Operación 416 ejecutada en la aplicación web',
#  'Operación 417 ejecutada en la aplicación web',
#  'Operación 418 ejecutada en la base de datos',
#  'Operación 419 ejecutada en la aplicación web',
#  'Operación 420 ejecutada en la aplicación web',
#  'Operación 421 ejecutada en la base de datos',
#  'Error de la base de datos en la operación 422',
#  'Operación 423 ejecutada en la base de datos',
#  'Operación 424 ejecutada en la aplicación web',
#  'Operación 425 ejecutada en la base de datos',
#  'Operación 426 ejecutada en la base de datos',
#  'Operación 427 ejecutada en la aplicación web',
#  'Error de la base de datos en la operación 428',
#  'Error de la base de datos en la operación 429',
#  'Operación 430 ejecutada en la aplicación web',
#  'Operación 431 ejecutada en la aplicación web',
#  'Operación 432 ejecutada en la aplicación web',
#  'Operación 433 ejecutada en la base de datos',
#  'Operación 434 ejecutada en la base de datos',
#  'Operación 435 ejecutada en la base de datos',
#  'Operación 436 ejecutada en la base de datos',
#  'Operación 437 ejecutada en la aplicación web',
#  'Operación 438 ejecutada en la aplicación web',
#  'Operación 439 ejecutada en la base de datos',
#  'Operación 440 ejecutada en la aplicación web',
#  'Operación 441 ejecutada en la base de datos',
#  'Error de la aplicación web de tipo 500 en la operación 442',
#  'Operación 443 ejecutada en la base de datos',
#  'Operación 444 ejecutada en la base de datos',
#  'Error de la aplicación web de tipo 500 en la operación 445',
#  'Operación 446 ejecutada en la aplicación web',
#  'Operación 447 ejecutada en la aplicación web',
#  'Operación 448 ejecutada en la base de datos',
#  'Error de la aplicación web de tipo 500 en la operación 449',
#  'Operación 450 ejecutada en la base de datos',
#  'Operación 451 ejecutada en la aplicación web',
#  'Error de la base de datos en la operación 452',
#  'Operación 453 ejecutada en la aplicación web',
#  'Operación 454 ejecutada en la aplicación web',
#  'Operación 455 ejecutada en la aplicación web',
#  'Operación 456 ejecutada en la aplicación web',
#  'Operación 457 ejecutada en la base de datos',
#  'Error de la base de datos en la operación 458',
#  'Operación 459 ejecutada en la base de datos',
#  'Operación 460 ejecutada en la aplicación web',
#  'Operación 461 ejecutada en la aplicación web',
#  'Operación 462 ejecutada en la aplicación web',
#  'Operación 463 ejecutada en la aplicación web',
#  'Operación 464 ejecutada en la base de datos',
#  'Error de la base de datos en la operación 465',
#  'Operación 466 ejecutada en la aplicación web',
#  'Operación 467 ejecutada en la aplicación web',
#  'Operación 468 ejecutada en la aplicación web',
#  'Operación 469 ejecutada en la aplicación web',
#  'Operación 470 ejecutada en la aplicación web',
#  'Error de la base de datos en la operación 471',
#  'Operación 472 ejecutada en la aplicación web',
#  'Operación 473 ejecutada en la aplicación web',
#  'Error de la base de datos en la operación 474',
#  'Operación 475 ejecutada en la base de datos',
#  'Error de la base de datos en la operación 476',
#  'Operación 477 ejecutada en la aplicación web',
#  'Operación 478 ejecutada en la aplicación web',
#  'Operación 479 ejecutada en la aplicación web',
#  'Operación 480 ejecutada en la base de datos',
#  'Operación 481 ejecutada en la base de datos',
#  'Operación 482 ejecutada en la base de datos',
#  'Operación 483 ejecutada en la aplicación web',
#  'Error de la aplicación web de tipo 400 en la operación 484',
#  'Error de la base de datos en la operación 485',
#  'Operación 486 ejecutada en la base de datos',
#  'Operación 487 ejecutada en la aplicación web',
#  'Error de la aplicación web de tipo 400 en la operación 488',
#  'Operación 489 ejecutada en la aplicación web',
#  'Operación 490 ejecutada en la base de datos',
#  'Operación 491 ejecutada en la aplicación web',
#  'Operación 492 ejecutada en la base de datos',
#  'Operación 493 ejecutada en la base de datos',
#  'Operación 494 ejecutada en la aplicación web',
#  'Operación 495 ejecutada en la base de datos',
#  'Error de la base de datos en la operación 496',
#  'Operación 497 ejecutada en la aplicación web',
#  'Operación 498 ejecutada en la base de datos',
#  'Operación 499 ejecutada en la base de datos',
#  'Operación 500 ejecutada en la base de datos',
#  'Operación 501 ejecutada en la aplicación web',
#  'Operación 502 ejecutada en la base de datos',
#  'Operación 503 ejecutada en la aplicación web',
#  'Error de la aplicación web de tipo 400 en la operación 504',
#  'Error de la base de datos en la operación 505',
#  'Error de la base de datos en la operación 506',
#  'Error de la aplicación web de tipo 500 en la operación 507',
#  'Operación 508 ejecutada en la base de datos',
#  'Operación 509 ejecutada en la base de datos',
#  'Operación 510 ejecutada en la aplicación web',
#  'Error de la aplicación web de tipo 500 en la operación 511',
#  'Error de la aplicación web de tipo 500 en la operación 512',
#  'Error de la aplicación web de tipo 500 en la operación 513',
#  'Operación 514 ejecutada en la aplicación web',
#  'Operación 515 ejecutada en la aplicación web',
#  'Error de la aplicación web de tipo 500 en la operación 516',
#  'Operación 517 ejecutada en la base de datos',
#  'Operación 518 ejecutada en la aplicación web',
#  'Operación 519 ejecutada en la aplicación web',
#  'Operación 520 ejecutada en la aplicación web',
#  'Operación 521 ejecutada en la base de datos',
#  'Operación 522 ejecutada en la base de datos',
#  'Error de la base de datos en la operación 523',
#  'Operación 524 ejecutada en la base de datos',
#  'Operación 525 ejecutada en la aplicación web',
#  'Error de la aplicación web de tipo 500 en la operación 526',
#  'Error de la base de datos en la operación 527',
#  'Operación 528 ejecutada en la aplicación web',
#  'Operación 529 ejecutada en la aplicación web',
#  'Operación 530 ejecutada en la aplicación web',
#  'Operación 531 ejecutada en la base de datos',
#  'Operación 532 ejecutada en la aplicación web',
#  'Operación 533 ejecutada en la aplicación web',
#  'Operación 534 ejecutada en la aplicación web',
#  'Operación 535 ejecutada en la aplicación web',
#  'Operación 536 ejecutada en la aplicación web',
#  'Operación 537 ejecutada en la aplicación web',
#  'Operación 538 ejecutada en la base de datos',
#  'Operación 539 ejecutada en la base de datos',
#  'Operación 540 ejecutada en la base de datos',
#  'Operación 541 ejecutada en la base de datos',
#  'Error de la base de datos en la operación 542',
#  'Operación 543 ejecutada en la aplicación web',
#  'Operación 544 ejecutada en la base de datos',
#  'Operación 545 ejecutada en la aplicación web',
#  'Operación 546 ejecutada en la base de datos',
#  'Operación 547 ejecutada en la base de datos',
#  'Operación 548 ejecutada en la base de datos',
#  'Operación 549 ejecutada en la aplicación web',
#  'Operación 550 ejecutada en la aplicación web',
#  'Operación 551 ejecutada en la base de datos',
#  'Operación 552 ejecutada en la aplicación web',
#  'Operación 553 ejecutada en la aplicación web',
#  'Error de la aplicación web de tipo 500 en la operación 554',
#  'Operación 555 ejecutada en la aplicación web',
#  'Operación 556 ejecutada en la aplicación web',
#  'Operación 557 ejecutada en la base de datos',
#  'Operación 558 ejecutada en la base de datos',
#  'Operación 559 ejecutada en la aplicación web',
#  'Operación 560 ejecutada en la aplicación web',
#  'Error de la aplicación web de tipo 400 en la operación 561',
#  'Operación 562 ejecutada en la base de datos',
#  'Operación 563 ejecutada en la aplicación web',
#  'Operación 564 ejecutada en la base de datos',
#  'Error de la aplicación web de tipo 400 en la operación 565',
#  'Operación 566 ejecutada en la aplicación web',
#  'Operación 567 ejecutada en la aplicación web',
#  'Operación 568 ejecutada en la aplicación web',
#  'Operación 569 ejecutada en la base de datos',
#  'Operación 570 ejecutada en la aplicación web',
#  'Error de la base de datos en la operación 571',
#  'Operación 572 ejecutada en la aplicación web',
#  'Operación 573 ejecutada en la base de datos',
#  'Operación 574 ejecutada en la aplicación web',
#  'Operación 575 ejecutada en la aplicación web',
#  'Operación 576 ejecutada en la base de datos',
#  'Operación 577 ejecutada en la aplicación web',
#  'Error de la base de datos en la operación 578',
#  'Operación 579 ejecutada en la aplicación web',
#  'Operación 580 ejecutada en la base de datos',
#  'Operación 581 ejecutada en la base de datos',
#  'Operación 582 ejecutada en la aplicación web',
#  'Operación 583 ejecutada en la base de datos',
#  'Operación 584 ejecutada en la base de datos',
#  'Operación 585 ejecutada en la aplicación web',
#  'Operación 586 ejecutada en la aplicación web',
#  'Operación 587 ejecutada en la base de datos',
#  'Operación 588 ejecutada en la aplicación web',
#  'Operación 589 ejecutada en la base de datos',
#  'Error de la base de datos en la operación 590',
#  'Operación 591 ejecutada en la aplicación web',
#  'Operación 592 ejecutada en la aplicación web',
#  'Error de la aplicación web de tipo 400 en la operación 593',
#  'Operación 594 ejecutada en la aplicación web',
#  'Operación 595 ejecutada en la aplicación web',
#  'Operación 596 ejecutada en la base de datos',
#  'Operación 597 ejecutada en la aplicación web',
#  'Operación 598 ejecutada en la aplicación web',
#  'Operación 599 ejecutada en la aplicación web',
#  'Operación 600 ejecutada en la base de datos',
#  'Operación 601 ejecutada en la aplicación web',
#  'Operación 602 ejecutada en la aplicación web',
#  'Operación 603 ejecutada en la base de datos',
#  'Operación 604 ejecutada en la aplicación web',
#  'Operación 605 ejecutada en la aplicación web',
#  'Operación 606 ejecutada en la base de datos',
#  'Operación 607 ejecutada en la aplicación web',
#  'Operación 608 ejecutada en la aplicación web',
#  'Operación 609 ejecutada en la aplicación web',
#  'Error de la aplicación web de tipo 400 en la operación 610',
#  'Operación 611 ejecutada en la base de datos',
#  'Operación 612 ejecutada en la aplicación web',
#  'Error de la base de datos en la operación 613',
#  'Operación 614 ejecutada en la aplicación web',
#  'Error de la aplicación web de tipo 500 en la operación 615',
#  'Operación 616 ejecutada en la aplicación web',
#  'Operación 617 ejecutada en la base de datos',
#  'Operación 618 ejecutada en la base de datos',
#  'Operación 619 ejecutada en la base de datos',
#  'Operación 620 ejecutada en la base de datos',
#  'Operación 621 ejecutada en la aplicación web',
#  'Operación 622 ejecutada en la base de datos',
#  'Operación 623 ejecutada en la base de datos',
#  'Error de la base de datos en la operación 624',
#  'Operación 625 ejecutada en la base de datos',
#  'Operación 626 ejecutada en la base de datos',
#  'Error de la base de datos en la operación 627',
#  'Operación 628 ejecutada en la aplicación web',
#  'Error de la aplicación web de tipo 500 en la operación 629',
#  'Operación 630 ejecutada en la aplicación web',
#  'Operación 631 ejecutada en la aplicación web',
#  'Error de la base de datos en la operación 632',
#  'Operación 633 ejecutada en la base de datos',
#  'Operación 634 ejecutada en la aplicación web',
#  'Operación 635 ejecutada en la aplicación web',
#  'Operación 636 ejecutada en la aplicación web',
#  'Operación 637 ejecutada en la aplicación web',
#  'Operación 638 ejecutada en la aplicación web',
#  'Error de la base de datos en la operación 639',
#  'Operación 640 ejecutada en la base de datos',
#  'Operación 641 ejecutada en la base de datos',
#  'Operación 642 ejecutada en la aplicación web',
#  'Operación 643 ejecutada en la aplicación web',
#  'Operación 644 ejecutada en la base de datos',
#  'Operación 645 ejecutada en la aplicación web',
#  'Operación 646 ejecutada en la aplicación web',
#  'Operación 647 ejecutada en la base de datos',
#  'Operación 648 ejecutada en la aplicación web',
#  'Operación 649 ejecutada en la aplicación web',
#  'Operación 650 ejecutada en la base de datos',
#  'Error de la aplicación web de tipo 400 en la operación 651',
#  'Operación 652 ejecutada en la aplicación web',
#  'Operación 653 ejecutada en la aplicación web',
#  'Operación 654 ejecutada en la aplicación web',
#  'Operación 655 ejecutada en la base de datos',
#  'Error de la aplicación web de tipo 400 en la operación 656',
#  'Operación 657 ejecutada en la aplicación web',
#  'Operación 658 ejecutada en la aplicación web',
#  'Operación 659 ejecutada en la base de datos',
#  'Error de la base de datos en la operación 660',
#  'Operación 661 ejecutada en la base de datos',
#  'Error de la base de datos en la operación 662',
#  'Operación 663 ejecutada en la base de datos',
#  'Error de la base de datos en la operación 664',
#  'Operación 665 ejecutada en la base de datos',
#  'Error de la aplicación web de tipo 400 en la operación 666',
#  'Error de la base de datos en la operación 667',
#  'Operación 668 ejecutada en la aplicación web',
#  'Operación 669 ejecutada en la base de datos',
#  'Operación 670 ejecutada en la base de datos',
#  'Operación 671 ejecutada en la aplicación web',
#  'Operación 672 ejecutada en la base de datos',
#  'Operación 673 ejecutada en la aplicación web',
#  'Operación 674 ejecutada en la base de datos',
#  'Operación 675 ejecutada en la aplicación web',
#  'Operación 676 ejecutada en la base de datos',
#  'Operación 677 ejecutada en la aplicación web',
#  'Error de la base de datos en la operación 678',
#  'Operación 679 ejecutada en la base de datos',
#  'Operación 680 ejecutada en la base de datos',
#  'Operación 681 ejecutada en la aplicación web',
#  'Error de la base de datos en la operación 682',
#  'Operación 683 ejecutada en la base de datos',
#  'Error de la base de datos en la operación 684',
#  'Operación 685 ejecutada en la base de datos',
#  'Operación 686 ejecutada en la aplicación web',
#  'Operación 687 ejecutada en la base de datos',
#  'Operación 688 ejecutada en la aplicación web',
#  'Error de la base de datos en la operación 689',
#  'Operación 690 ejecutada en la aplicación web',
#  'Operación 691 ejecutada en la base de datos',
#  'Operación 692 ejecutada en la base de datos',
#  'Operación 693 ejecutada en la base de datos',
#  'Operación 694 ejecutada en la aplicación web',
#  'Operación 695 ejecutada en la aplicación web',
#  'Operación 696 ejecutada en la aplicación web',
#  'Operación 697 ejecutada en la aplicación web',
#  'Operación 698 ejecutada en la base de datos',
#  'Operación 699 ejecutada en la aplicación web',
#  'Operación 700 ejecutada en la base de datos',
#  'Operación 701 ejecutada en la aplicación web',
#  'Operación 702 ejecutada en la aplicación web',
#  'Error de la base de datos en la operación 703',
#  'Error de la base de datos en la operación 704',
#  'Operación 705 ejecutada en la base de datos',
#  'Operación 706 ejecutada en la aplicación web',
#  'Operación 707 ejecutada en la aplicación web',
#  'Operación 708 ejecutada en la aplicación web',
#  'Error de la base de datos en la operación 709',
#  'Error de la base de datos en la operación 710',
#  'Operación 711 ejecutada en la aplicación web',
#  'Operación 712 ejecutada en la base de datos',
#  'Operación 713 ejecutada en la aplicación web',
#  'Operación 714 ejecutada en la base de datos',
#  'Operación 715 ejecutada en la aplicación web',
#  'Operación 716 ejecutada en la aplicación web',
#  'Error de la aplicación web de tipo 500 en la operación 717',
#  'Operación 718 ejecutada en la base de datos',
#  'Error de la aplicación web de tipo 500 en la operación 719',
#  'Operación 720 ejecutada en la aplicación web',
#  'Operación 721 ejecutada en la base de datos',
#  'Error de la base de datos en la operación 722',
#  'Error de la base de datos en la operación 723',
#  'Operación 724 ejecutada en la aplicación web',
#  'Operación 725 ejecutada en la aplicación web',
#  'Operación 726 ejecutada en la base de datos',
#  'Operación 727 ejecutada en la base de datos',
#  'Operación 728 ejecutada en la aplicación web',
#  'Operación 729 ejecutada en la aplicación web',
#  'Operación 730 ejecutada en la base de datos',
#  'Operación 731 ejecutada en la base de datos',
#  'Operación 732 ejecutada en la aplicación web',
#  'Operación 733 ejecutada en la aplicación web',
#  'Error de la base de datos en la operación 734',
#  'Operación 735 ejecutada en la aplicación web',
#  'Error de la aplicación web de tipo 500 en la operación 736',
#  'Operación 737 ejecutada en la base de datos',
#  'Operación 738 ejecutada en la base de datos',
#  'Operación 739 ejecutada en la aplicación web',
#  'Operación 740 ejecutada en la aplicación web',
#  'Operación 741 ejecutada en la base de datos',
#  'Error de la aplicación web de tipo 500 en la operación 742',
#  'Operación 743 ejecutada en la base de datos',
#  'Operación 744 ejecutada en la aplicación web',
#  'Operación 745 ejecutada en la base de datos',
#  'Operación 746 ejecutada en la aplicación web',
#  'Operación 747 ejecutada en la aplicación web',
#  'Operación 748 ejecutada en la aplicación web',
#  'Operación 749 ejecutada en la base de datos',
#  'Error de la base de datos en la operación 750',
#  'Error de la aplicación web de tipo 500 en la operación 751',
#  'Operación 752 ejecutada en la base de datos',
#  'Operación 753 ejecutada en la aplicación web',
#  'Error de la base de datos en la operación 754',
#  'Operación 755 ejecutada en la base de datos',
#  'Operación 756 ejecutada en la aplicación web',
#  'Operación 757 ejecutada en la aplicación web',
#  'Operación 758 ejecutada en la aplicación web',
#  'Operación 759 ejecutada en la aplicación web',
#  'Error de la base de datos en la operación 760',
#  'Operación 761 ejecutada en la base de datos',
#  'Operación 762 ejecutada en la aplicación web',
#  'Operación 763 ejecutada en la aplicación web',
#  'Operación 764 ejecutada en la aplicación web',
#  'Operación 765 ejecutada en la aplicación web',
#  'Operación 766 ejecutada en la aplicación web',
#  'Operación 767 ejecutada en la aplicación web',
#  'Operación 768 ejecutada en la aplicación web',
#  'Error de la base de datos en la operación 769',
#  'Operación 770 ejecutada en la aplicación web',
#  'Error de la aplicación web de tipo 400 en la operación 771',
#  'Operación 772 ejecutada en la aplicación web',
#  'Operación 773 ejecutada en la aplicación web',
#  'Operación 774 ejecutada en la aplicación web',
#  'Operación 775 ejecutada en la aplicación web',
#  'Operación 776 ejecutada en la base de datos',
#  'Operación 777 ejecutada en la base de datos',
#  'Operación 778 ejecutada en la aplicación web',
#  'Error de la aplicación web de tipo 500 en la operación 779',
#  'Operación 780 ejecutada en la base de datos',
#  'Operación 781 ejecutada en la aplicación web',
#  'Error de la aplicación web de tipo 500 en la operación 782',
#  'Operación 783 ejecutada en la base de datos',
#  'Error de la base de datos en la operación 784',
#  'Operación 785 ejecutada en la base de datos',
#  'Operación 786 ejecutada en la aplicación web',
#  'Operación 787 ejecutada en la base de datos',
#  'Operación 788 ejecutada en la base de datos',
#  'Operación 789 ejecutada en la base de datos',
#  'Error de la base de datos en la operación 790',
#  'Operación 791 ejecutada en la aplicación web',
#  'Operación 792 ejecutada en la aplicación web',
#  'Operación 793 ejecutada en la aplicación web',
#  'Operación 794 ejecutada en la base de datos',
#  'Operación 795 ejecutada en la aplicación web',
#  'Operación 796 ejecutada en la aplicación web',
#  'Operación 797 ejecutada en la base de datos',
#  'Operación 798 ejecutada en la aplicación web',
#  'Operación 799 ejecutada en la aplicación web',
#  'Operación 800 ejecutada en la base de datos',
#  'Operación 801 ejecutada en la aplicación web',
#  'Operación 802 ejecutada en la base de datos',
#  'Operación 803 ejecutada en la base de datos',
#  'Operación 804 ejecutada en la base de datos',
#  'Error de la base de datos en la operación 805',
#  'Error de la aplicación web de tipo 400 en la operación 806',
#  'Error de la aplicación web de tipo 400 en la operación 807',
#  'Operación 808 ejecutada en la aplicación web',
#  'Operación 809 ejecutada en la base de datos',
#  'Error de la aplicación web de tipo 500 en la operación 810',
#  'Operación 811 ejecutada en la aplicación web',
#  'Error de la base de datos en la operación 812',
#  'Error de la aplicación web de tipo 500 en la operación 813',
#  'Operación 814 ejecutada en la aplicación web',
#  'Operación 815 ejecutada en la aplicación web',
#  'Operación 816 ejecutada en la aplicación web',
#  'Error de la aplicación web de tipo 500 en la operación 817',
#  'Operación 818 ejecutada en la base de datos',
#  'Operación 819 ejecutada en la aplicación web',
#  'Error de la base de datos en la operación 820',
#  'Operación 821 ejecutada en la aplicación web',
#  'Operación 822 ejecutada en la aplicación web',
#  'Operación 823 ejecutada en la aplicación web',
#  'Operación 824 ejecutada en la aplicación web',
#  'Error de la base de datos en la operación 825',
#  'Operación 826 ejecutada en la base de datos',
#  'Error de la base de datos en la operación 827',
#  'Operación 828 ejecutada en la aplicación web',
#  'Operación 829 ejecutada en la base de datos',
#  'Operación 830 ejecutada en la base de datos',
#  'Error de la base de datos en la operación 831',
#  'Error de la base de datos en la operación 832',
#  'Operación 833 ejecutada en la base de datos',
#  'Operación 834 ejecutada en la aplicación web',
#  'Error de la base de datos en la operación 835',
#  'Operación 836 ejecutada en la base de datos',
#  'Operación 837 ejecutada en la base de datos',
#  'Operación 838 ejecutada en la aplicación web',
#  'Error de la aplicación web de tipo 500 en la operación 839',
#  'Operación 840 ejecutada en la base de datos',
#  'Operación 841 ejecutada en la aplicación web',
#  'Operación 842 ejecutada en la aplicación web',
#  'Operación 843 ejecutada en la aplicación web',
#  'Operación 844 ejecutada en la base de datos',
#  'Error de la base de datos en la operación 845',
#  'Operación 846 ejecutada en la aplicación web',
#  'Operación 847 ejecutada en la base de datos',
#  'Operación 848 ejecutada en la aplicación web',
#  'Operación 849 ejecutada en la aplicación web',
#  'Operación 850 ejecutada en la aplicación web',
#  'Operación 851 ejecutada en la aplicación web',
#  'Operación 852 ejecutada en la aplicación web',
#  'Operación 853 ejecutada en la aplicación web',
#  'Operación 854 ejecutada en la aplicación web',
#  'Operación 855 ejecutada en la base de datos',
#  'Operación 856 ejecutada en la aplicación web',
#  'Operación 857 ejecutada en la aplicación web',
#  'Operación 858 ejecutada en la base de datos',
#  'Operación 859 ejecutada en la base de datos',
#  'Operación 860 ejecutada en la aplicación web',
#  'Operación 861 ejecutada en la aplicación web',
#  'Operación 862 ejecutada en la aplicación web',
#  'Error de la base de datos en la operación 863',
#  'Error de la base de datos en la operación 864',
#  'Error de la base de datos en la operación 865',
#  'Operación 866 ejecutada en la aplicación web',
#  'Error de la base de datos en la operación 867',
#  'Operación 868 ejecutada en la aplicación web',
#  'Operación 869 ejecutada en la base de datos',
#  'Operación 870 ejecutada en la base de datos',
#  'Operación 871 ejecutada en la aplicación web',
#  'Operación 872 ejecutada en la base de datos',
#  'Operación 873 ejecutada en la base de datos',
#  'Operación 874 ejecutada en la aplicación web',
#  'Operación 875 ejecutada en la aplicación web',
#  'Operación 876 ejecutada en la aplicación web',
#  'Operación 877 ejecutada en la aplicación web',
#  'Operación 878 ejecutada en la base de datos',
#  'Error de la aplicación web de tipo 400 en la operación 879',
#  'Operación 880 ejecutada en la aplicación web',
#  'Operación 881 ejecutada en la base de datos',
#  'Operación 882 ejecutada en la aplicación web',
#  'Operación 883 ejecutada en la aplicación web',
#  'Operación 884 ejecutada en la base de datos',
#  'Operación 885 ejecutada en la aplicación web',
#  'Operación 886 ejecutada en la base de datos',
#  'Operación 887 ejecutada en la base de datos',
#  'Error de la base de datos en la operación 888',
#  'Operación 889 ejecutada en la base de datos',
#  'Operación 890 ejecutada en la aplicación web',
#  'Operación 891 ejecutada en la aplicación web',
#  'Operación 892 ejecutada en la aplicación web',
#  'Operación 893 ejecutada en la aplicación web',
#  'Operación 894 ejecutada en la aplicación web',
#  'Operación 895 ejecutada en la aplicación web',
#  'Error de la base de datos en la operación 896',
#  'Operación 897 ejecutada en la base de datos',
#  'Operación 898 ejecutada en la aplicación web',
#  'Operación 899 ejecutada en la aplicación web',
#  'Operación 900 ejecutada en la aplicación web',
#  'Operación 901 ejecutada en la base de datos',
#  'Error de la base de datos en la operación 902',
#  'Error de la base de datos en la operación 903',
#  'Operación 904 ejecutada en la aplicación web',
#  'Operación 905 ejecutada en la aplicación web',
#  'Operación 906 ejecutada en la aplicación web',
#  'Operación 907 ejecutada en la aplicación web',
#  'Error de la aplicación web de tipo 400 en la operación 908',
#  'Error de la base de datos en la operación 909',
#  'Operación 910 ejecutada en la aplicación web',
#  'Error de la base de datos en la operación 911',
#  'Error de la base de datos en la operación 912',
#  'Operación 913 ejecutada en la base de datos',
#  'Operación 914 ejecutada en la aplicación web',
#  'Operación 915 ejecutada en la aplicación web',
#  'Operación 916 ejecutada en la aplicación web',
#  'Operación 917 ejecutada en la aplicación web',
#  'Operación 918 ejecutada en la base de datos',
#  'Operación 919 ejecutada en la base de datos',
#  'Operación 920 ejecutada en la base de datos',
#  'Operación 921 ejecutada en la base de datos',
#  'Operación 922 ejecutada en la aplicación web',
#  'Error de la base de datos en la operación 923',
#  'Operación 924 ejecutada en la aplicación web',
#  'Operación 925 ejecutada en la base de datos',
#  'Error de la base de datos en la operación 926',
#  'Error de la base de datos en la operación 927',
#  'Error de la aplicación web de tipo 500 en la operación 928',
#  'Operación 929 ejecutada en la base de datos',
#  'Operación 930 ejecutada en la base de datos',
#  'Error de la aplicación web de tipo 400 en la operación 931',
#  'Operación 932 ejecutada en la base de datos',
#  'Error de la aplicación web de tipo 400 en la operación 933',
#  'Error de la aplicación web de tipo 400 en la operación 934',
#  'Error de la base de datos en la operación 935',
#  'Operación 936 ejecutada en la aplicación web',
#  'Operación 937 ejecutada en la aplicación web',
#  'Operación 938 ejecutada en la base de datos',
#  'Operación 939 ejecutada en la aplicación web',
#  'Error de la base de datos en la operación 940',
#  'Operación 941 ejecutada en la aplicación web',
#  'Error de la base de datos en la operación 942',
#  'Operación 943 ejecutada en la base de datos',
#  'Operación 944 ejecutada en la base de datos',
#  'Operación 945 ejecutada en la base de datos',
#  'Operación 946 ejecutada en la base de datos',
#  'Error de la base de datos en la operación 947',
#  'Operación 948 ejecutada en la aplicación web',
#  'Error de la base de datos en la operación 949',
#  'Operación 950 ejecutada en la base de datos',
#  'Error de la base de datos en la operación 951',
#  'Operación 952 ejecutada en la aplicación web',
#  'Operación 953 ejecutada en la aplicación web',
#  'Operación 954 ejecutada en la aplicación web',
#  'Error de la aplicación web de tipo 500 en la operación 955',
#  'Operación 956 ejecutada en la aplicación web',
#  'Operación 957 ejecutada en la base de datos',
#  'Operación 958 ejecutada en la aplicación web',
#  'Operación 959 ejecutada en la aplicación web',
#  'Operación 960 ejecutada en la base de datos',
#  'Operación 961 ejecutada en la aplicación web',
#  'Operación 962 ejecutada en la aplicación web',
#  'Operación 963 ejecutada en la base de datos',
#  'Operación 964 ejecutada en la aplicación web',
#  'Operación 965 ejecutada en la aplicación web',
#  'Operación 966 ejecutada en la aplicación web',
#  'Operación 967 ejecutada en la base de datos',
#  'Operación 968 ejecutada en la base de datos',
#  'Operación 969 ejecutada en la aplicación web',
#  'Operación 970 ejecutada en la aplicación web',
#  'Error de la aplicación web de tipo 400 en la operación 971',
#  'Error de la base de datos en la operación 972',
#  'Error de la aplicación web de tipo 500 en la operación 973',
#  'Operación 974 ejecutada en la aplicación web',
#  'Operación 975 ejecutada en la aplicación web',
#  'Operación 976 ejecutada en la base de datos',
#  'Operación 977 ejecutada en la aplicación web',
#  'Operación 978 ejecutada en la base de datos',
#  'Operación 979 ejecutada en la aplicación web',
#  'Operación 980 ejecutada en la aplicación web',
#  'Operación 981 ejecutada en la aplicación web',
#  'Operación 982 ejecutada en la aplicación web',
#  'Error de la base de datos en la operación 983',
#  'Operación 984 ejecutada en la base de datos',
#  'Operación 985 ejecutada en la aplicación web',
#  'Operación 986 ejecutada en la aplicación web',
#  'Operación 987 ejecutada en la aplicación web',
#  'Error de la base de datos en la operación 988',
#  'Operación 989 ejecutada en la base de datos',
#  'Error de la aplicación web de tipo 500 en la operación 990',
#  'Operación 991 ejecutada en la base de datos',
#  'Operación 992 ejecutada en la aplicación web',
#  'Operación 993 ejecutada en la base de datos',
#  'Operación 994 ejecutada en la aplicación web',
#  'Operación 995 ejecutada en la aplicación web',
#  'Operación 996 ejecutada en la aplicación web',
#  'Operación 997 ejecutada en la base de datos',
#  'Operación 998 ejecutada en la aplicación web',
#  'Operación 999 ejecutada en la aplicación web']

# %%
logs_filter = text_file.filter(lambda line: "Error" in line)
logs_filter.collect()
# Out:
# Out[6]: ['Error de la base de datos en la operación 10',
#  'Error de la aplicación web de tipo 500 en la operación 14',
#  'Error de la base de datos en la operación 15',
#  'Error de la aplicación web de tipo 500 en la operación 17',
#  'Error de la aplicación web de tipo 400 en la operación 27',
#  'Error de la aplicación web de tipo 500 en la operación 28',
#  'Error de la base de datos en la operación 31',
#  'Error de la aplicación web de tipo 400 en la operación 35',
#  'Error de la base de datos en la operación 37',
#  'Error de la aplicación web de tipo 400 en la operación 39',
#  'Error de la aplicación web de tipo 500 en la operación 40',
#  'Error de la base de datos en la operación 41',
#  'Error de la base de datos en la operación 42',
#  'Error de la aplicación web de tipo 500 en la operación 43',
#  'Error de la base de datos en la operación 45',
#  'Error de la base de datos en la operación 46',
#  'Error de la base de datos en la operación 49',
#  'Error de la base de datos en la operación 50',
#  'Error de la base de datos en la operación 53',
#  'Error de la base de datos en la operación 56',
#  'Error de la aplicación web de tipo 400 en la operación 60',
#  'Error de la base de datos en la operación 62',
#  'Error de la aplicación web de tipo 400 en la operación 65',
#  'Error de la aplicación web de tipo 400 en la operación 67',
#  'Error de la base de datos en la operación 68',
#  'Error de la aplicación web de tipo 500 en la operación 70',
#  'Error de la aplicación web de tipo 500 en la operación 78',
#  'Error de la base de datos en la operación 83',
#  'Error de la base de datos en la operación 86',
#  'Error de la base de datos en la operación 91',
#  'Error de la base de datos en la operación 101',
#  'Error de la aplicación web de tipo 500 en la operación 102',
#  'Error de la base de datos en la operación 109',
#  'Error de la aplicación web de tipo 400 en la operación 115',
#  'Error de la aplicación web de tipo 400 en la operación 118',
#  'Error de la base de datos en la operación 126',
#  'Error de la aplicación web de tipo 500 en la operación 133',
#  'Error de la aplicación web de tipo 400 en la operación 140',
#  'Error de la base de datos en la operación 143',
#  'Error de la aplicación web de tipo 500 en la operación 159',
#  'Error de la aplicación web de tipo 400 en la operación 165',
#  'Error de la aplicación web de tipo 500 en la operación 166',
#  'Error de la base de datos en la operación 185',
#  'Error de la base de datos en la operación 188',
#  'Error de la base de datos en la operación 195',
#  'Error de la base de datos en la operación 210',
#  'Error de la base de datos en la operación 219',
#  'Error de la base de datos en la operación 222',
#  'Error de la aplicación web de tipo 500 en la operación 227',
#  'Error de la base de datos en la operación 228',
#  'Error de la aplicación web de tipo 400 en la operación 238',
#  'Error de la aplicación web de tipo 500 en la operación 239',
#  'Error de la base de datos en la operación 241',
#  'Error de la base de datos en la operación 243',
#  'Error de la base de datos en la operación 246',
#  'Error de la base de datos en la operación 247',
#  'Error de la base de datos en la operación 253',
#  'Error de la aplicación web de tipo 400 en la operación 261',
#  'Error de la aplicación web de tipo 500 en la operación 267',
#  'Error de la aplicación web de tipo 500 en la operación 268',
#  'Error de la aplicación web de tipo 400 en la operación 276',
#  'Error de la base de datos en la operación 280',
#  'Error de la aplicación web de tipo 400 en la operación 282',
#  'Error de la base de datos en la operación 287',
#  'Error de la base de datos en la operación 290',
#  'Error de la aplicación web de tipo 500 en la operación 292',
#  'Error de la aplicación web de tipo 500 en la operación 297',
#  'Error de la aplicación web de tipo 500 en la operación 301',
#  'Error de la aplicación web de tipo 500 en la operación 302',
#  'Error de la base de datos en la operación 307',
#  'Error de la aplicación web de tipo 400 en la operación 308',
#  'Error de la aplicación web de tipo 500 en la operación 313',
#  'Error de la base de datos en la operación 315',
#  'Error de la base de datos en la operación 322',
#  'Error de la aplicación web de tipo 400 en la operación 324',
#  'Error de la base de datos en la operación 338',
#  'Error de la base de datos en la operación 339',
#  'Error de la base de datos en la operación 340',
#  'Error de la base de datos en la operación 341',
#  'Error de la base de datos en la operación 345',
#  'Error de la base de datos en la operación 347',
#  'Error de la base de datos en la operación 349',
#  'Error de la base de datos en la operación 350',
#  'Error de la base de datos en la operación 354',
#  'Error de la base de datos en la operación 358',
#  'Error de la base de datos en la operación 360',
#  'Error de la base de datos en la operación 364',
#  'Error de la base de datos en la operación 368',
#  'Error de la aplicación web de tipo 500 en la operación 369',
#  'Error de la aplicación web de tipo 500 en la operación 374',
#  'Error de la base de datos en la operación 378',
#  'Error de la aplicación web de tipo 400 en la operación 380',
#  'Error de la aplicación web de tipo 400 en la operación 405',
#  'Error de la base de datos en la operación 406',
#  'Error de la base de datos en la operación 411',
#  'Error de la base de datos en la operación 422',
#  'Error de la base de datos en la operación 428',
#  'Error de la base de datos en la operación 429',
#  'Error de la aplicación web de tipo 500 en la operación 442',
#  'Error de la aplicación web de tipo 500 en la operación 445',
#  'Error de la aplicación web de tipo 500 en la operación 449',
#  'Error de la base de datos en la operación 452',
#  'Error de la base de datos en la operación 458',
#  'Error de la base de datos en la operación 465',
#  'Error de la base de datos en la operación 471',
#  'Error de la base de datos en la operación 474',
#  'Error de la base de datos en la operación 476',
#  'Error de la aplicación web de tipo 400 en la operación 484',
#  'Error de la base de datos en la operación 485',
#  'Error de la aplicación web de tipo 400 en la operación 488',
#  'Error de la base de datos en la operación 496',
#  'Error de la aplicación web de tipo 400 en la operación 504',
#  'Error de la base de datos en la operación 505',
#  'Error de la base de datos en la operación 506',
#  'Error de la aplicación web de tipo 500 en la operación 507',
#  'Error de la aplicación web de tipo 500 en la operación 511',
#  'Error de la aplicación web de tipo 500 en la operación 512',
#  'Error de la aplicación web de tipo 500 en la operación 513',
#  'Error de la aplicación web de tipo 500 en la operación 516',
#  'Error de la base de datos en la operación 523',
#  'Error de la aplicación web de tipo 500 en la operación 526',
#  'Error de la base de datos en la operación 527',
#  'Error de la base de datos en la operación 542',
#  'Error de la aplicación web de tipo 500 en la operación 554',
#  'Error de la aplicación web de tipo 400 en la operación 561',
#  'Error de la aplicación web de tipo 400 en la operación 565',
#  'Error de la base de datos en la operación 571',
#  'Error de la base de datos en la operación 578',
#  'Error de la base de datos en la operación 590',
#  'Error de la aplicación web de tipo 400 en la operación 593',
#  'Error de la aplicación web de tipo 400 en la operación 610',
#  'Error de la base de datos en la operación 613',
#  'Error de la aplicación web de tipo 500 en la operación 615',
#  'Error de la base de datos en la operación 624',
#  'Error de la base de datos en la operación 627',
#  'Error de la aplicación web de tipo 500 en la operación 629',
#  'Error de la base de datos en la operación 632',
#  'Error de la base de datos en la operación 639',
#  'Error de la aplicación web de tipo 400 en la operación 651',
#  'Error de la aplicación web de tipo 400 en la operación 656',
#  'Error de la base de datos en la operación 660',
#  'Error de la base de datos en la operación 662',
#  'Error de la base de datos en la operación 664',
#  'Error de la aplicación web de tipo 400 en la operación 666',
#  'Error de la base de datos en la operación 667',
#  'Error de la base de datos en la operación 678',
#  'Error de la base de datos en la operación 682',
#  'Error de la base de datos en la operación 684',
#  'Error de la base de datos en la operación 689',
#  'Error de la base de datos en la operación 703',
#  'Error de la base de datos en la operación 704',
#  'Error de la base de datos en la operación 709',
#  'Error de la base de datos en la operación 710',
#  'Error de la aplicación web de tipo 500 en la operación 717',
#  'Error de la aplicación web de tipo 500 en la operación 719',
#  'Error de la base de datos en la operación 722',
#  'Error de la base de datos en la operación 723',
#  'Error de la base de datos en la operación 734',
#  'Error de la aplicación web de tipo 500 en la operación 736',
#  'Error de la aplicación web de tipo 500 en la operación 742',
#  'Error de la base de datos en la operación 750',
#  'Error de la aplicación web de tipo 500 en la operación 751',
#  'Error de la base de datos en la operación 754',
#  'Error de la base de datos en la operación 760',
#  'Error de la base de datos en la operación 769',
#  'Error de la aplicación web de tipo 400 en la operación 771',
#  'Error de la aplicación web de tipo 500 en la operación 779',
#  'Error de la aplicación web de tipo 500 en la operación 782',
#  'Error de la base de datos en la operación 784',
#  'Error de la base de datos en la operación 790',
#  'Error de la base de datos en la operación 805',
#  'Error de la aplicación web de tipo 400 en la operación 806',
#  'Error de la aplicación web de tipo 400 en la operación 807',
#  'Error de la aplicación web de tipo 500 en la operación 810',
#  'Error de la base de datos en la operación 812',
#  'Error de la aplicación web de tipo 500 en la operación 813',
#  'Error de la aplicación web de tipo 500 en la operación 817',
#  'Error de la base de datos en la operación 820',
#  'Error de la base de datos en la operación 825',
#  'Error de la base de datos en la operación 827',
#  'Error de la base de datos en la operación 831',
#  'Error de la base de datos en la operación 832',
#  'Error de la base de datos en la operación 835',
#  'Error de la aplicación web de tipo 500 en la operación 839',
#  'Error de la base de datos en la operación 845',
#  'Error de la base de datos en la operación 863',
#  'Error de la base de datos en la operación 864',
#  'Error de la base de datos en la operación 865',
#  'Error de la base de datos en la operación 867',
#  'Error de la aplicación web de tipo 400 en la operación 879',
#  'Error de la base de datos en la operación 888',
#  'Error de la base de datos en la operación 896',
#  'Error de la base de datos en la operación 902',
#  'Error de la base de datos en la operación 903',
#  'Error de la aplicación web de tipo 400 en la operación 908',
#  'Error de la base de datos en la operación 909',
#  'Error de la base de datos en la operación 911',
#  'Error de la base de datos en la operación 912',
#  'Error de la base de datos en la operación 923',
#  'Error de la base de datos en la operación 926',
#  'Error de la base de datos en la operación 927',
#  'Error de la aplicación web de tipo 500 en la operación 928',
#  'Error de la aplicación web de tipo 400 en la operación 931',
#  'Error de la aplicación web de tipo 400 en la operación 933',
#  'Error de la aplicación web de tipo 400 en la operación 934',
#  'Error de la base de datos en la operación 935',
#  'Error de la base de datos en la operación 940',
#  'Error de la base de datos en la operación 942',
#  'Error de la base de datos en la operación 947',
#  'Error de la base de datos en la operación 949',
#  'Error de la base de datos en la operación 951',
#  'Error de la aplicación web de tipo 500 en la operación 955',
#  'Error de la aplicación web de tipo 400 en la operación 971',
#  'Error de la base de datos en la operación 972',
#  'Error de la aplicación web de tipo 500 en la operación 973',
#  'Error de la base de datos en la operación 983',
#  'Error de la base de datos en la operación 988',
#  'Error de la aplicación web de tipo 500 en la operación 990']

# %%
t1 = sc.parallelize([("a", 1), ("b", 4)])
t2 = sc.parallelize([("a", 2), ("a", 3)])

t1.join(t2).collect()
# Out:
# Out[9]: [('a', (1, 2)), ('a', (1, 3))]
