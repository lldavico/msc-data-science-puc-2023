# %% [markdown]
# # <img style="float: left; padding-right: 20px; width: 100px" src="https://upload.wikimedia.org/wikipedia/commons/thumb/8/84/Escudo_de_la_Pontificia_Universidad_Cat%C3%B3lica_de_Chile.svg/1920px-Escudo_de_la_Pontificia_Universidad_Cat%C3%B3lica_de_Chile.svg.png"> MCD3020 - Introducción a Ciencia de Datos
# **Pontificia Universidad Católica de Chile**<br>
# **Profesora:** Paula Aguirre <br>
#
# ----

# %% [markdown]
#  <h1><center>Ejemplos Complementarios: Extracción de Datos desde la Web </center></h1>
#
#
# ## Objetivos de Aprendizaje.
#
# Esta Tarea tiene como objetivo poner en práctica los contenidos del curso vistos hasta ahora, en especial:
# - Manejo de librerías `pandas`,`matplotlib`, `requests` y `BeautifulSoup`.
# - Manejo de datos estructurado y semi-estructurados.
# - Análisis y comprensión de los elementos fundamentales de APIs y códigos HTML de páginas web.
# - Extracción de datos de la via API y scrapping sencillo.
#
# ---------

# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Ejemplo 1: API Open Notify ¿Cuántas personas hay en el espacio hoy?
#
# La API Open Notify entrega información actualizada de la ubicación de la Estación Espacial Internacional (ISS), y de las personas que están en el espacio.
#
# http://open-notify.org/Open-Notify-API/People-In-Space/
#
# Esta es una API sencilla, que no tiene argumentos. Por lo tanto, la consulta que se le envía es siempre la misma.

# %%
url='http://api.open-notify.org/astros.json'
r=requests.get(url)
r.json()
# Out:
# {'message': 'success',
#  'number': 13,
#  'people': [{'craft': 'ISS', 'name': 'Sergey Prokopyev'},
#   {'craft': 'ISS', 'name': 'Dmitry Petelin'},
#   {'craft': 'ISS', 'name': 'Frank Rubio'},
#   {'craft': 'Tiangong', 'name': 'Fei Junlong'},
#   {'craft': 'Tiangong', 'name': 'Deng Qingming'},
#   {'craft': 'Tiangong', 'name': 'Zhang Lu'},
#   {'craft': 'ISS', 'name': 'Stephen Bowen'},
#   {'craft': 'ISS', 'name': 'Warren Hoburg'},
#   {'craft': 'ISS', 'name': 'Sultan Alneyadi'},
#   {'craft': 'ISS', 'name': 'Andrey Fedyaev'},
#   {'craft': 'Tiangong', 'name': 'Jing Haiping'},
#   {'craft': 'Tiangong', 'name': 'Gui Haichow'},
#   {'craft': 'Tiangong', 'name': 'Zhu Yangzhu'}]}

# %%
df=pd.json_normalize(r.json(),record_path='people')
df
# Out:
#        craft              name
# 0        ISS  Sergey Prokopyev
# 1        ISS    Dmitry Petelin
# 2        ISS       Frank Rubio
# 3   Tiangong       Fei Junlong
# 4   Tiangong     Deng Qingming
# 5   Tiangong          Zhang Lu
# 6        ISS     Stephen Bowen
# 7        ISS     Warren Hoburg
# 8        ISS   Sultan Alneyadi
# 9        ISS    Andrey Fedyaev
# 10  Tiangong      Jing Haiping
# 11  Tiangong       Gui Haichow
# 12  Tiangong       Zhu Yangzhu

# %%
#¿Dónde está la ISS ahora?
url='http://api.open-notify.org/iss-now.json'
r=requests.get(url)
print(r.json())
# Out:
# {'iss_position': {'latitude': '11.8799', 'longitude': '149.9402'}, 'message': 'success', 'timestamp': 1686007118}

# %%
url='http://api.open-notify.org/iss-now.json'
r=requests.get(url)
print(r.json())
# Out:
# {'iss_position': {'latitude': '13.0060', 'longitude': '150.7946'}, 'message': 'success', 'timestamp': 1686007140}

# %% [markdown]
# ## Ejemplo 2: Reporte de indicadores económicos de Chile.
#
# La API **MindicadorChile** es un servicio open source (web service) que entrega los principales indicadores económicos para Chile en formato JSON. Tanto los indicadores diarios como históricos para que desarrolladores puedan utilizarlos en sus aplicaciones o sitios web.
#
# La aplicación mapea constantemente el sitio del Banco Central de Chile manteniendo así nuestra base de datos actualizada con los últimos valores del día. Toda la documentación de la API está disponible en la dirección https://mindicador.cl/.
#
# En este ejercicio, ud. deberá utilizar la API para compilar datos para un análisis de la evolución de la economía chilena en los años 2019, 2020 y 2021, de manera de evaluar el impacto del estallido social y la pandemia.
#
# **Revise cuisadosamente la página y documentación de la API**, y luego desarrolle los siguientes problemas:
#
# **1.1.** Use la API para obtener los valores de siguientes indicadores entre el 1 de enero de 2019, y el 30 de septiembre de 2021: Dólar observado, tasa de desempleo, libra de cobre, índice de precios al consumidor.

# %%
url='https://mindicador.cl/api/{tipo_indicador}/{yyyy}'

indicadores=['dolar','libra_cobre','tasa_desempleo','ipc']

years=[2019,2020,2021]

for year in years:
    for ind in indicadores:
        
        resp = requests.get(url.format(tipo_indicador=ind, yyyy=year))
        print(resp.json())
        print()
# Out:
# {'version': '1.7.0', 'autor': 'mindicador.cl', 'codigo': 'dolar', 'nombre': 'Dólar observado', 'unidad_medida': 'Pesos', 'serie': [{'fecha': '2019-12-30T03:00:00.000Z', 'valor': 744.62}, {'fecha': '2019-12-27T03:00:00.000Z', 'valor': 746.66}, {'fecha': '2019-12-26T03:00:00.000Z', 'valor': 751.04}, {'fecha': '2019-12-24T03:00:00.000Z', 'valor': 754.27}, {'fecha': '2019-12-23T03:00:00.000Z', 'valor': 749.83}, {'fecha': '2019-12-20T03:00:00.000Z', 'valor': 752.6}, {'fecha': '2019-12-19T03:00:00.000Z', 'valor': 752.3}, {'fecha': '2019-12-18T03:00:00.000Z', 'valor': 756.95}, {'fecha': '2019-12-17T03:00:00.000Z', 'valor': 762.83}, {'fecha': '2019-12-16T03:00:00.000Z', 'valor': 766.76}, {'fecha': '2019-12-13T03:00:00.000Z', 'valor': 768.69}, {'fecha': '2019-12-12T03:00:00.000Z', 'valor': 772.93}, {'fecha': '2019-12-11T03:00:00.000Z', 'valor': 778.14}, {'fecha': '2019-12-10T03:00:00.000Z', 'valor': 771.29}, {'fecha': '2019-12-09T03:00:00.000Z', 'valor': 779.04}, {'fecha': '2019-12-06T03:00:00.000Z', 'valor': 784.25}, {'fecha': '2019-12-05T03:00:00.000Z', 'valor': 796.75}, {'fecha': '2019-12-04T03:00:00.000Z', 'valor': 802.44}, {'fecha': '2019-12-03T03:00:00.000Z', 'valor': 804.29}, {'fecha': '2019-12-02T03:00:00.000Z', 'valor': 812.13}, {'fecha': '2019-11-29T03:00:00.000Z', 'valor': 828.25}, {'fecha': '2019-11-28T03:00:00.000Z', 'valor': 806.3}
#
# {'version': '1.7.0', 'autor': 'mindicador.cl', 'codigo': 'ipc', 'nombre': 'Indice de Precios al Consumidor (IPC)', 'unidad_medida': 'Porcentaje', 'serie': [{'fecha': '2021-12-01T03:00:00.000Z', 'valor': 0.8}, {'fecha': '2021-11-01T03:00:00.000Z', 'valor': 0.5}, {'fecha': '2021-10-01T03:00:00.000Z', 'valor': 1.3}, {'fecha': '2021-09-01T04:00:00.000Z', 'valor': 1.2}, {'fecha': '2021-08-01T04:00:00.000Z', 'valor': 0.4}, {'fecha': '2021-07-01T04:00:00.000Z', 'valor': 0.8}, {'fecha': '2021-06-01T04:00:00.000Z', 'valor': 0.1}, {'fecha': '2021-05-01T04:00:00.000Z', 'valor': 0.3}, {'fecha': '2021-04-01T03:00:00.000Z', 'valor': 0.4}, {'fecha': '2021-03-01T03:00:00.000Z', 'valor': 0.4}, {'fecha': '2021-02-01T03:00:00.000Z', 'valor': 0.2}, {'fecha': '2021-01-01T03:00:00.000Z', 'valor': 0.7}]}

# %% [markdown]
# **1.2.** Para cada indicador, genere un único DataFrame que contenga las siguientes columnas: fecha, valor. El DataFrame debe incluir todos los reportes disponibles para dicho indicador en el rango de fechas indicado, y las fechas deben estar en orden cronológico. Para ello, le pueden ser de utilidad las siguientes funciones de pandas: pd.to_datetime(),DataFrame.sort_values().

# %%
frames={}
for ind in indicadores:
    df=pd.DataFrame(columns=['fecha','valor'])
    for year in years:
        url='https://mindicador.cl/api/%s/%s'%(ind,year)
        print(url)
        r=requests.get(url)
        df=df.append(pd.json_normalize(r.json(),record_path='serie'))
    frames[ind]=df
# Out:
# https://mindicador.cl/api/dolar/2019
# https://mindicador.cl/api/dolar/2020
# https://mindicador.cl/api/dolar/2021
# https://mindicador.cl/api/libra_cobre/2019
# https://mindicador.cl/api/libra_cobre/2020
# https://mindicador.cl/api/libra_cobre/2021
# https://mindicador.cl/api/tasa_desempleo/2019
# https://mindicador.cl/api/tasa_desempleo/2020
# https://mindicador.cl/api/tasa_desempleo/2021
# https://mindicador.cl/api/ipc/2019
# https://mindicador.cl/api/ipc/2020
# https://mindicador.cl/api/ipc/2021

# %% [markdown]
# **1.3.** Genere una figura con cuatro paneles o subplots. En cada uno de ellos, grafique la serie de tiempo de los indicadores analizados, siguiendo las reglas básicas de formato de gráficos (ejes, títulos, etiquetas, etc.). A continuación se muestra un ejemplo de la figura a generar:

# %% [markdown]
# <div>
# <img src="attachment:image.png" width="500"/>
# </div>

# %%
frames['ipc']
# Out:
#                        fecha  valor
# 0   2019-12-01T03:00:00.000Z    0.1
# 1   2019-11-01T03:00:00.000Z    0.1
# 2   2019-10-01T03:00:00.000Z    0.8
# 3   2019-09-01T04:00:00.000Z    0.0
# 4   2019-08-01T04:00:00.000Z    0.2
# 5   2019-07-01T04:00:00.000Z    0.2
# 6   2019-06-01T04:00:00.000Z    0.0
# 7   2019-05-01T04:00:00.000Z    0.6
# 8   2019-04-01T03:00:00.000Z    0.3
# 9   2019-03-01T03:00:00.000Z    0.5
# 10  2019-02-01T03:00:00.000Z    0.0
# 11  2019-01-01T03:00:00.000Z    0.1
# 0   2020-12-01T03:00:00.000Z    0.3
# 1   2020-11-01T03:00:00.000Z   -0.1
# 2   2020-10-01T03:00:00.000Z    0.7
# 3   2020-09-01T04:00:00.000Z    0.6
# 4   2020-08-01T04:00:00.000Z    0.1
# 5   2020-07-01T04:00:00.000Z    0.1
# 6   2020-06-01T04:00:00.000Z   -0.1
# 7   2020-05-01T04:00:00.000Z   -0.1
# 8   2020-04-01T03:00:00.000Z    0.0
# 9   2020-03-01T03:00:00.000Z    0.3
# 10  2020-02-01T03:00:00.000Z    0.4
# 11  2020-01-01T03:00:00.000Z    0.6
# 0   2021-12-01T03:00:00.000Z    0.8
# 1   2021-11-01T03:00:00.000Z    0.5
# 2   2021-10-01T03:00:00.000Z    1.3
# 3   2021-09-01T04:00:00.000Z    1.2
# 4   2021-08-01T04:00:00.000Z    0.4
# 5   2021-07-01T04:00:00.000Z    0.8
# 6   2021-06-01T04:00:00.000Z    0.1
# 7   2021-05-01T04:00:00.000Z    0.3
# 8   2021-04-01T03:00:00.000Z    0.4
# 9   2021-03-01T03:00:00.000Z    0.4
# 10  2021-02-01T03:00:00.000Z    0.2
# 11  2021-01-01T03:00:00.000Z    0.7

# %%
fig=plt.figure(figsize=(12,12))

for n,ind in enumerate(indicadores):
    print(ind)

    ax=fig.add_subplot(2,2,n+1)
    df=frames[ind]
    df['fecha']=pd.to_datetime(df['fecha'])
    df=df.sort_values(by='fecha')
    fecha=df['fecha']
    valor=df['valor']
    ax.plot(fecha,valor,'.-')
    ax.set_ylabel(ind.title(),fontsize=12)
    ax.set_xlabel('Fecha',fontsize=12)
    #ax.set_xlim(frames['dolar'].fecha.min(),frames['dolar'].fecha.max())
    plt.xticks(rotation=45)
fig.suptitle('Indicadores económicos en Chile, 2019-2021',fontsize=14);
# Out:
# dolar
# libra_cobre
# tasa_desempleo
# ipc

# %% [markdown]
# ## Ejemplo 3: Terremotos alrededor del mundo (USGS)
#
# El Servicio Geológico de los Estados Unidos o USGS por sus siglas en inglés (United States Geological Survey), es una agencia científica del gobierno federal de los Estados Unidos, dedicada al estudio del medio ambiente y ecosistemas, recursos naturales, amenazas del cambio climático y peligros naturales que pueden afectar a las personas.
#
# El USGS es una institución líder a nivel mundial en sismología, y a través del programa *Earthquake Hazards* (https://earthquake.usgs.gov/) se ocupa de monitorear y reportar eventos sísmicos, evaluar la amenaza e impacto de terremotos, e investigar sobre sus causas y efectos. Dentro de sus múltiples herramientas y plataformas de información, cuenta con una API que entrega información en tiempo real de los sismos registrados alrededor del mundo:
#
# https://earthquake.usgs.gov/fdsnws/event/1/?ref=springboard
#
# En este ejericio, ud. extraerá data del USGS para analizar y visualizar la ocurrencia de terremotos de gran magnitud alrededor del mundo en las últimas dos décadas.
#
# **2.1.** Usando la API del USGS, obtenga el listado de sismos de **magnitud mayor a 7** ocurridos en todo el mundo, desde el 1 de enero de 2000 a la fecha. Puede elegir el formato de respuesta de su preferencia. Consdiere que el formato GeoJSON es similar a JSON, sólo que en uno de sus campos incluye información de coordenadas geográficas.

# %%
url='https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=2000-01-01&endtime=2021-09-02&minmagnitude=7.0'

r=requests.get(url)

dat=r.json()
dat
# Out:
# {'type': 'FeatureCollection',
#  'metadata': {'generated': 1665719472000,
#   'url': 'https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=2000-01-01&endtime=2021-09-02&minmagnitude=7.0',
#   'title': 'USGS Earthquakes',
#   'status': 200,
#   'api': '1.13.6',
#   'count': 326},
#  'features': [{'type': 'Feature',
#    'properties': {'mag': 7.1,
#     'place': 'South Sandwich Islands region',
#     'time': 1629667998983,
#     'updated': 1635864870040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000f9sq',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000f9sq&format=geojson',
#     'felt': 2,
#     'cdi': 1,
#     'mmi': 3.787,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 1,
#     'sig': 776,
#     'net': 'us',
#     'code': '6000f9sq',
#     'ids': ',us6000f9sq,pt21234002,at00qy9fvn,usauto6000f9sq,',
#     'sources': ',us,pt,at,usauto,',
#     'types': ',dyfi,finite-fault,general-text,impact-link,internal-moment-tensor,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 9.799,
#     'rms': 0.39,
#     'gap': 32,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 7.1 - South Sandwich Islands region'},
#    'geometry': {'type': 'Point', 'coordinates': [-24.8743, -60.2845, 6]},
#    'id': 'us6000f9sq'},
#   {'type': 'Feature',
#    'properties': {'mag': 7.2,
#     'place': 'Nippes, Haiti',
#     'time': 1628944148454,
#     'updated': 1660684484534,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000f65h',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000f65h&format=geojson',
#     'felt': 363,
#     'cdi': 9.1,
#     'mmi': 8.425,
#     'alert': 'red',
#     'status': 'reviewed',
#     'tsunami': 1,
#     'sig': 2330,
#     'net': 'us',
#     'code': '6000f65h',
#     'ids': ',at00qxtxcn,pt21226002,us6000f65h,usauto6000f65h,',
#     'sources': ',at,pt,us,usauto,',
#     'types': ',dyfi,earthquake-name,finite-fault,general-text,ground-failure,impact-link,impact-text,internal-moment-tensor,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 1.178,
#     'rms': 0.75,
#     'gap': 23,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 7.2 - Nippes, Haiti'},
#    'geometry': {'type': 'Point', 'coordinates': [-73.4822, 18.4335, 10]},
#    'id': 'us6000f65h'},
#   {'type': 'Feature',
#    'properties': {'mag': 8.1,
#     'place': 'South Sandwich Islands region',
#     'time': 1628793317231,
#     'updated': 1652976332997,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000f53e',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000f53e&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': 6.543,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 1009,
#     'net': 'us',
#     'code': '6000f53e',
#     'ids': ',us6000f53e,',
#     'sources': ',us,',
#     'types': ',general-header,general-text,losspager,moment-tensor,origin,phase-data,shakemap,trump-moment-tensor,',
#     'nst': None,
#     'dmin': 7.463,
#     'rms': 0.76,
#     'gap': 78,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 8.1 - South Sandwich Islands region'},
#    'geometry': {'type': 'Point', 'coordinates': [-25.2637, -58.3753, 22.79]},
#    'id': 'us6000f53e'},
#   {'type': 'Feature',
#    'properties': {'mag': 7.5,
#     'place': 'South Sandwich Islands region',
#     'time': 1628793172464,
#     'updated': 1635003979040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000f4ly',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000f4ly&format=geojson',
#     'felt': 3,
#     'cdi': 8.6,
#     'mmi': 5.922,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 1,
#     'sig': 868,
#     'net': 'us',
#     'code': '6000f4ly',
#     'ids': ',us6000f4ly,at00qxqoup,pt21224001,usauto6000f4ly,',
#     'sources': ',us,at,pt,usauto,',
#     'types': ',dyfi,general-header,general-text,ground-failure,impact-link,internal-moment-tensor,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 7.227,
#     'rms': 1.16,
#     'gap': 38,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 7.5 - South Sandwich Islands region'},
#    'geometry': {'type': 'Point', 'coordinates': [-25.0316, -57.5674, 47.23]},
#    'id': 'us6000f4ly'},
#   {'type': 'Feature',
#    'properties': {'mag': 7.1,
#     'place': '60 km ENE of Pondaguitan, Philippines',
#     'time': 1628703973143,
#     'updated': 1638599092059,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000f48v',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000f48v&format=geojson',
#     'felt': 77,
#     'cdi': 9.1,
#     'mmi': 6.777,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 1,
#     'sig': 846,
#     'net': 'us',
#     'code': '6000f48v',
#     'ids': ',at00qxos14,us6000f48v,pt21223000,usauto6000f48v,',
#     'sources': ',at,us,pt,usauto,',
#     'types': ',dyfi,finite-fault,general-text,ground-failure,impact-link,impact-text,internal-moment-tensor,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 1.273,
#     'rms': 1.27,
#     'gap': 25,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 7.1 - 60 km ENE of Pondaguitan, Philippines'},
#    'geometry': {'type': 'Point', 'coordinates': [126.7151, 6.4748, 55.14]},
#    'id': 'us6000f48v'},
#   {'type': 'Feature',
#    'properties': {'mag': 8.2,
#     'place': '99 km SE of Perryville, Alaska',
#     'time': 1627539349188,
#     'updated': 1659075952812,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0219neiszm',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak0219neiszm&format=geojson',
#     'felt': 268,
#     'cdi': 8.1,
#     'mmi': 7.355,
#     'alert': 'yellow',
#     'status': 'reviewed',
#     'tsunami': 1,
#     'sig': 1252,
#     'net': 'ak',
#     'code': '0219neiszm',
#     'ids': ',ak0219neiszm,us6000f02w,at00qwzteb,pt21210001,usauto6000f02w,',
#     'sources': ',ak,us,at,pt,usauto,',
#     'types': ',dyfi,finite-fault,general-text,ground-failure,impact-link,impact-text,internal-moment-tensor,internal-origin,losspager,moment-tensor,oaf,origin,phase-data,shakemap,trump-losspager,trump-shakemap,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.95,
#     'gap': None,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 8.2 - 99 km SE of Perryville, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-157.8876, 55.3635, 35]},
#    'id': 'ak0219neiszm'},
#   {'type': 'Feature',
#    'properties': {'mag': 7.3,
#     'place': 'Southern Qinghai, China',
#     'time': 1621620253565,
#     'updated': 1653024819372,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000e54r',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000e54r&format=geojson',
#     'felt': 26,
#     'cdi': 9.1,
#     'mmi': 9.115,
#     'alert': 'orange',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 1024,
#     'net': 'us',
#     'code': '7000e54r',
#     'ids': ',us7000e54r,usauto7000e54r,pt21141001,at00qtgy75,',
#     'sources': ',us,usauto,pt,at,',
#     'types': ',dyfi,finite-fault,general-text,ground-failure,impact-text,internal-moment-tensor,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 4.655,
#     'rms': 0.77,
#     'gap': 9,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 7.3 - Southern Qinghai, China'},
#    'geometry': {'type': 'Point', 'coordinates': [98.2513, 34.5983, 10]},
#    'id': 'us7000e54r'},
#   {'type': 'Feature',
#    'properties': {'mag': 7,
#     'place': '30 km E of Ishinomaki, Japan',
#     'time': 1616231383966,
#     'updated': 1660306076816,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000dl6y',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000dl6y&format=geojson',
#     'felt': 409,
#     'cdi': 7.3,
#     'mmi': 7.008,
#     'alert': 'yellow',
#     'status': 'reviewed',
#     'tsunami': 1,
#     'sig': 1052,
#     'net': 'us',
#     'code': '7000dl6y',
#     'ids': ',at00qq9g49,us7000dl6y,usauto7000dl6y,pt21079003,',
#     'sources': ',at,us,usauto,pt,',
#     'types': ',associate,dyfi,finite-fault,general-text,ground-failure,impact-link,impact-text,internal-moment-tensor,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 2.378,
#     'rms': 0.75,
#     'gap': 35,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 7.0 - 30 km E of Ishinomaki, Japan'},
#    'geometry': {'type': 'Point', 'coordinates': [141.6477, 38.4515, 43]},
#    'id': 'us7000dl6y'},
#   {'type': 'Feature',
#    'properties': {'mag': 8.1,
#     'place': 'Kermadec Islands, New Zealand',
#     'time': 1614886113178,
#     'updated': 1639444540270,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000dflf',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000dflf&format=geojson',
#     'felt': 13,
#     'cdi': 9.1,
#     'mmi': 8.038,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 1,
#     'sig': 1021,
#     'net': 'us',
#     'code': '7000dflf',
#     'ids': ',at00qpgm3n,pt21063003,us7000dflf,usauto7000dflf,',
#     'sources': ',at,pt,us,usauto,',
#     'types': ',associate,dyfi,finite-fault,general-text,impact-link,impact-text,internal-moment-tensor,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 0.739,
#     'rms': 0.69,
#     'gap': 21,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 8.1 - Kermadec Islands, New Zealand'},
#    'geometry': {'type': 'Point', 'coordinates': [-177.2794, -29.7228, 28.93]},
#    'id': 'us7000dflf'},
#   {'type': 'Feature',
#    'properties': {'mag': 7.4,
#     'place': 'Kermadec Islands, New Zealand',
#     'time': 1614879683370,
#     'updated': 1640262537659,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000dfk3',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000dfk3&format=geojson',
#     'felt': 3,
#     'cdi': 3.4,
#     'mmi': 6.815,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 1,
#     'sig': 843,
#     'net': 'us',
#     'code': '7000dfk3',
#     'ids': ',us7000dfk3,pt21063002,at00qpgh52,usauto7000dfk3,',
#     'sources': ',us,pt,at,usauto,',
#     'types': ',dyfi,finite-fault,general-text,impact-link,impact-text,internal-moment-tensor,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 0.437,
#     'rms': 1.09,
#     'gap': 30,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 7.4 - Kermadec Islands, New Zealand'},
#    'geometry': {'type': 'Point', 'coordinates': [-177.8398, -29.6768, 43]},
#    'id': 'us7000dfk3'},
#   {'type': 'Feature',
#    'properties': {'mag': 7.3,
#     'place': '182 km NE of Gisborne, New Zealand',
#     'time': 1614864454647,
#     'updated': 1639386831261,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000dffl',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000dffl&format=geojson',
#     'felt': 154,
#     'cdi': 7.3,
#     'mmi': 6.495,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 1,
#     'sig': 932,
#     'net': 'us',
#     'code': '7000dffl',
#     'ids': ',us7000dffl,at00qpg5dz,pt21063000,usauto7000dffl,',
#     'sources': ',us,at,pt,usauto,',
#     'types': ',associate,dyfi,general-text,ground-failure,impact-link,impact-text,internal-moment-tensor,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 0.918,
#     'rms': 0.68,
#     'gap': 24,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 7.3 - 182 km NE of Gisborne, New Zealand'},
#    'geometry': {'type': 'Point', 'coordinates': [179.4576, -37.4787, 10]},
#    'id': 'us7000dffl'},
#   {'type': 'Feature',
#    'properties': {'mag': 7.1,
#     'place': '73 km ENE of Namie, Japan',
#     'time': 1613225269797,
#     'updated': 1660306212886,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000dher',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000dher&format=geojson',
#     'felt': 672,
#     'cdi': 9.1,
#     'mmi': 8.127,
#     'alert': 'orange',
#     'status': 'reviewed',
#     'tsunami': 1,
#     'sig': 1612,
#     'net': 'us',
#     'code': '6000dher',
#     'ids': ',at00qoh0l1,us6000dher,pt21044000,',
#     'sources': ',at,us,pt,',
#     'types': ',associate,dyfi,finite-fault,general-text,ground-failure,impact-link,impact-text,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 3.085,
#     'rms': 0.94,
#     'gap': 11,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 7.1 - 73 km ENE of Namie, Japan'},
#    'geometry': {'type': 'Point', 'coordinates': [141.7751, 37.7265, 43.98]},
#    'id': 'us6000dher'},
#   {'type': 'Feature',
#    'properties': {'mag': 7.7,
#     'place': 'southeast of the Loyalty Islands',
#     'time': 1612963195530,
#     'updated': 1638163346891,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000dg77',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000dg77&format=geojson',
#     'felt': 7,
#     'cdi': 9,
#     'mmi': 4.349,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 1,
#     'sig': 918,
#     'net': 'us',
#     'code': '6000dg77',
#     'ids': ',us6000dg77,at00qobedd,pt21041004,',
#     'sources': ',us,at,pt,',
#     'types': ',dyfi,finite-fault,general-text,ground-failure,impact-link,impact-text,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 7.989,
#     'rms': 0.42,
#     'gap': 15,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 7.7 - southeast of the Loyalty Islands'},
#    'geometry': {'type': 'Point', 'coordinates': [171.6566, -23.0511, 10]},
#    'id': 'us6000dg77'},
#   {'type': 'Feature',
#    'properties': {'mag': 7,
#     'place': '211 km SE of Pondaguitan, Philippines',
#     'time': 1611231784255,
#     'updated': 1620986739314,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000d20e',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000d20e&format=geojson',
#     'felt': 73,
#     'cdi': 6.6,
#     'mmi': 5.451,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 1,
#     'sig': 802,
#     'net': 'us',
#     'code': '7000d20e',
#     'ids': ',pt21021050,at00qnaaek,us7000d20e,usauto7000d20e,',
#     'sources': ',pt,at,us,usauto,',
#     'types': ',dyfi,general-text,ground-failure,impact-link,impact-text,internal-moment-tensor,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 2.821,
#     'rms': 0.77,
#     'gap': 15,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 7.0 - 211 km SE of Pondaguitan, Philippines'},
#    'geometry': {'type': 'Point', 'coordinates': [127.5145, 4.9931, 80]},
#    'id': 'us7000d20e'},
#   {'type': 'Feature',
#    'properties': {'mag': 7,
#     'place': '13 km NNE of Néon Karlovásion, Greece',
#     'time': 1604058687348,
#     'updated': 1661945277762,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000c7y0',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000c7y0&format=geojson',
#     'felt': 693,
#     'cdi': 7.6,
#     'mmi': 7.213,
#     'alert': 'orange',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 1527,
#     'net': 'us',
#     'code': '7000c7y0',
#     'ids': ',us7000c7y0,pt20304000,at00qj0jlr,',
#     'sources': ',us,pt,at,',
#     'types': ',dyfi,finite-fault,general-text,ground-failure,impact-text,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 1.518,
#     'rms': 0.59,
#     'gap': 18,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 7.0 - 13 km NNE of Néon Karlovásion, Greece'},
#    'geometry': {'type': 'Point', 'coordinates': [26.7838, 37.8973, 21]},
#    'id': 'us7000c7y0'},
#   {'type': 'Feature',
#    'properties': {'mag': 7.6,
#     'place': '99 km SE of Sand Point, Alaska',
#     'time': 1603140878950,
#     'updated': 1646891002055,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000c9hg',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000c9hg&format=geojson',
#     'felt': 321,
#     'cdi': 8.6,
#     'mmi': 7.343,
#     'alert': 'yellow',
#     'status': 'reviewed',
#     'tsunami': 1,
#     'sig': 1165,
#     'net': 'us',
#     'code': '6000c9hg',
#     'ids': ',at00qigvf4,us6000c9hg,pt20293005,ak020dgwp0mk,',
#     'sources': ',at,us,pt,ak,',
#     'types': ',dyfi,finite-fault,general-text,ground-failure,impact-link,impact-text,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,trump-origin,',
#     'nst': None,
#     'dmin': 0.23,
#     'rms': 0.91,
#     'gap': 36,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 7.6 - 99 km SE of Sand Point, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-159.6258, 54.602, 28.37]},
#    'id': 'us6000c9hg'},
#   {'type': 'Feature',
#    'properties': {'mag': 7.8,
#     'place': '99 km SSE of Perryville, Alaska',
#     'time': 1595398364810,
#     'updated': 1657262620468,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000asvb',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000asvb&format=geojson',
#     'felt': 192,
#     'cdi': 9.1,
#     'mmi': 6.501,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 1,
#     'sig': 1111,
#     'net': 'us',
#     'code': '7000asvb',
#     'ids': ',at00qdux98,us7000asvb,pt20204000,ak0209dha24u,',
#     'sources': ',at,us,pt,ak,',
#     'types': ',dyfi,finite-fault,general-link,general-text,ground-failure,impact-link,impact-text,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,trump-origin,trump-shakemap,',
#     'nst': None,
#     'dmin': 0.621,
#     'rms': 0.97,
#     'gap': 60,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 7.8 - 99 km SSE of Perryville, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-158.596, 55.0715, 28]},
#    'id': 'us7000asvb'},
#   {'type': 'Feature',
#    'properties': {'mag': 7,
#     'place': '114 km NNW of Popondetta, Papua New Guinea',
#     'time': 1594954222178,
#     'updated': 1646890062636,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000aq3e',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000aq3e&format=geojson',
#     'felt': 103,
#     'cdi': 6.4,
#     'mmi': 7.003,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 1,
#     'sig': 820,
#     'net': 'us',
#     'code': '7000aq3e',
#     'ids': ',at00qdlek0,pt20199000,us7000aq3e,',
#     'sources': ',at,pt,us,',
#     'types': ',dyfi,finite-fault,general-text,ground-failure,impact-link,impact-text,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 1.671,
#     'rms': 1.1,
#     'gap': 18,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 7.0 - 114 km NNW of Popondetta, Papua New Guinea'},
#    'geometry': {'type': 'Point', 'coordinates': [147.7704, -7.836, 73]},
#    'id': 'us7000aq3e'},
#   {'type': 'Feature',
#    'properties': {'mag': 7.4,
#     'place': '9 km SE of Santa María Xadani, Mexico',
#     'time': 1592926144350,
#     'updated': 1655918454870,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000ah9t',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000ah9t&format=geojson',
#     'felt': 642,
#     'cdi': 7.7,
#     'mmi': 7.658,
#     'alert': 'orange',
#     'status': 'reviewed',
#     'tsunami': 1,
#     'sig': 1494,
#     'net': 'us',
#     'code': '6000ah9t',
#     'ids': ',at00qcdxol,pt20175001,us6000ah9t,',
#     'sources': ',at,pt,us,',
#     'types': ',dyfi,finite-fault,general-link,general-text,ground-failure,impact-link,impact-text,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 0.151,
#     'rms': 1.14,
#     'gap': 30,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 7.4 - 9 km SE of Santa María Xadani, Mexico'},
#    'geometry': {'type': 'Point', 'coordinates': [-96.0077, 15.8861, 20]},
#    'id': 'us6000ah9t'},
#   {'type': 'Feature',
#    'properties': {'mag': 7.4,
#     'place': 'south of the Kermadec Islands',
#     'time': 1592484593844,
#     'updated': 1598745645040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000ae4n',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000ae4n&format=geojson',
#     'felt': 47,
#     'cdi': 6.6,
#     'mmi': 6.954,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 1,
#     'sig': 873,
#     'net': 'us',
#     'code': '6000ae4n',
#     'ids': ',pt20170001,us6000ae4n,at00qc4gz1,',
#     'sources': ',pt,us,at,',
#     'types': ',dyfi,general-text,impact-link,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 4.035,
#     'rms': 0.86,
#     'gap': 23,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 7.4 - south of the Kermadec Islands'},
#    'geometry': {'type': 'Point', 'coordinates': [-177.8571, -33.2927, 10]},
#    'id': 'us6000ae4n'},
#   {'type': 'Feature',
#    'properties': {'mag': 7.5,
#     'place': '221 km SSE of Severo-Kuril’sk, Russia',
#     'time': 1585104561160,
#     'updated': 1659994312041,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us70008fi4',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us70008fi4&format=geojson',
#     'felt': 25,
#     'cdi': 5.5,
#     'mmi': 5.293,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 1,
#     'sig': 879,
#     'net': 'us',
#     'code': '70008fi4',
#     'ids': ',at00q7qai7,pt20085000,us70008fi4,',
#     'sources': ',at,pt,us,',
#     'types': ',dyfi,finite-fault,general-text,ground-failure,impact-link,impact-text,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 4.109,
#     'rms': 0.66,
#     'gap': 12,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 7.5 - 221 km SSE of Severo-Kuril’sk, Russia'},
#    'geometry': {'type': 'Point', 'coordinates': [157.6955, 48.9638, 57.8]},
#    'id': 'us70008fi4'},
#   {'type': 'Feature',
#    'properties': {'mag': 7,
#     'place': '95 km ENE of Kuril’sk, Russia',
#     'time': 1581590024406,
#     'updated': 1646888775410,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us70007pa9',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us70007pa9&format=geojson',
#     'felt': 33,
#     'cdi': 4.8,
#     'mmi': 6.255,
#     'alert': 'yellow',
#     'status': 'reviewed',
#     'tsunami': 1,
#     'sig': 770,
#     'net': 'us',
#     'code': '70007pa9',
#     'ids': ',us70007pa9,at00q5myo9,pt20044002,at00q5mcj0,',
#     'sources': ',us,at,pt,at,',
#     'types': ',associate,dyfi,finite-fault,ground-failure,impact-link,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 4.501,
#     'rms': 0.83,
#     'gap': 25,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 7.0 - 95 km ENE of Kuril’sk, Russia'},
#    'geometry': {'type': 'Point', 'coordinates': [148.959, 45.6161, 143]},
#    'id': 'us70007pa9'},
#   {'type': 'Feature',
#    'properties': {'mag': 7.7,
#     'place': '123 km NNW of Lucea, Jamaica',
#     'time': 1580238624918,
#     'updated': 1646888644558,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us60007idc',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us60007idc&format=geojson',
#     'felt': 1051,
#     'cdi': 9,
#     'mmi': 6.042,
#     'alert': 'yellow',
#     'status': 'reviewed',
#     'tsunami': 1,
#     'sig': 1812,
#     'net': 'us',
#     'code': '60007idc',
#     'ids': ',pt20028001,us60007idc,at00q4ttp1,',
#     'sources': ',pt,us,at,',
#     'types': ',dyfi,finite-fault,general-text,ground-failure,impact-link,impact-text,losspager,losspager-admin,moment-tensor,origin,phase-data,poster,shakemap,',
#     'nst': None,
#     'dmin': 1.657,
#     'rms': 0.75,
#     'gap': 26,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 7.7 - 123 km NNW of Lucea, Jamaica'},
#    'geometry': {'type': 'Point', 'coordinates': [-78.756, 19.4193, 14.86]},
#    'id': 'us60007idc'},
#   {'type': 'Feature',
#    'properties': {'mag': 7.1,
#     'place': '141 km NW of Ternate, Indonesia',
#     'time': 1573748260578,
#     'updated': 1601703531266,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us60006bjl',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us60006bjl&format=geojson',
#     'felt': 41,
#     'cdi': 5.8,
#     'mmi': 6.459,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 1,
#     'sig': 799,
#     'net': 'us',
#     'code': '60006bjl',
#     'ids': ',pt19318001,at00q0yvxj,us60006bjl,',
#     'sources': ',pt,at,us,',
#     'types': ',dyfi,finite-fault,general-text,ground-failure,impact-link,impact-text,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 1.271,
#     'rms': 1.15,
#     'gap': 11,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 7.1 - 141 km NW of Ternate, Indonesia'},
#    'geometry': {'type': 'Point', 'coordinates': [126.4156, 1.6213, 33]},
#    'id': 'us60006bjl'},
#   {'type': 'Feature',
#    'properties': {'mag': 7.2,
#     'place': '155 km SSE of Sofifi, Indonesia',
#     'time': 1563095451523,
#     'updated': 1596115886346,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us70004jyv',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us70004jyv&format=geojson',
#     'felt': 17,
#     'cdi': 6.7,
#     'mmi': 6.81,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 809,
#     'net': 'us',
#     'code': '70004jyv',
#     'ids': ',us70004jyv,',
#     'sources': ',us,',
#     'types': ',dyfi,finite-fault,general-text,ground-failure,impact-text,losspager,moment-tensor,origin,phase-data,poster,shakemap,',
#     'nst': None,
#     'dmin': 1.504,
#     'rms': 0.88,
#     'gap': 38,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 7.2 - 155 km SSE of Sofifi, Indonesia'},
#    'geometry': {'type': 'Point', 'coordinates': [128.034, -0.5858, 18.98]},
#    'id': 'us70004jyv'},
#   {'type': 'Feature',
#    'properties': {'mag': 7.1,
#     'place': '18km W of Searles Valley, CA',
#     'time': 1562383193040,
#     'updated': 1664385981047,
#     'tz': -480,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci38457511',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci38457511&format=geojson',
#     'felt': 24384,
#     'cdi': 8.7,
#     'mmi': 8.73,
#     'alert': 'yellow',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 1646,
#     'net': 'ci',
#     'code': '38457511',
#     'ids': ',ci38457511,us70004bn0,at00pu7alg,pt19187000,',
#     'sources': ',ci,us,at,pt,',
#     'types': ',dyfi,finite-fault,focal-mechanism,general-link,general-text,geoserve,ground-failure,impact-text,losspager,moment-tensor,nearby-cities,oaf,origin,phase-data,poster,scitech-link,shakemap,',
#     'nst': 77,
#     'dmin': 0.04616,
#     'rms': 0.22,
#     'gap': 43,
#     'magType': 'mw',
#     'type': 'earthquake',
#     'title': 'M 7.1 - 18km W of Searles Valley, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-117.5993333, 35.7695, 8]},
#    'id': 'ci38457511'},
#   {'type': 'Feature',
#    'properties': {'mag': 7.3,
#     'place': 'Banda Sea',
#     'time': 1561344819830,
#     'updated': 1594402211502,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us600044zz',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us600044zz&format=geojson',
#     'felt': 323,
#     'cdi': 4.1,
#     'mmi': 5.64,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 1,
#     'sig': 952,
#     'net': 'us',
#     'code': '600044zz',
#     'ids': ',at00ptl1dg,pt19175001,us600044zz,',
#     'sources': ',at,pt,us,',
#     'types': ',dyfi,general-text,ground-failure,impact-link,losspager,moment-tensor,origin,phase-data,poster,shakemap,',
#     'nst': None,
#     'dmin': 2.629,
#     'rms': 1.08,
#     'gap': 16,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 7.3 - Banda Sea'},
#    'geometry': {'type': 'Point', 'coordinates': [129.1692, -6.4078, 212]},
#    'id': 'us600044zz'},
#   {'type': 'Feature',
#    'properties': {'mag': 7.3,
#     'place': 'Kermadec Islands, New Zealand',
#     'time': 1560639304130,
#     'updated': 1567779911040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000417i',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000417i&format=geojson',
#     'felt': 12,
#     'cdi': 8.3,
#     'mmi': 6.465,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 1,
#     'sig': 830,
#     'net': 'us',
#     'code': '6000417i',
#     'ids': ',at00pt5wzj,us6000417i,pt19166001,',
#     'sources': ',at,us,pt,',
#     'types': ',dyfi,finite-fault,general-text,impact-link,impact-text,losspager,moment-tensor,origin,phase-data,poster,shakemap,',
#     'nst': None,
#     'dmin': 1.402,
#     'rms': 0.81,
#     'gap': 11,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 7.3 - Kermadec Islands, New Zealand'},
#    'geometry': {'type': 'Point', 'coordinates': [-178.0995, -30.6441, 46]},
#    'id': 'us6000417i'},
#   {'type': 'Feature',
#    'properties': {'mag': 8,
#     'place': '78 km NE of Navarro, Peru',
#     'time': 1558856475073,
#     'updated': 1655597166103,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us60003sc0',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us60003sc0&format=geojson',
#     'felt': 1083,
#     'cdi': 8.9,
#     'mmi': 7.945,
#     'alert': 'orange',
#     'status': 'reviewed',
#     'tsunami': 1,
#     'sig': 1890,
#     'net': 'us',
#     'code': '60003sc0',
#     'ids': ',at00ps3pco,pt19146001,us60003sc0,',
#     'sources': ',at,pt,us,',
#     'types': ',dyfi,finite-fault,general-text,ground-failure,impact-link,impact-text,losspager,moment-tensor,origin,phase-data,poster,shakemap,',
#     'nst': None,
#     'dmin': 3.18,
#     'rms': 0.84,
#     'gap': 17,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 8.0 - 78 km NE of Navarro, Peru'},
#    'geometry': {'type': 'Point', 'coordinates': [-75.2697, -5.8119, 122.57]},
#    'id': 'us60003sc0'},
#   {'type': 'Feature',
#    'properties': {'mag': 7.6,
#     'place': '48 km NE of Kokopo, Papua New Guinea',
#     'time': 1557838705939,
#     'updated': 1594162417609,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us70003kyy',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us70003kyy&format=geojson',
#     'felt': 58,
#     'cdi': 6.9,
#     'mmi': 7.252,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 1,
#     'sig': 929,
#     'net': 'us',
#     'code': '70003kyy',
#     'ids': ',pt19134000,us70003kyy,',
#     'sources': ',pt,us,',
#     'types': ',dyfi,finite-fault,general-link,general-text,ground-failure,impact-link,impact-text,losspager,moment-tensor,origin,phase-data,poster,shakemap,',
#     'nst': None,
#     'dmin': 0.453,
#     'rms': 1,
#     'gap': 16,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 7.6 - 48 km NE of Kokopo, Papua New Guinea'},
#    'geometry': {'type': 'Point', 'coordinates': [152.5967, -4.051, 10]},
#    'id': 'us70003kyy'},
#   {'type': 'Feature',
#    'properties': {'mag': 7.1,
#     'place': '32 km NW of Bulolo, Papua New Guinea',
#     'time': 1557177577983,
#     'updated': 1594402818038,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us70003hqb',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us70003hqb&format=geojson',
#     'felt': 77,
#     'cdi': 6.5,
#     'mmi': 6.159,
#     'alert': 'yellow',
#     'status': 'reviewed',
#     'tsunami': 1,
#     'sig': 826,
#     'net': 'us',
#     'code': '70003hqb',
#     'ids': ',at00pr3pwp,us70003hqb,pt19126050,',
#     'sources': ',at,us,pt,',
#     'types': ',dyfi,finite-fault,general-text,ground-failure,impact-link,impact-text,losspager,moment-tensor,origin,phase-data,poster,shakemap,',
#     'nst': None,
#     'dmin': 2.514,
#     'rms': 1.02,
#     'gap': 16,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 7.1 - 32 km NW of Bulolo, Papua New Guinea'},
#    'geometry': {'type': 'Point', 'coordinates': [146.4494, -6.9746, 146]},
#    'id': 'us70003hqb'},
#   {'type': 'Feature',
#    'properties': {'mag': 7,
#     'place': '22 km NNE of Azángaro, Peru',
#     'time': 1551430242591,
#     'updated': 1649851917121,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us1000j96d',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us1000j96d&format=geojson',
#     'felt': 160,
#     'cdi': 7.2,
#     'mmi': 4.423,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 1,
#     'sig': 869,
#     'net': 'us',
#     'code': '1000j96d',
#     'ids': ',at00pnoj8k,pt19060000,us1000j96d,',
#     'sources': ',at,pt,us,',
#     'types': ',dyfi,finite-fault,general-text,ground-failure,impact-link,impact-text,losspager,moment-tensor,origin,phase-data,poster,shakemap,',
#     'nst': None,
#     'dmin': 2.501,
#     'rms': 1.13,
#     'gap': 42,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 7.0 - 22 km NNE of Azángaro, Peru'},
#    'geometry': {'type': 'Point', 'coordinates': [-70.1546, -14.7131, 267]},
#    'id': 'us1000j96d'},
#   {'type': 'Feature',
#    'properties': {'mag': 7.5,
#     'place': '115 km ESE of Palora, Ecuador',
#     'time': 1550830643770,
#     'updated': 1594162356277,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us2000jlfv',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us2000jlfv&format=geojson',
#     'felt': 418,
#     'cdi': 6.7,
#     'mmi': 7.281,
#     'alert': 'yellow',
#     'status': 'reviewed',
#     'tsunami': 1,
#     'sig': 1145,
#     'net': 'us',
#     'code': '2000jlfv',
#     'ids': ',at00pnbol0,pt19053000,us2000jlfv,',
#     'sources': ',at,pt,us,',
#     'types': ',dyfi,finite-fault,general-text,ground-failure,impact-link,impact-text,losspager,moment-tensor,origin,phase-data,poster,shakemap,',
#     'nst': None,
#     'dmin': 2.045,
#     'rms': 1.12,
#     'gap': 15,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 7.5 - 115 km ESE of Palora, Ecuador'},
#    'geometry': {'type': 'Point', 'coordinates': [-77.0505, -2.1862, 145]},
#    'id': 'us2000jlfv'},
#   {'type': 'Feature',
#    'properties': {'mag': 7,
#     'place': '96 km ESE of Pondaguitan, Philippines',
#     'time': 1546054749740,
#     'updated': 1651606983314,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us2000iyta',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us2000iyta&format=geojson',
#     'felt': 95,
#     'cdi': 5.2,
#     'mmi': 5.22,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 1,
#     'sig': 803,
#     'net': 'us',
#     'code': '2000iyta',
#     'ids': ',at00pkhbhc,pt18363000,us2000iyta,iscgem614463414,',
#     'sources': ',at,pt,us,iscgem,',
#     'types': ',dyfi,finite-fault,ground-failure,impact-link,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 1.769,
#     'rms': 1.45,
#     'gap': 21,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 7.0 - 96 km ESE of Pondaguitan, Philippines'},
#    'geometry': {'type': 'Point', 'coordinates': [126.9209, 5.8983, 60.21]},
#    'id': 'us2000iyta'},
#   {'type': 'Feature',
#    'properties': {'mag': 7.3,
#     'place': '187 km SE of Ust’-Kamchatsk Staryy, Russia',
#     'time': 1545325315150,
#     'updated': 1651606930731,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us2000ivfw',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us2000ivfw&format=geojson',
#     'felt': 6,
#     'cdi': 3.2,
#     'mmi': 6.92,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 1,
#     'sig': 822,
#     'net': 'us',
#     'code': '2000ivfw',
#     'ids': ',us2000ivfw,pt18354000,at00pk1on9,iscgem614459017,',
#     'sources': ',us,pt,at,iscgem,',
#     'types': ',dyfi,finite-fault,general-text,ground-failure,impact-link,losspager,moment-tensor,origin,phase-data,poster,shakemap,',
#     'nst': None,
#     'dmin': 4.126,
#     'rms': 0.79,
#     'gap': 23,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 7.3 - 187 km SE of Ust’-Kamchatsk Staryy, Russia'},
#    'geometry': {'type': 'Point', 'coordinates': [164.6993, 55.0999, 16.56]},
#    'id': 'us2000ivfw'},
#   {'type': 'Feature',
#    'properties': {'mag': 7.1,
#     'place': 'South Sandwich Islands region',
#     'time': 1544495189420,
#     'updated': 1651606867127,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us2000isc8',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us2000isc8&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': 5.36,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 1,
#     'sig': 776,
#     'net': 'us',
#     'code': '2000isc8',
#     'ids': ',us2000isc8,pt18345000,at00pjjw49,iscgem614423758,',
#     'sources': ',us,pt,at,iscgem,',
#     'types': ',general-text,impact-link,losspager,moment-tensor,origin,phase-data,poster,shakemap,',
#     'nst': None,
#     'dmin': 7.043,
#     'rms': 0.92,
#     'gap': 20,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 7.1 - South Sandwich Islands region'},
#    'geometry': {'type': 'Point', 'coordinates': [-26.3856, -58.5446, 133]},
#    'id': 'us2000isc8'},
#   {'type': 'Feature',
#    'properties': {'mag': 7.5,
#     'place': '166 km ESE of Tadine, New Caledonia',
#     'time': 1543983488420,
#     'updated': 1651607449454,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us1000i2gt',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us1000i2gt&format=geojson',
#     'felt': 17,
#     'cdi': 3.4,
#     'mmi': 5.972,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 1,
#     'sig': 871,
#     'net': 'us',
#     'code': '1000i2gt',
#     'ids': ',at00pj8xaa,pt18339001,us1000i2gt,iscgem615091842,',
#     'sources': ',at,pt,us,iscgem,',
#     'types': ',dyfi,finite-fault,general-text,ground-failure,impact-link,impact-text,losspager,moment-tensor,origin,phase-data,poster,shakemap,',
#     'nst': None,
#     'dmin': 2.405,
#     'rms': 0.74,
#     'gap': 18,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 7.5 - 166 km ESE of Tadine, New Caledonia'},
#    'geometry': {'type': 'Point', 'coordinates': [169.4266, -21.9496, 10]},
#    'id': 'us1000i2gt'},
#   {'type': 'Feature',
#    'properties': {'mag': 7.1,
#     'place': '1 km SE of Point MacKenzie, Alaska',
#     'time': 1543598969330,
#     'updated': 1661312461150,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak018fcnsk91',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak018fcnsk91&format=geojson',
#     'felt': 2335,
#     'cdi': 7.9,
#     'mmi': 7.696,
#     'alert': 'orange',
#     'status': 'reviewed',
#     'tsunami': 1,
#     'sig': 1790,
#     'net': 'ak',
#     'code': '018fcnsk91',
#     'ids': ',ak20419010,at00pj0ol4,us1000hyfh,ak018fcnsk91,pt18334000,iscgem616643636,',
#     'sources': ',ak,at,us,ak,pt,iscgem,',
#     'types': ',associate,dyfi,finite-fault,general-link,general-text,ground-failure,impact-link,impact-text,losspager,moment-tensor,origin,phase-data,poster,scitech-link,shakemap,',
#     'nst': None,
#     'dmin': None,
#     'rms': 1.04,
#     'gap': None,
#     'magType': 'mw',
#     'type': 'earthquake',
#     'title': 'M 7.1 - 1 km SE of Point MacKenzie, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-149.9552, 61.3464, 46.7]},
#    'id': 'ak018fcnsk91'},
#   {'type': 'Feature',
#    'properties': {'mag': 7,
#     'place': '119 km E of Kimbe, Papua New Guinea',
#     'time': 1539204500100,
#     'updated': 1651607421621,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us1000haa3',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us1000haa3&format=geojson',
#     'felt': 6,
#     'cdi': 6.3,
#     'mmi': 6.273,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 1,
#     'sig': 758,
#     'net': 'us',
#     'code': '1000haa3',
#     'ids': ',us1000haa3,at00pgehsk,pt18283003,iscgem615091200,',
#     'sources': ',us,at,pt,iscgem,',
#     'types': ',dyfi,finite-fault,general-text,ground-failure,impact-link,losspager,moment-tensor,origin,phase-data,poster,shakemap,',
#     'nst': None,
#     'dmin': 1.778,
#     'rms': 1.1,
#     'gap': 18,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 7.0 - 119 km E of Kimbe, Papua New Guinea'},
#    'geometry': {'type': 'Point', 'coordinates': [151.2046, -5.7012, 39]},
#    'id': 'us1000haa3'},
#   {'type': 'Feature',
#    'properties': {'mag': 7.5,
#     'place': '72 km N of Palu, Indonesia',
#     'time': 1538128965250,
#     'updated': 1651607827729,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us1000h3p4',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us1000h3p4&format=geojson',
#     'felt': 30,
#     'cdi': 8.5,
#     'mmi': 8.367,
#     'alert': 'red',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 2026,
#     'net': 'us',
#     'code': '1000h3p4',
#     'ids': ',us1000h3p4,iscgem616642238,',
#     'sources': ',us,iscgem,',
#     'types': ',dyfi,finite-fault,general-text,ground-failure,impact-text,losspager,moment-tensor,origin,phase-data,poster,shakemap,',
#     'nst': None,
#     'dmin': 1.649,
#     'rms': 1,
#     'gap': 13,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 7.5 - 72 km N of Palu, Indonesia'},
#    'geometry': {'type': 'Point', 'coordinates': [119.8462, -0.2559, 20]},
#    'id': 'us1000h3p4'},
#   {'type': 'Feature',
#    'properties': {'mag': 7.9,
#     'place': '45 km S of Levuka, Fiji',
#     'time': 1536248958710,
#     'updated': 1651606409496,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us2000h9e2',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us2000h9e2&format=geojson',
#     'felt': 27,
#     'cdi': 7,
#     'mmi': 3.569,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 1,
#     'sig': 979,
#     'net': 'us',
#     'code': '2000h9e2',
#     'ids': ',at00pen5a4,pt18249001,us2000h9e2,iscgem612848327,',
#     'sources': ',at,pt,us,iscgem,',
#     'types': ',dyfi,general-text,impact-link,losspager,moment-tensor,origin,phase-data,poster,shakemap,',
#     'nst': None,
#     'dmin': 1.431,
#     'rms': 1.07,
#     'gap': 12,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 7.9 - 45 km S of Levuka, Fiji'},
#    'geometry': {'type': 'Point', 'coordinates': [179.3502, -18.4743, 670.81]},
#    'id': 'us2000h9e2'},
#   {'type': 'Feature',
#    'properties': {'mag': 7.1,
#     'place': '238 km ESE of Tadine, New Caledonia',
#     'time': 1535514716100,
#     'updated': 1659944054777,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us1000gjaz',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us1000gjaz&format=geojson',
#     'felt': 2,
#     'cdi': 2,
#     'mmi': 4.51,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 1,
#     'sig': 776,
#     'net': 'us',
#     'code': '1000gjaz',
#     'ids': ',at00pe7eqn,us1000gjaz,pt18241000,iscgem615001001,',
#     'sources': ',at,us,pt,iscgem,',
#     'types': ',dyfi,general-text,ground-failure,impact-link,impact-text,losspager,moment-tensor,origin,phase-data,poster,shakemap,',
#     'nst': None,
#     'dmin': 2.548,
#     'rms': 0.98,
#     'gap': 23,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 7.1 - 238 km ESE of Tadine, New Caledonia'},
#    'geometry': {'type': 'Point', 'coordinates': [170.1262, -22.0295, 21.43]},
#    'id': 'us1000gjaz'},
#   {'type': 'Feature',
#    'properties': {'mag': 7.1,
#     'place': '136 km W of Iñapari, Peru',
#     'time': 1535101448250,
#     'updated': 1651606100969,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us1000ggj4',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us1000ggj4&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': 2.93,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 776,
#     'net': 'us',
#     'code': '1000ggj4',
#     'ids': ',us1000ggj4,iscgem612637304,',
#     'sources': ',us,iscgem,',
#     'types': ',general-text,ground-failure,losspager,moment-tensor,origin,phase-data,poster,shakemap,',
#     'nst': None,
#     'dmin': 3.77,
#     'rms': 0.99,
#     'gap': 12,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 7.1 - 136 km W of Iñapari, Peru'},
#    'geometry': {'type': 'Point', 'coordinates': [-70.8284, -11.0355, 630]},
#    'id': 'us1000ggj4'},
#   {'type': 'Feature',
#    'properties': {'mag': 7.3,
#     'place': '40 km ENE of Carúpano, Venezuela',
#     'time': 1534887107600,
#     'updated': 1646767420101,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us1000gez7',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us1000gez7&format=geojson',
#     'felt': 1169,
#     'cdi': 7.5,
#     'mmi': 6.105,
#     'alert': 'yellow',
#     'status': 'reviewed',
#     'tsunami': 1,
#     'sig': 1570,
#     'net': 'us',
#     'code': '1000gez7',
#     'ids': ',at00pdtygt,pt18233000,us1000gez7,',
#     'sources': ',at,pt,us,',
#     'types': ',dyfi,finite-fault,general-text,ground-failure,impact-link,impact-text,losspager,moment-tensor,origin,phase-data,poster,shakemap,',
#     'nst': None,
#     'dmin': 1.822,
#     'rms': 1.1,
#     'gap': 15,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 7.3 - 40 km ENE of Carúpano, Venezuela'},
#    'geometry': {'type': 'Point', 'coordinates': [-62.9019, 10.7731, 146.82]},
#    'id': 'us1000gez7'},
#   {'type': 'Feature',
#    'properties': {'mag': 8.2,
#     'place': '267 km E of Levuka, Fiji',
#     'time': 1534637980670,
#     'updated': 1651607812773,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us1000gcii',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us1000gcii&format=geojson',
#     'felt': 31,
#     'cdi': 5,
#     'mmi': 4.033,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 1,
#     'sig': 1050,
#     'net': 'us',
#     'code': '1000gcii',
#     'ids': ',at00pdom8q,pt18231000,us1000gcii,iscgem616641704,',
#     'sources': ',at,pt,us,iscgem,',
#     'types': ',dyfi,finite-fault,general-text,impact-link,impact-text,losspager,moment-tensor,origin,phase-data,poster,shakemap,',
#     'nst': None,
#     'dmin': 3.63,
#     'rms': 0.79,
#     'gap': 13,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 8.2 - 267 km E of Levuka, Fiji'},
#    'geometry': {'type': 'Point', 'coordinates': [-178.153, -18.1125, 600]},
#    'id': 'us1000gcii'},
#   {'type': 'Feature',
#    'properties': {'mag': 7.5,
#     'place': '32 km SW of Tari, Papua New Guinea',
#     'time': 1519580684140,
#     'updated': 1651607091042,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us2000d7q6',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us2000d7q6&format=geojson',
#     'felt': 86,
#     'cdi': 9,
#     'mmi': 8.288,
#     'alert': 'yellow',
#     'status': 'reviewed',
#     'tsunami': 1,
#     'sig': 943,
#     'net': 'us',
#     'code': '2000d7q6',
#     'ids': ',at00p4pvyj,pt18056001,us2000d7q6,iscgem615000068,',
#     'sources': ',at,pt,us,iscgem,',
#     'types': ',dyfi,finite-fault,general-link,general-text,ground-failure,impact-link,impact-text,losspager,moment-tensor,origin,phase-data,poster,shakemap,',
#     'nst': None,
#     'dmin': 5.48,
#     'rms': 1.31,
#     'gap': 17,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 7.5 - 32 km SW of Tari, Papua New Guinea'},
#    'geometry': {'type': 'Point', 'coordinates': [142.7536, -6.0699, 25.21]},
#    'id': 'us2000d7q6'},
#   {'type': 'Feature',
#    'properties': {'mag': 7.2,
#     'place': '4 km S of Pinotepa de Don Luis, Mexico',
#     'time': 1518824379280,
#     'updated': 1651604576218,
#     'tz': None,
# ...
#     'updated': 1651258852062,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/usp000a5m7',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=usp000a5m7&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': 7.203,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 754,
#     'net': 'us',
#     'code': 'p000a5m7',
#     'ids': ',choy20001206171106,gcmtc120600c,usp000a5m7,duputel120600c,atlas20001206171107,iscgem1742774,atlas20001206171106,',
#     'sources': ',choy,gcmt,us,duputel,atlas,iscgem,atlas,',
#     'types': ',focal-mechanism,general-text,impact-text,moment-tensor,origin,phase-data,shakemap,trump-shakemap,',
#     'nst': 495,
#     'dmin': None,
#     'rms': 0.9,
#     'gap': None,
#     'magType': 'mwc',
#     'type': 'earthquake',
#     'title': 'M 7.0 - 37 km E of Balkanabat, Turkmenistan'},
#    'geometry': {'type': 'Point', 'coordinates': [54.799, 39.566, 30]},
#    'id': 'usp000a5m7'},
#   {'type': 'Feature',
#    'properties': {'mag': 7.8,
#     'place': '138 km SSW of Kokopo, Papua New Guinea',
#     'time': 974494916490,
#     'updated': 1651258730243,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/usp000a45f',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=usp000a45f&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': 6.895,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 936,
#     'net': 'us',
#     'code': 'p000a45f',
#     'ids': ',usp000a45f,choy20001117210156,gcmtc111700q,duputel111700q,gcmt20001117210156,atlas20001117210157,iscgem1741952,',
#     'sources': ',us,choy,gcmt,duputel,gcmt,atlas,iscgem,',
#     'types': ',finite-fault,focal-mechanism,general-text,impact-text,moment-tensor,origin,phase-data,shakemap,trump-shakemap,',
#     'nst': 346,
#     'dmin': None,
#     'rms': 1.07,
#     'gap': None,
#     'magType': 'mwc',
#     'type': 'earthquake',
#     'title': 'M 7.8 - 138 km SSW of Kokopo, Papua New Guinea'},
#    'geometry': {'type': 'Point', 'coordinates': [151.781, -5.496, 33]},
#    'id': 'usp000a45f'},
#   {'type': 'Feature',
#    'properties': {'mag': 7.8,
#     'place': '135 km SE of Kokopo, Papua New Guinea',
#     'time': 974360536930,
#     'updated': 1651259792829,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/usp000a3sp',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=usp000a3sp&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': 6.62,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 936,
#     'net': 'us',
#     'code': 'p000a3sp',
#     'ids': ',usp000a3sp,choy20001116074216,gcmtc111600c,gcmt20001116074216,atlas20001116074218,iscgem1838286,',
#     'sources': ',us,choy,gcmt,gcmt,atlas,iscgem,',
#     'types': ',finite-fault,focal-mechanism,general-text,impact-text,moment-tensor,origin,phase-data,shakemap,trump-shakemap,',
#     'nst': 294,
#     'dmin': None,
#     'rms': 1.31,
#     'gap': None,
#     'magType': 'mwc',
#     'type': 'earthquake',
#     'title': 'M 7.8 - 135 km SE of Kokopo, Papua New Guinea'},
#    'geometry': {'type': 'Point', 'coordinates': [153.102, -5.233, 30]},
#    'id': 'usp000a3sp'},
#   {'type': 'Feature',
#    'properties': {'mag': 8,
#     'place': '24 km N of Rabaul, Papua New Guinea',
#     'time': 974350496740,
#     'updated': 1651260373204,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/usp000a3qq',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=usp000a3qq&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': 7.106,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 985,
#     'net': 'us',
#     'code': 'p000a3qq',
#     'ids': ',usp000a3qq,gcmtm111600b,gcmt20001116045456,duputel111600b,atlas20001116045457,iscgem1913438,',
#     'sources': ',us,gcmt,gcmt,duputel,atlas,iscgem,',
#     'types': ',finite-fault,focal-mechanism,general-text,ground-failure,impact-text,moment-tensor,origin,phase-data,shakemap,trump-shakemap,',
#     'nst': 254,
#     'dmin': None,
#     'rms': 1.2,
#     'gap': None,
#     'magType': 'mwc',
#     'type': 'earthquake',
#     'title': 'M 8.0 - 24 km N of Rabaul, Papua New Guinea'},
#    'geometry': {'type': 'Point', 'coordinates': [152.169, -3.98, 33]},
#    'id': 'usp000a3qq'},
#   {'type': 'Feature',
#    'properties': {'mag': 7,
#     'place': '191 km ESE of Kokopo, Papua New Guinea',
#     'time': 972808628770,
#     'updated': 1651258552687,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/usp000a2mw',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=usp000a2mw&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': 6.637,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 754,
#     'net': 'us',
#     'code': 'p000a2mw',
#     'ids': ',choy20001029083708,gcmtc102900c,usp000a2mw,gcmt20001029083708,duputel102900c,iscgem1741138,',
#     'sources': ',choy,gcmt,us,gcmt,duputel,iscgem,',
#     'types': ',focal-mechanism,general-text,moment-tensor,origin,phase-data,shakemap,',
#     'nst': 60,
#     'dmin': None,
#     'rms': 0.96,
#     'gap': None,
#     'magType': 'mwc',
#     'type': 'earthquake',
#     'title': 'M 7.0 - 191 km ESE of Kokopo, Papua New Guinea'},
#    'geometry': {'type': 'Point', 'coordinates': [153.945, -4.766, 50]},
#    'id': 'usp000a2mw'},
#   {'type': 'Feature',
#    'properties': {'mag': 7,
#     'place': '29 km WNW of Luganville, Vanuatu',
#     'time': 970678724310,
#     'updated': 1651258453150,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/usp000a18v',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=usp000a18v&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': 6.722,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 754,
#     'net': 'us',
#     'code': 'p000a18v',
#     'ids': ',choy20001004165844,gcmtc100400g,usp000a18v,gcmt20001004165844,duputel100400g,atlas20001004165845,iscgem1740522,',
#     'sources': ',choy,gcmt,us,gcmt,duputel,atlas,iscgem,',
#     'types': ',focal-mechanism,general-text,moment-tensor,origin,phase-data,shakemap,trump-shakemap,',
#     'nst': 357,
#     'dmin': None,
#     'rms': 1.16,
#     'gap': None,
#     'magType': 'mwc',
#     'type': 'earthquake',
#     'title': 'M 7.0 - 29 km WNW of Luganville, Vanuatu'},
#    'geometry': {'type': 'Point', 'coordinates': [166.91, -15.421, 23]},
#    'id': 'usp000a18v'},
#   {'type': 'Feature',
#    'properties': {'mag': 7.4,
#     'place': 'Bonin Islands, Japan region',
#     'time': 965546832900,
#     'updated': 1651258064258,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/usp0009xzy',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=usp0009xzy&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 842,
#     'net': 'us',
#     'code': 'p0009xzy',
#     'ids': ',choy20000806072712,gcmtc080600b,usp0009xzy,gcmt20000806072712,duputel080600b,iscgem1738788,',
#     'sources': ',choy,gcmt,us,gcmt,duputel,iscgem,',
#     'types': ',focal-mechanism,general-text,impact-text,moment-tensor,origin,phase-data,',
#     'nst': 588,
#     'dmin': None,
#     'rms': 0.9,
#     'gap': None,
#     'magType': 'mwc',
#     'type': 'earthquake',
#     'title': 'M 7.4 - Bonin Islands, Japan region'},
#    'geometry': {'type': 'Point', 'coordinates': [139.556, 28.856, 394.8]},
#    'id': 'usp0009xzy'},
#   {'type': 'Feature',
#    'properties': {'mag': 7.9,
#     'place': 'South Indian Ocean',
#     'time': 961339453310,
#     'updated': 1651257722193,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/usp0009ut0',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=usp0009ut0&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': 4.809,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 960,
#     'net': 'us',
#     'code': 'p0009ut0',
#     'ids': ',usp0009ut0,choy20000618144413,gcmtc061800a,gcmt20000618144413,duputel061800a,iscgem1736624,',
#     'sources': ',us,choy,gcmt,gcmt,duputel,iscgem,',
#     'types': ',finite-fault,focal-mechanism,general-text,impact-text,moment-tensor,origin,phase-data,shakemap,',
#     'nst': 405,
#     'dmin': None,
#     'rms': 1.16,
#     'gap': None,
#     'magType': 'mwc',
#     'type': 'earthquake',
#     'title': 'M 7.9 - South Indian Ocean'},
#    'geometry': {'type': 'Point', 'coordinates': [97.453, -13.802, 10]},
#    'id': 'usp0009ut0'},
#   {'type': 'Feature',
#    'properties': {'mag': 7.9,
#     'place': '103 km S of Bengkulu, Indonesia',
#     'time': 960136106170,
#     'updated': 1651257573008,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/usp0009txv',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=usp0009txv&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': 7.885,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 960,
#     'net': 'us',
#     'code': 'p0009txv',
#     'ids': ',usp0009txv,choy20000604162826,gcmtm060400d,gcmt20000604162826,duputel060400d,atlas20000604162827,iscgem1736014,',
#     'sources': ',us,choy,gcmt,gcmt,duputel,atlas,iscgem,',
#     'types': ',finite-fault,focal-mechanism,general-text,impact-text,moment-tensor,origin,phase-data,shakemap,trump-shakemap,',
#     'nst': 379,
#     'dmin': None,
#     'rms': 1.1,
#     'gap': None,
#     'magType': 'mwc',
#     'type': 'earthquake',
#     'title': 'M 7.9 - 103 km S of Bengkulu, Indonesia'},
#    'geometry': {'type': 'Point', 'coordinates': [102.087, -4.721, 33]},
#    'id': 'usp0009txv'},
#   {'type': 'Feature',
#    'properties': {'mag': 7.2,
#     'place': '75 km N of San Antonio de los Cobres, Argentina',
#     'time': 958156998120,
#     'updated': 1651259787106,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/usp0009suu',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=usp0009suu&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': 5.178,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 798,
#     'net': 'us',
#     'code': 'p0009suu',
#     'ids': ',choy20000512184318,usp0009suu,gcmt20000512184318,duputel051200c,atlas20000512184319,iscgem1837083,',
#     'sources': ',choy,us,gcmt,duputel,atlas,iscgem,',
#     'types': ',focal-mechanism,general-text,impact-text,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.86,
#     'gap': None,
#     'magType': 'mwc',
#     'type': 'earthquake',
#     'title': 'M 7.2 - 75 km N of San Antonio de los Cobres, Argentina'},
#    'geometry': {'type': 'Point', 'coordinates': [-66.452, -23.548, 225]},
#    'id': 'usp0009suu'},
#   {'type': 'Feature',
#    'properties': {'mag': 7.6,
#     'place': '89 km E of Luwuk, Indonesia',
#     'time': 957414076210,
#     'updated': 1651259781382,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/usp0009sbh',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=usp0009sbh&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': 6.715,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 889,
#     'net': 'us',
#     'code': 'p0009sbh',
#     'ids': ',usp0009sbh,choy20000504042116,gcmtc050400a,duputel050400a,gcmt20000504042116,atlas20000504042117,iscgem1836975,',
#     'sources': ',us,choy,gcmt,duputel,gcmt,atlas,iscgem,',
#     'types': ',finite-fault,focal-mechanism,general-text,impact-text,moment-tensor,origin,phase-data,shakemap,trump-shakemap,',
#     'nst': None,
#     'dmin': None,
#     'rms': 1.14,
#     'gap': None,
#     'magType': 'mwc',
#     'type': 'earthquake',
#     'title': 'M 7.6 - 89 km E of Luwuk, Indonesia'},
#    'geometry': {'type': 'Point', 'coordinates': [123.573, -1.105, 26]},
#    'id': 'usp0009sbh'},
#   {'type': 'Feature',
#    'properties': {'mag': 7,
#     'place': '22 km NW of Añatuya, Argentina',
#     'time': 956482043320,
#     'updated': 1651261061054,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/usp0009rrc',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=usp0009rrc&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 754,
#     'net': 'us',
#     'code': 'p0009rrc',
#     'ids': ',choy20000423092723,gcmtc042300b,usp0009rrc,gcmt20000423092723,duputel042300b,atlas20000423092724,iscgem2208257,',
#     'sources': ',choy,gcmt,us,gcmt,duputel,atlas,iscgem,',
#     'types': ',focal-mechanism,general-text,impact-text,moment-tensor,origin,phase-data,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.89,
#     'gap': None,
#     'magType': 'mwb',
#     'type': 'earthquake',
#     'title': 'M 7.0 - 22 km NW of Añatuya, Argentina'},
#    'geometry': {'type': 'Point', 'coordinates': [-62.99, -28.307, 608.5]},
#    'id': 'usp0009rrc'},
#   {'type': 'Feature',
#    'properties': {'mag': 7.6,
#     'place': 'Volcano Islands, Japan region',
#     'time': 954241222510,
#     'updated': 1651257342761,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/usp0009qb4',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=usp0009qb4&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 889,
#     'net': 'us',
#     'code': 'p0009qb4',
#     'ids': ',usp0009qb4,choy20000328110022,gcmtm032800c,duputel032800c,gcmt20000328110022,iscgem1733948,',
#     'sources': ',us,choy,gcmt,duputel,gcmt,iscgem,',
#     'types': ',finite-fault,focal-mechanism,general-text,impact-text,moment-tensor,origin,phase-data,',
#     'nst': None,
#     'dmin': None,
#     'rms': 1.22,
#     'gap': None,
#     'magType': 'mwc',
#     'type': 'earthquake',
#     'title': 'M 7.6 - Volcano Islands, Japan region'},
#    'geometry': {'type': 'Point', 'coordinates': [143.73, 22.338, 126.5]},
#    'id': 'usp0009qb4'},
#   {'type': 'Feature',
#    'properties': {'mag': 7.1,
#     'place': None,
#     'time': 951443038640,
#     'updated': 1651257205979,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/usp0009nxg',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=usp0009nxg&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 776,
#     'net': 'us',
#     'code': 'p0009nxg',
#     'ids': ',choy20000225014358,gcmtc022500b,usp0009nxg,gcmt20000225014358,duputel022500b,iscgem1733126,',
#     'sources': ',choy,gcmt,us,gcmt,duputel,iscgem,',
#     'types': ',focal-mechanism,general-text,moment-tensor,origin,phase-data,',
#     'nst': None,
#     'dmin': None,
#     'rms': 1.2,
#     'gap': None,
#     'magType': 'mwc',
#     'type': 'earthquake',
#     'title': 'M 7.1 - '},
#    'geometry': {'type': 'Point', 'coordinates': [173.818, -19.528, 33]},
#    'id': 'usp0009nxg'},
#   {'type': 'Feature',
#    'properties': {'mag': 7.2,
#     'place': '117 km SSW of Hihifo, Tonga',
#     'time': 947350040580,
#     'updated': 1651261308270,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/usp0009kx3',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=usp0009kx3&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': 5.8,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 798,
#     'net': 'us',
#     'code': 'p0009kx3',
#     'ids': ',choy20000108164720,gcmtc010800g,usp0009kx3,gcmt20000108164720,duputel010800g,iscgem2348979,atlas20000108164718,',
#     'sources': ',choy,gcmt,us,gcmt,duputel,iscgem,atlas,',
#     'types': ',focal-mechanism,general-text,impact-text,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': None,
#     'rms': 1.25,
#     'gap': None,
#     'magType': 'mwc',
#     'type': 'earthquake',
#     'title': 'M 7.2 - 117 km SSW of Hihifo, Tonga'},
#    'geometry': {'type': 'Point', 'coordinates': [-174.248, -16.925, 183.4]},
#    'id': 'usp0009kx3'}],
#  'bbox': [-179.575, -61.029, 4.2, 179.4576, 63.5141, 675.4]}

# %% [markdown]
# **2.2.** Convierta los datos extraídos en un DataFrame con la siguiente estructura:
#
# <div>
# <img src="attachment:image.png" width="600"/>
# </div>

# %%
df=pd.json_normalize(dat['features'])
df
# Out:
#         type          id  properties.mag  \
# 0    Feature  us6000f9sq             7.1
# 1    Feature  us6000f65h             7.2
# 2    Feature  us6000f53e             8.1
# 3    Feature  us6000f4ly             7.5
# 4    Feature  us6000f48v             7.1
# ..       ...         ...             ...
# 321  Feature  usp0009sbh             7.6
# 322  Feature  usp0009rrc             7.0
# 323  Feature  usp0009qb4             7.6
# 324  Feature  usp0009nxg             7.1
# 325  Feature  usp0009kx3             7.2
#
#                           properties.place  properties.time  \
# 0            South Sandwich Islands region    1629667998983
# 1                            Nippes, Haiti    1628944148454
# 2            South Sandwich Islands region    1628793317231
# 3            South Sandwich Islands region    1628793172464
# 4    60 km ENE of Pondaguitan, Philippines    1628703973143
# ..                                     ...              ...
# 321            89 km E of Luwuk, Indonesia     957414076210
# 322         22 km NW of Añatuya, Argentina     956482043320
# 323          Volcano Islands, Japan region     954241222510
# 324                                   None     951443038640
# 325            117 km SSW of Hihifo, Tonga     947350040580
#
#      properties.updated  properties.tz  \
# 0         1635864870040            NaN
# 1         1660684484534            NaN
# 2         1652976332997            NaN
# 3         1635003979040            NaN
# 4         1638599092059            NaN
# ..                  ...            ...
# 321       1651259781382            NaN
# 322       1651261061054            NaN
# 323       1651257342761            NaN
# 324       1651257205979            NaN
# 325       1651261308270            NaN
#
#                                         properties.url  \
# 0    https://earthquake.usgs.gov/earthquakes/eventp...
# 1    https://earthquake.usgs.gov/earthquakes/eventp...
# 2    https://earthquake.usgs.gov/earthquakes/eventp...
# 3    https://earthquake.usgs.gov/earthquakes/eventp...
# 4    https://earthquake.usgs.gov/earthquakes/eventp...
# ..                                                 ...
# 321  https://earthquake.usgs.gov/earthquakes/eventp...
# 322  https://earthquake.usgs.gov/earthquakes/eventp...
# 323  https://earthquake.usgs.gov/earthquakes/eventp...
# 324  https://earthquake.usgs.gov/earthquakes/eventp...
# 325  https://earthquake.usgs.gov/earthquakes/eventp...
#
#                                      properties.detail  properties.felt  ...  \
# 0    https://earthquake.usgs.gov/fdsnws/event/1/que...              2.0  ...
# 1    https://earthquake.usgs.gov/fdsnws/event/1/que...            363.0  ...
# 2    https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN  ...
# 3    https://earthquake.usgs.gov/fdsnws/event/1/que...              3.0  ...
# 4    https://earthquake.usgs.gov/fdsnws/event/1/que...             77.0  ...
# ..                                                 ...              ...  ...
# 321  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN  ...
# 322  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN  ...
# 323  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN  ...
# 324  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN  ...
# 325  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN  ...
#
#                                       properties.types  properties.nst  \
# 0    ,dyfi,finite-fault,general-text,impact-link,in...             NaN
# 1    ,dyfi,earthquake-name,finite-fault,general-tex...             NaN
# 2    ,general-header,general-text,losspager,moment-...             NaN
# 3    ,dyfi,general-header,general-text,ground-failu...             NaN
# 4    ,dyfi,finite-fault,general-text,ground-failure...             NaN
# ..                                                 ...             ...
# 321  ,finite-fault,focal-mechanism,general-text,imp...             NaN
# 322  ,focal-mechanism,general-text,impact-text,mome...             NaN
# 323  ,finite-fault,focal-mechanism,general-text,imp...             NaN
# 324  ,focal-mechanism,general-text,moment-tensor,or...             NaN
# 325  ,focal-mechanism,general-text,impact-text,mome...             NaN
#
#     properties.dmin properties.rms  properties.gap  properties.magType  \
# 0             9.799           0.39            32.0                 mww
# 1             1.178           0.75            23.0                 mww
# 2             7.463           0.76            78.0                 mww
# 3             7.227           1.16            38.0                 mww
# 4             1.273           1.27            25.0                 mww
# ..              ...            ...             ...                 ...
# 321             NaN           1.14             NaN                 mwc
# 322             NaN           0.89             NaN                 mwb
# 323             NaN           1.22             NaN                 mwc
# 324             NaN           1.20             NaN                 mwc
# 325             NaN           1.25             NaN                 mwc
#
#     properties.type                               properties.title  \
# 0        earthquake          M 7.1 - South Sandwich Islands region
# 1        earthquake                          M 7.2 - Nippes, Haiti
# 2        earthquake          M 8.1 - South Sandwich Islands region
# 3        earthquake          M 7.5 - South Sandwich Islands region
# 4        earthquake  M 7.1 - 60 km ENE of Pondaguitan, Philippines
# ..              ...                                            ...
# 321      earthquake            M 7.6 - 89 km E of Luwuk, Indonesia
# 322      earthquake         M 7.0 - 22 km NW of Añatuya, Argentina
# 323      earthquake          M 7.6 - Volcano Islands, Japan region
# 324      earthquake                                       M 7.1 -
# 325      earthquake            M 7.2 - 117 km SSW of Hihifo, Tonga
#
#     geometry.type         geometry.coordinates
# 0           Point      [-24.8743, -60.2845, 6]
# 1           Point      [-73.4822, 18.4335, 10]
# 2           Point  [-25.2637, -58.3753, 22.79]
# 3           Point  [-25.0316, -57.5674, 47.23]
# 4           Point    [126.7151, 6.4748, 55.14]
# ..            ...                          ...
# 321         Point        [123.573, -1.105, 26]
# 322         Point     [-62.99, -28.307, 608.5]
# 323         Point      [143.73, 22.338, 126.5]
# 324         Point       [173.818, -19.528, 33]
# 325         Point   [-174.248, -16.925, 183.4]
#
# [326 rows x 30 columns]

# %% [markdown]
# ## Ejemplo 4:  Webscrapping
#
# Suponga que ud. ha decidido crear un emprendimiento comercial vendiendo tablets, ya que actualmente que son un producto muy demandado para el teletrabajo. Para ello, necesita hacer un estudio de mercado y analizar los precios de venta de la competencia.
#
# En este ejercicio, ud. hará un scrapper de la página de la tienda PCFactory, específicamente del catálogo de tablets ubicado en la siguiente URL: https://www.pcfactory.cl/tablets?categoria=967&papa=636.
#
# **3.1** Analice cuidadosamente el código HTML de la página y determine: ¿qué tag o atributo permite identificar el listado de productos con sus respectivas características (nombre, marca, precio)?

# %% [markdown]
# **Respuesta**: hay distintas opciones, dependiendo de cómo hayan inspeccionado la página e implementado el scrapper.
#
# "<input type="hidden" id="data_mentalidad_web"" ==> listado con todos los productos y sus atributos
#
# "<div class="product-list"> <div class="product" data-class="Caluga">" ==> grid que se puede iterar para extraer la información de cada producto
#
# Cualquier alternativa (u otra es válida), en la medida que permita identificar la sección del código HTML que se debe extraer para hacer scarpping de todos los productos, y que sea coherente con lo implementado en la parte 3.2.

# %% [markdown]
# **3.2** Obtenga el código web de la página y extraiga la información de interés, de manera de llegar a un DataFrame.

# %%
import requests, json
import pandas as pd
from bs4 import BeautifulSoup 

main_url = " https://www.pcfactory.cl/tablets?categoria=967&papa=636"

session = requests.Session()
response = session.get(main_url)

result = requests.get(main_url,cookies=session.cookies)
soup = BeautifulSoup(result.text, 'html.parser')
catalog= soup.find_all('input',attrs={"id": "data_mentalidad_web"})
catalog
# Out:
# [<input data-type="json" id="data_mentalidad_web" type="hidden" value='[{"name":"Tablet Space 7\" 1GB 16GB WiFi Quad Core Android","id":"43812","price":"30890","brand":"Gear","category":"Tablets","variant":"","list":"Categor\u00edas","position":2},{"name":"Tablet Space 7\" 1GB 16GB WiFi Quad Core Android","id":"44178","price":"30890","brand":"Gear","category":"Tablets","variant":"","list":"Categor\u00edas","position":4},{"name":"Tablet Space 7\" 1GB 16GB WiFi Quad Core Android","id":"44247","price":"30890","brand":"Gear","category":"Tablets","variant":"","list":"Categor\u00edas","position":6},{"name":"Tablet Space Kids 7\" 1GB 16GB WiFi Quad Core Android + Carcasa Monster","id":"43813","price":"36090","brand":"Gear","category":"Tablets","variant":"","list":"Categor\u00edas","position":8},{"name":"Tablet Space Kids 7\" 1GB 16GB WiFi Quad Core Android + Carcasa Monster","id":"44188","price":"36090","brand":"Gear","category":"Tablets","variant":"","list":"Categor\u00edas","position":10},{"name":"Tablet Space Kids 7\" 1GB 16GB WiFi Quad Core Android + Carcasa Monster","id":"44248","price":"36090","brand":"Gear","category":"Tablets","variant":"","list":"Categor\u00edas","position":12},{"name":"Tablet Tab M7 7\" HD 1GB 16GB 4G LTE Onix Black","id":"41836","price":"72190","brand":"Lenovo","category":"Tablets","variant":"","list":"Categor\u00edas","position":14},{"name":"Tablet SoyMomo Lite 2.0 7\" 2GB 16GB Wifi Quad Core Android Rosado","id":"45068","price":"72190","brand":"SoyMomo","category":"Tablets","variant":"","list":"Categor\u00edas","position":16},{"name":"Tablet Pro T310 10,1\" 2GB 32GB WiFi Quad Core Android ","id":"43421","price":"87590","brand":"Gear","category":"Tablets","variant":"","list":"Categor\u00edas","position":18},{"name":"Tablet M7 2GB RAM 32GB 7\" HD Wifi Iron grey","id":"45200","price":"87590","brand":"Lenovo","category":"Tablets","variant":"","list":"Categor\u00edas","position":20},{"name":"Kindle Touch 6\" 8GB Luz frontal ajustable WiFi Blanco","id":"40918","price":"90690","brand":"Kindle","category":"Tablets","variant":"","list":"Categor\u00edas","position":22},{"name":"Kindle Touch 6\" 8GB Luz frontal ajustable WiFi Negro ","id":"40101","price":"90690","brand":"Kindle","category":"Tablets","variant":"","list":"Categor\u00edas","position":24},{"name":"Kindle Touch 6\" 8GB Luz frontal ajustable WiFi Negro","id":"40917","price":"90690","brand":"Kindle","category":"Tablets","variant":"","list":"Categor\u00edas","position":26},{"name":"Kindle Touch 6\" 8GB Luz frontal ajustable WiFi Negro ","id":"44765","price":"90690","brand":"Kindle","category":"Tablets","variant":"","list":"Categor\u00edas","position":28},{"name":"Kindle Touch 6\" 8GB Luz frontal ajustable WiFi Blanco","id":"44767","price":"90690","brand":"Kindle","category":"Tablets","variant":"","list":"Categor\u00edas","position":30},{"name":"Tablet Tab M7 3rd Gen 7\" HD 2GB 32GB 4G LTE Iron grey","id":"43205","price":"103090","brand":"Lenovo","category":"Tablets","variant":"","list":"Categor\u00edas","position":32},{"name":"Tablet  Pro T618 10,1\" 4GB 64GB WiFi Octa Core Android","id":"43420","price":"103090","brand":"Gear","category":"Tablets","variant":"","list":"Categor\u00edas","position":34},{"name":"Tablet SoyMomo Pro 8\" 2GB 32GB WiFi Octa Core Android Azul","id":"45067","price":"103090","brand":"SoyMomo","category":"Tablets","variant":"","list":"Categor\u00edas","position":36},{"name":"Tablet MatePad T10 9.7\" 2GB 32GB WiFi Deepsea Blue","id":"41923","price":"113390","brand":"Huawei","category":"Tablets","variant":"","list":"Categor\u00edas","position":38},{"name":"Tablet Smart M8 8\" 2GB 32GB WiFi con Estaci\u00f3n de Carga Inteligente y Google Assitant Iron Grey","id":"37245","price":"113390","brand":"Lenovo","category":"Tablets","variant":"","list":"Categor\u00edas","position":40},{"name":"Tablet Tab M10 2GB 32GB 10.1\" Iron Grey WIFI","id":"43300","price":"123690","brand":"Lenovo","category":"Tablets","variant":"","list":"Categor\u00edas","p ...

# %%
session = requests.Session()
response = session.get(main_url)
print(session.cookies)
# Out:
# <RequestsCookieJar[<Cookie Queue-it=u=d3d46ca3-145d-4617-a018-307d0c7cc389 for .queue-it.net/>, <Cookie Queue-it-pcfactory___________cyber202210=Cid=es-CL&f=0 for pcfactory.queue-it.net/>, <Cookie PHPSESSID=6qr2u5vn17aldoor09lgropfkh for www.pcfactory.cl/>, <Cookie QueueITAccepted-SDFrts345E-V3_cyber202210=EventId%3Dcyber202210%26QueueId%3D00000000-0000-0000-0000-000000000000%26RedirectType%3Dafterevent%26IssueTime%3D1665719661%26Hash%3D6bfba0ba729fcf5bb59fd938ccb56af97d9816c0cb779162123e5f56d9ad86ff for www.pcfactory.cl/>]>

# %%
products=catalog[0].attrs['value']

prods=json.loads(products)
prods
# Out:
# [{'name': 'Tablet Space 7" 1GB 16GB WiFi Quad Core Android',
#   'id': '43812',
#   'price': '30890',
#   'brand': 'Gear',
#   'category': 'Tablets',
#   'variant': '',
#   'list': 'Categorías',
#   'position': 2},
#  {'name': 'Tablet Space 7" 1GB 16GB WiFi Quad Core Android',
#   'id': '44178',
#   'price': '30890',
#   'brand': 'Gear',
#   'category': 'Tablets',
#   'variant': '',
#   'list': 'Categorías',
#   'position': 4},
#  {'name': 'Tablet Space 7" 1GB 16GB WiFi Quad Core Android',
#   'id': '44247',
#   'price': '30890',
#   'brand': 'Gear',
#   'category': 'Tablets',
#   'variant': '',
#   'list': 'Categorías',
#   'position': 6},
#  {'name': 'Tablet Space Kids 7" 1GB 16GB WiFi Quad Core Android + Carcasa Monster',
#   'id': '43813',
#   'price': '36090',
#   'brand': 'Gear',
#   'category': 'Tablets',
#   'variant': '',
#   'list': 'Categorías',
#   'position': 8},
#  {'name': 'Tablet Space Kids 7" 1GB 16GB WiFi Quad Core Android + Carcasa Monster',
#   'id': '44188',
#   'price': '36090',
#   'brand': 'Gear',
#   'category': 'Tablets',
#   'variant': '',
#   'list': 'Categorías',
#   'position': 10},
#  {'name': 'Tablet Space Kids 7" 1GB 16GB WiFi Quad Core Android + Carcasa Monster',
#   'id': '44248',
#   'price': '36090',
#   'brand': 'Gear',
#   'category': 'Tablets',
#   'variant': '',
#   'list': 'Categorías',
#   'position': 12},
#  {'name': 'Tablet Tab M7 7" HD 1GB 16GB 4G LTE Onix Black',
#   'id': '41836',
#   'price': '72190',
#   'brand': 'Lenovo',
#   'category': 'Tablets',
#   'variant': '',
#   'list': 'Categorías',
#   'position': 14},
#  {'name': 'Tablet SoyMomo Lite 2.0 7" 2GB 16GB Wifi Quad Core Android Rosado',
#   'id': '45068',
#   'price': '72190',
#   'brand': 'SoyMomo',
#   'category': 'Tablets',
#   'variant': '',
#   'list': 'Categorías',
#   'position': 16},
#  {'name': 'Tablet Pro T310 10,1" 2GB 32GB WiFi Quad Core Android ',
#   'id': '43421',
#   'price': '87590',
#   'brand': 'Gear',
#   'category': 'Tablets',
#   'variant': '',
#   'list': 'Categorías',
#   'position': 18},
#  {'name': 'Tablet M7 2GB RAM 32GB 7" HD Wifi Iron grey',
#   'id': '45200',
#   'price': '87590',
#   'brand': 'Lenovo',
#   'category': 'Tablets',
#   'variant': '',
#   'list': 'Categorías',
#   'position': 20},
#  {'name': 'Kindle Touch 6" 8GB Luz frontal ajustable WiFi Blanco',
#   'id': '40918',
#   'price': '90690',
#   'brand': 'Kindle',
#   'category': 'Tablets',
#   'variant': '',
#   'list': 'Categorías',
#   'position': 22},
#  {'name': 'Kindle Touch 6" 8GB Luz frontal ajustable WiFi Negro ',
#   'id': '40101',
#   'price': '90690',
#   'brand': 'Kindle',
#   'category': 'Tablets',
#   'variant': '',
#   'list': 'Categorías',
#   'position': 24},
#  {'name': 'Kindle Touch 6" 8GB Luz frontal ajustable WiFi Negro',
#   'id': '40917',
#   'price': '90690',
#   'brand': 'Kindle',
#   'category': 'Tablets',
#   'variant': '',
#   'list': 'Categorías',
#   'position': 26},
#  {'name': 'Kindle Touch 6" 8GB Luz frontal ajustable WiFi Negro ',
#   'id': '44765',
#   'price': '90690',
#   'brand': 'Kindle',
#   'category': 'Tablets',
#   'variant': '',
#   'list': 'Categorías',
#   'position': 28},
#  {'name': 'Kindle Touch 6" 8GB Luz frontal ajustable WiFi Blanco',
#   'id': '44767',
#   'price': '90690',
#   'brand': 'Kindle',
#   'category': 'Tablets',
#   'variant': '',
#   'list': 'Categorías',
#   'position': 30},
#  {'name': 'Tablet Tab M7 3rd Gen 7" HD 2GB 32GB 4G LTE Iron grey',
#   'id': '43205',
#   'price': '103090',
#   'brand': 'Lenovo',
#   'category': 'Tablets',
#   'variant': '',
#   'list': 'Categorías',
#   'position': 32},
#  {'name': 'Tablet  Pro T618 10,1" 4GB 64GB WiFi Octa Core Android',
#   'id': '43420',
#   'price': '103090',
#   'brand': 'Gear',
#   'category': 'Tablets',
#   'variant': '',
#   'list': 'Categorías',
#   'position': 34},
#  {'name': 'Tablet SoyMomo Pro 8" 2GB 32GB WiFi Octa Core Android Azul',
#   'id': '45067',
#   'price': '103090',
#   'brand': 'SoyMomo',
#   'category': 'Tablets',
#   'variant': '',
#   'list': 'Categorías',
#   'position': 36},
#  {'name': 'Tablet MatePad T10 9.7" 2GB 32GB WiFi Deepsea Blue',
#   'id': '41923',
#   'price': '113390',
#   'brand': 'Huawei',
#   'category': 'Tablets',
#   'variant': '',
#   'list': 'Categorías',
#   'position': 38},
#  {'name': 'Tablet Smart M8 8" 2GB 32GB WiFi con Estación de Carga Inteligente y Google Assitant Iron Grey',
#   'id': '37245',
#   'price': '113390',
#   'brand': 'Lenovo',
#   'category': 'Tablets',
#   'variant': '',
#   'list': 'Categorías',
#   'position': 40},
#  {'name': 'Tablet Tab M10 2GB 32GB 10.1" Iron Grey WIFI',
#   'id': '43300',
#   'price': '123690',
#   'brand': 'Lenovo',
#   'category': 'Tablets',
#   'variant': '',
#   'list': 'Categorías',
#   'position': 42},
#  {'name': 'Tablet  Tab M8 8" 2GB 32GB WiFi Quad Core Android Iron Grey',
#   'id': '36684',
#   'price': '123690',
#   'brand': 'Lenovo',
#   'category': 'Tablets',
#   'variant': '',
#   'list': 'Categorías',
#   'position': 44},
#  {'name': 'Tablet Galaxy Tab A7 Lite 8.7" 3GB 32GB WIFI Octa Core Android Dark Grey',
#   'id': '41832',
#   'price': '123690',
#   'brand': 'Samsung',
#   'category': 'Tablets',
#   'variant': '',
#   'list': 'Categorías',
#   'position': 46},
#  {'name': 'Tablet MatePad T10 LTE 9.7" 2GB 32GB WiFi Deepsea Blue ',
#   'id': '45659',
#   'price': '123690',
#   'brand': 'Huawei',
#   'category': 'Tablets',
#   'variant': '',
#   'list': 'Categorías',
#   'position': 48},
#  {'name': 'Tablet Galaxy Tab A7 Lite 8.7" 3GB 32GB WIFI Octa Core Android Silver',
#   'id': '46733',
#   'price': '123690',
#   'brand': 'Samsung',
#   'category': 'Tablets',
#   'variant': '',
#   'list': 'Categorías',
#   'position': 50},
#  {'name': 'Kindle Paperwhite Waterproof 6" WiFi 8GB  Negro',
#   'id': '40916',
#   'price': '131990',
#   'brand': 'Kindle',
#   'category': 'Tablets',
#   'variant': '',
#   'list': 'Categorías',
#   'position': 52},
#  {'name': 'Kindle Paperwhite Waterproof 6” WiFi  8GB Azul',
#   'id': '43360',
#   'price': '131990',
#   'brand': 'Kindle',
#   'category': 'Tablets',
#   'variant': '',
#   'list': 'Categorías',
#   'position': 54},
#  {'name': 'Kindle Paperwhite Waterproof 6" WiFi 8GB Negro',
#   'id': '44768',
#   'price': '131990',
#   'brand': 'Kindle',
#   'category': 'Tablets',
#   'variant': '',
#   'list': 'Categorías',
#   'position': 56},
#  {'name': 'Tablet Matepad T8 8" 2GB 32GB WiFi Deepsea Blue',
#   'id': '38071',
#   'price': '133990',
#   'brand': 'Huawei',
#   'category': 'Tablets',
#   'variant': '',
#   'list': 'Categorías',
#   'position': 58},
#  {'name': 'Tablet MatePad T10 Kid 9.7" 2GB 32GB WiFi Deepsea Blue',
#   'id': '42704',
#   'price': '144290',
#   'brand': 'Huawei',
#   'category': 'Tablets',
#   'variant': '',
#   'list': 'Categorías',
#   'position': 60},
#  {'name': 'Tablet Smart Tab M10 10.1" HD 4GB 64GB Octa Core Iron Grey WiFi',
#   'id': '41837',
#   'price': '144290',
#   'brand': 'Lenovo',
#   'category': 'Tablets',
#   'variant': '',
#   'list': 'Categorías',
#   'position': 62},
#  {'name': 'Tablet Matepad T10s 10.1" 4GB 64GB WiFi Deepsea Blue ',
#   'id': '44740',
#   'price': '144290',
#   'brand': 'Huawei',
#   'category': 'Tablets',
#   'variant': '',
#   'list': 'Categorías',
#   'position': 64},
#  {'name': 'Tablet SoyMomo Pro 2.0 8" 4GB 64GB Wifi Octa Core Android Azul',
#   'id': '45069',
#   'price': '154590',
#   'brand': 'SoyMomo',
#   'category': 'Tablets',
#   'variant': '',
#   'list': 'Categorías',
#   'position': 66},
#  {'name': 'Tablet Tab M10 Plus 10.3" 4GB 64GB WiFi  Platinum Grey',
#   'id': '37868',
#   'price': '175290',
#   'brand': 'Lenovo',
#   'category': 'Tablets',
#   'variant': '',
#   'list': 'Categorías',
#   'position': 68},
#  {'name': 'Tablet MatePad T10S 10,1" 4GB 128GB WiFi Deepsea Blue ',
#   'id': '45658',
#   'price': '175290',
#   'brand': 'Huawei',
#   'category': 'Tablets',
#   'variant': '',
#   'list': 'Categorías',
#   'position': 70},
#  {'name': 'Tablet Frozen SoyMomo Pro 2.0 8" 4GB 64GB Wifi Octa Core Android',
#   'id': '46474',
#   'price': '175290',
#   'brand': 'SoyMomo',
#   'category': 'Tablets',
#   'variant': '',
#   'list': 'Categorías',
#   'position': 72},
#  {'name': 'Tablet Marvel SoyMomo Pro 2.0 8" 4GB 64GB Wifi Octa Core Android',
#   'id': '46475',
#   'price': '175290',
#   'brand': 'SoyMomo',
#   'category': 'Tablets',
#   'variant': '',
#   'list': 'Categorías',
#   'position': 74},
#  {'name': 'Tablet Lightyear SoyMomo Pro 2.0 8" 4GB 64GB Wifi Octa Core Android ',
#   'id': '46476',
#   'price': '175290',
#   'brand': 'SoyMomo',
#   'category': 'Tablets',
#   'variant': '',
#   'list': 'Categorías',
#   'position': 76},
#  {'name': 'Tablet Yoga Smart 10.1" 4GB 64GB WiFi OctaCore Android Iron Grey Google Assistant',
#   'id': '37732',
#   'price': '185590',
#   'brand': 'Lenovo',
#   'category': 'Tablets',
#   'variant': '',
#   'list': 'Categorías',
#   'position': 78},
#  {'name': 'Tablet Galaxy Tab A8 10.5" 3GB 32GB WiFi con BookCover Gray',
#   'id': '44882',
#   'price': '185590',
#   'brand': 'Samsung',
#   'category': 'Tablets',
#   'variant': '',
#   'list': 'Categorías',
#   'position': 80},
#  {'name': 'Tablet M10 Plus 4GB 128GB 10.3" FHD WiFi platinum grey',
#   'id': '45203',
#   'price': '195890',
#   'brand': 'Lenovo',
#   'category': 'Tablets',
#   'variant': '',
#   'list': 'Categorías',
#   'position': 82},
#  {'name': 'Tablet MatePad T10S 10.1" FHD 3GB 64GB WiFi Android Deepsea Blue',
#   'id': '43540',
#   'price': '199990',
#   'brand': 'Huawei',
#   'category': 'Tablets',
#   'variant': '',
#   'list': 'Categorías',
#   'position': 84},
#  {'name': 'Tablet Galaxy Tab A8 10.5" 4GB 64GB WiFi con BookCover Gray ',
#   'id': '44881',
#   'price': '206190',
#   'brand': 'Samsung',
#   'category': 'Tablets',
#   'variant': '',
#   'list': 'Categorías',
#   'position': 86},
#  {'name': 'Tablet Galaxy Tab A8 Lite 10.5" 3GB 32GB WiFi 4G con BookCover Gray ',
#   'id': '44884',
#   'price': '226790',
#   'brand': 'Samsung',
#   'category': 'Tablets',
#   'variant': '',
#   'list': 'Categorías',
#   'position': 88},
#  {'name': 'Tablet Galaxy Tab A8 10.5" 4GB 64GB WiFi con Book Cover Pink Gold',
#   'id': '44880',
#   'price': '289990',
#   'brand': 'Samsung',
#   'category': 'Tablets',
#   'variant': '',
#   'list': 'Categorías',
#   'position': 90},
#  {'name': 'Tablet MatePad 10.4" 4GB 128GB Wifi con Keyboard + Lapiz Midnight Grey Bach4-W09DS',
#   'id': '44739',
#   'price': '309290',
#   'brand': 'Huawei',
#   'category': 'Tablets',
#   'variant': '',
#   'list': 'Categorías',
#   'position': 92},
#  {'name': 'Tablet Galaxy Tab S6 Lite 10.4" 4GB 64GB WiFi con S Pen y BookCover Dark Gray',
#   'id': '46770',
#   'price': '319590',
#   'brand': 'Samsung',
#   'category': 'Tablets',
#   'variant': '',
#   'list': 'Categorías',
#   'position': 94},
#  {'name': 'Tablet Galaxy Tab S6 Lite 10.4" 4GB 64GB WiFi con S Pen y BookCover Blue',
#   'id': '47174',
#   'price': '319590',
#   'brand': 'Samsung',
#   'category': 'Tablets',
#   'variant': '',
#   'list': 'Categorías',
#   'position': 96}]

# %%
df=pd.DataFrame(columns=['name', 'id', 'price', 'brand','variant','list'])
for prod in prods:
    df=df.append({'name':prod['name'], 'id':prod['id'], 'price':prod['price'], 'brand':prod['brand'],'variant':prod['variant'],'list':prod['list']},ignore_index=True)

df.to_csv('productos.csv')
