# %%
#código de inicio
import pandas as pd
import numpy as np

# %% [markdown]
# # <img style="float: left; padding-right: 20px; width: 100px" src="https://upload.wikimedia.org/wikipedia/commons/thumb/8/84/Escudo_de_la_Pontificia_Universidad_Cat%C3%B3lica_de_Chile.svg/1920px-Escudo_de_la_Pontificia_Universidad_Cat%C3%B3lica_de_Chile.svg.png"> MCD3020 - Introducción a Ciencia de Datos
# **Pontificia Universidad Católica de Chile**<br>
# **Magíster en Ciencia de Datos**<br>
# **2022**<br>
#
# ----

# %% [markdown]
# # Tarea 2: Limpieza y combinación de datos.
#
# ***
# ## Instrucciones Generales:
# - Esta Tarea debe ser desarrollada completamente en lenguaje de programación Python, en este mismo Notebook.
# - El Notebook debe estar  ordenado, seguir buenas prácticas de escritura y programación, e incluir comentarios o celdas de markdown suficientes para explicar claramente todos lo códigos computacionales.
# - El Notebook ya contiene algunas celdas marcadas con el comentario `#código de inicio`. Estas celdas han sido incluidas como ayuda para el desarrollo de la Tarea, y pueden ser ejecutadas tal como están.
# - Las celdas marcadas como `#completar código` tienen un código parcial que debe ser completado para poder ser ejecutado. Ud debe agregar todas las líneas o bloques de código necesarios para desarrollar correctamente cada punto de la tarea. También puede eliminar estas celdas y partir el código desde cero si le resulta más conveniente.
#
# ***
# ## Introducción.
#
# Hace ya casi 10 años, el trabajo de científico de datos fue catalogado por Harvard Bussiness Review como "el trabajo más atractivo del siglo XXI" [(Davenport & Patil 2012)](https://hbr.org/2012/10/data-scientist-the-sexiest-job-of-the-21st-century). Desde entonces, se ha comprobado un aumento constante de la demanda por profesionales expertos datos, y se espera que tanto la creación de puestos trabajos como los salarios sigan al alza en los próximos años. Los siguienes artículos de prensa y difusión ilustran esta situación:
#
# https://www.smithhanley.com/2022/01/04/data-science-in-2022/
# https://www.bbva.com/es/big-data-la-demanda-de-talento-experto-sigue-creciendo/
#
# Los estudios citados hacen referencia a mercados laborales en Europa y Estados Unidos. Suponga que ud.está a cargo del desarrollo de un estudio del mercado laboral de científicos de datos en latinoamérica, para lo cual necesita construir, procesar y analizar una base de datos con las ofertas de trabajo publicadas en distintos países de la región.
#
# En la **Tarea 1**, ud. avanzó en la primera etapa de construcción de la base de datos, utilizando web scraping para extraer los datos de ofertas de empleo en *data science* publicados en la red Linkedin, para una ciudad o país. Este proceso fue repetido y ampliado para todos los países de sudamérica, dando origen a un conjunto de bases de datos que serán su insumos para la siguiente etapa del proceso de ciencia de datos.
#
# Para considerar en el análisis el contexto económico y tecnológico de cada país, entre los datos se incluirán también otras variables como el *Índice global de innovación* (https://www.globalinnovationindex.org/Home), disponible online para distintos países del mundo.
#
# En esta **Tarea 2**, ud. deberá integrar, limpiar y procesar las bases de datos obtenidas de distintas fuentes, de manera de obtener un conjunto de datos apto para distintos tipos de análisis.

# %% [markdown]
# ## Datos de Entrada.
#
# Los datos ofertas laborales de *data science* publicadas en Linkedin para los países de sudamérica están disponibles para lectura o descarga en los siguientes links:
#
# * https://raw.githubusercontent.com/paguirre-uc/mds3020_2022/main/tarea2/jobsLinkedin_Argentina_t2.csv
# * https://raw.githubusercontent.com/paguirre-uc/mds3020_2022/main/tarea2/jobsLinkedin_Bolivia_t2.csv
# * https://raw.githubusercontent.com/paguirre-uc/mds3020_2022/main/tarea2/jobsLinkedin_Brasil_t2.csv
# * https://raw.githubusercontent.com/paguirre-uc/mds3020_2022/main/tarea2/jobsLinkedin_Chile_t2.csv
# * https://raw.githubusercontent.com/paguirre-uc/mds3020_2022/main/tarea2/jobsLinkedin_Colombia_t2.csv
# * https://raw.githubusercontent.com/paguirre-uc/mds3020_2022/main/tarea2/jobsLinkedin_Guyana_t2.csv
# * https://raw.githubusercontent.com/paguirre-uc/mds3020_2022/main/tarea2/jobsLinkedin_Ecuador_t2.csv
# * https://raw.githubusercontent.com/paguirre-uc/mds3020_2022/main/tarea2/jobsLinkedin_Paraguay_t2.csv
# * https://raw.githubusercontent.com/paguirre-uc/mds3020_2022/main/tarea2/jobsLinkedin_Peru_t2.csv
# * https://raw.githubusercontent.com/paguirre-uc/mds3020_2022/main/tarea2/jobsLinkedin_Suriname_t2.csv
# * https://raw.githubusercontent.com/paguirre-uc/mds3020_2022/main/tarea2/jobsLinkedin_Uruguay_t2.csv
# * https://raw.githubusercontent.com/paguirre-uc/mds3020_2022/main/tarea2/jobsLinkedin_Venezuela_t2.csv
#
# Además, se han descargado desde la página https://www.globalinnovationindex.org/analysis-indicator/ los datos de Índice de Innovación Global para el año 2022, disponibles en el siguiente archivo:
#
# https://raw.githubusercontent.com/paguirre-uc/mds3020_2022/main/tarea2/indiceInnovacionPaises.csv

# %% [markdown]
# ### 1. Lea todos los conjuntos de datos entregados, y concatenelos para generar un único dataframe con todas las ofertas laborales de Data Scientist publicadas en Linkedin para los países de sudamérica.
#
# *Funciones útiles*: `pandas.concat()`

# %%
#completar codigo

locations = ['Chile','Argentina','Peru','Colombia','Ecuador','Brasil','Venezuela','Uruguay','Paraguay','Bolivia','Suriname','Guyana']

alldf=[]

for loc in locations:
    url = f'https://raw.githubusercontent.com/paguirre-uc/mds3020_2022/main/tarea2/jobsLinkedin_{loc}_t2.csv'
    df = pd.read_csv(url, sep=',')
    alldf.append(df)
    
    
alldf = pd.concat(alldf)
alldf
# Out:
#     Unnamed: 0 Country                                       Location  \
# 0            0   Chile  Santiago, Santiago Metropolitan Region, Chile
# 1            1   Chile  Santiago, Santiago Metropolitan Region, Chile
# 2            2   Chile  Santiago, Santiago Metropolitan Region, Chile
# 3            3   Chile              Rancagua, O'Higgins Region, Chile
# 4            4   Chile  Santiago, Santiago Metropolitan Region, Chile
# ..         ...     ...                                            ...
# 121        256  Guyana                                         Guyana
# 122        275  Guyana           Georgetown, Demerara-Mahaica, Guyana
# 123        310  Guyana              Mahaica, Demerara-Mahaica, Guyana
# 124        322  Guyana                                         Guyana
# 125        334  Guyana                 No. 3, Mahaica-Berbice, Guyana
#
#                                                  Title         Company  \
# 0                                       Data Scientist       BICE VIDA
# 1                                       Data Scientist      BNamericas
# 2                                      Data Scientist.  Fuerza Laboral
# 3                                       Data Scientist       Agrosuper
# 4                                       Data Scientist   MAS Analytics
# ..                                                 ...             ...
# 121                              Sr. Platform Engineer            Aha!
# 122  Operations Intelligence Performance Optimizati...    SBM Offshore
# 123                              Sr. Platform Engineer            Aha!
# 124                             Ruby on Rails Engineer            Aha!
# 125                                      Data Engineer       Univision
#
#                                                    Url  \
# 0    https://cl.linkedin.com/jobs/view/data-scienti...
# 1    https://cl.linkedin.com/jobs/view/data-scienti...
# 2    https://cl.linkedin.com/jobs/view/data-scienti...
# 3    https://cl.linkedin.com/jobs/view/data-scienti...
# 4    https://cl.linkedin.com/jobs/view/data-scienti...
# ..                                                 ...
# 121  https://gy.linkedin.com/jobs/view/sr-platform-...
# 122  https://gy.linkedin.com/jobs/view/operations-i...
# 123  https://gy.linkedin.com/jobs/view/sr-platform-...
# 124  https://gy.linkedin.com/jobs/view/ruby-on-rail...
# 125  https://gy.linkedin.com/jobs/view/data-enginee...
#
#                             Postulaciones  \
# 0                                     NaN
# 1    \n          42 solicitudes\n
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# ..                                    ...
# 121                                   NaN
# 122                                   NaN
# 123                                   NaN
# 124                                   NaN
# 125                                   NaN
#
#                                     Jornada  \
# 0    \n          Jornada completa\n
# 1    \n          Jornada completa\n
# 2    \n          Jornada completa\n
# 3    \n          Jornada completa\n
# 4    \n          Jornada completa\n
# ..                                      ...
# 121                                     NaN
# 122         \n          Full-time\n
# 123         \n          Full-time\n
# 124         \n          Full-time\n
# 125         \n          Full-time\n
#
#                                      Antiguedad
# 0      \n            No corresponde\n
# 1     \n            Sin experiencia\n
# 2     \n            Sin experiencia\n
# 3          \n            Intermedio\n
# 4      \n            No corresponde\n
# ..                                          ...
# 121                                         NaN
# 122       \n            Entry level\n
# 123  \n            Mid-Senior level\n
# 124       \n            Entry level\n
# 125       \n            Entry level\n
#
# [1023 rows x 9 columns]

# %% [markdown]
# ### 2. ¿Existe alguna columna innecesaria o inútil en su dataframe? Justifique, y en caso necesario, elimine la(s) columna(s) de sobra.

# %% [markdown]
# Revisamos las columnas y su información

# %%
alldf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1023 entries, 0 to 125
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     1023 non-null   object
#  1   Country        1023 non-null   object
#  2   Location       1023 non-null   object
#  3   Title          1023 non-null   object
#  4   Company        1023 non-null   object
#  5   Url            1023 non-null   object
#  6   Postulaciones  183 non-null    object
#  7   Jornada        693 non-null    object
#  8   Antiguedad     713 non-null    object
# dtypes: object(9)
# memory usage: 79.9+ KB

# %% [markdown]
# Podemos ver que la columna *Unnamed: 0* no aporta valor, dado que se autogeneró al existir una coma como primer caracter del csv. La borramos.

# %%
alldf.drop('Unnamed: 0', axis=1, inplace=True)
alldf
# Out:
#     Country                                       Location  \
# 0     Chile  Santiago, Santiago Metropolitan Region, Chile
# 1     Chile  Santiago, Santiago Metropolitan Region, Chile
# 2     Chile  Santiago, Santiago Metropolitan Region, Chile
# 3     Chile              Rancagua, O'Higgins Region, Chile
# 4     Chile  Santiago, Santiago Metropolitan Region, Chile
# ..      ...                                            ...
# 121  Guyana                                         Guyana
# 122  Guyana           Georgetown, Demerara-Mahaica, Guyana
# 123  Guyana              Mahaica, Demerara-Mahaica, Guyana
# 124  Guyana                                         Guyana
# 125  Guyana                 No. 3, Mahaica-Berbice, Guyana
#
#                                                  Title         Company  \
# 0                                       Data Scientist       BICE VIDA
# 1                                       Data Scientist      BNamericas
# 2                                      Data Scientist.  Fuerza Laboral
# 3                                       Data Scientist       Agrosuper
# 4                                       Data Scientist   MAS Analytics
# ..                                                 ...             ...
# 121                              Sr. Platform Engineer            Aha!
# 122  Operations Intelligence Performance Optimizati...    SBM Offshore
# 123                              Sr. Platform Engineer            Aha!
# 124                             Ruby on Rails Engineer            Aha!
# 125                                      Data Engineer       Univision
#
#                                                    Url  \
# 0    https://cl.linkedin.com/jobs/view/data-scienti...
# 1    https://cl.linkedin.com/jobs/view/data-scienti...
# 2    https://cl.linkedin.com/jobs/view/data-scienti...
# 3    https://cl.linkedin.com/jobs/view/data-scienti...
# 4    https://cl.linkedin.com/jobs/view/data-scienti...
# ..                                                 ...
# 121  https://gy.linkedin.com/jobs/view/sr-platform-...
# 122  https://gy.linkedin.com/jobs/view/operations-i...
# 123  https://gy.linkedin.com/jobs/view/sr-platform-...
# 124  https://gy.linkedin.com/jobs/view/ruby-on-rail...
# 125  https://gy.linkedin.com/jobs/view/data-enginee...
#
#                             Postulaciones  \
# 0                                     NaN
# 1    \n          42 solicitudes\n
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# ..                                    ...
# 121                                   NaN
# 122                                   NaN
# 123                                   NaN
# 124                                   NaN
# 125                                   NaN
#
#                                     Jornada  \
# 0    \n          Jornada completa\n
# 1    \n          Jornada completa\n
# 2    \n          Jornada completa\n
# 3    \n          Jornada completa\n
# 4    \n          Jornada completa\n
# ..                                      ...
# 121                                     NaN
# 122         \n          Full-time\n
# 123         \n          Full-time\n
# 124         \n          Full-time\n
# 125         \n          Full-time\n
#
#                                      Antiguedad
# 0      \n            No corresponde\n
# 1     \n            Sin experiencia\n
# 2     \n            Sin experiencia\n
# 3          \n            Intermedio\n
# 4      \n            No corresponde\n
# ..                                          ...
# 121                                         NaN
# 122       \n            Entry level\n
# 123  \n            Mid-Senior level\n
# 124       \n            Entry level\n
# 125       \n            Entry level\n
#
# [1023 rows x 8 columns]

# %% [markdown]
# En segundo lugar, vemos que la columna `Postulaciones` tiene aproximadamente un 85% de datos nulos. De todas maneras, se puede procesar esa columna para que los datos nulos sean 0, dado que es la cantidad de postulaciones que existen en curso. A priori no la eliminaría, sino que llenaría los nulos con 0.

# %% [markdown]
# En tercer lugar, las columnas `Jornada` y `Antiguedad` no deben ser borradas, pese a tener una cantidad significativa de nulos (la mitad aproximadamente), no es lo suficientemente poco para borrarlas, considerando una convención del 5%. Lo ideal sería tratar de recolectar esos datos faltantes con precisión.

# %% [markdown]
# Finalmente, reseteamos los indices de nuestro dataset.

# %%
alldf.reset_index(inplace=True, drop=True)
alldf
# Out:
#      Country                                       Location  \
# 0      Chile  Santiago, Santiago Metropolitan Region, Chile
# 1      Chile  Santiago, Santiago Metropolitan Region, Chile
# 2      Chile  Santiago, Santiago Metropolitan Region, Chile
# 3      Chile              Rancagua, O'Higgins Region, Chile
# 4      Chile  Santiago, Santiago Metropolitan Region, Chile
# ...      ...                                            ...
# 1018  Guyana                                         Guyana
# 1019  Guyana           Georgetown, Demerara-Mahaica, Guyana
# 1020  Guyana              Mahaica, Demerara-Mahaica, Guyana
# 1021  Guyana                                         Guyana
# 1022  Guyana                 No. 3, Mahaica-Berbice, Guyana
#
#                                                   Title         Company  \
# 0                                        Data Scientist       BICE VIDA
# 1                                        Data Scientist      BNamericas
# 2                                       Data Scientist.  Fuerza Laboral
# 3                                        Data Scientist       Agrosuper
# 4                                        Data Scientist   MAS Analytics
# ...                                                 ...             ...
# 1018                              Sr. Platform Engineer            Aha!
# 1019  Operations Intelligence Performance Optimizati...    SBM Offshore
# 1020                              Sr. Platform Engineer            Aha!
# 1021                             Ruby on Rails Engineer            Aha!
# 1022                                      Data Engineer       Univision
#
#                                                     Url  \
# 0     https://cl.linkedin.com/jobs/view/data-scienti...
# 1     https://cl.linkedin.com/jobs/view/data-scienti...
# 2     https://cl.linkedin.com/jobs/view/data-scienti...
# 3     https://cl.linkedin.com/jobs/view/data-scienti...
# 4     https://cl.linkedin.com/jobs/view/data-scienti...
# ...                                                 ...
# 1018  https://gy.linkedin.com/jobs/view/sr-platform-...
# 1019  https://gy.linkedin.com/jobs/view/operations-i...
# 1020  https://gy.linkedin.com/jobs/view/sr-platform-...
# 1021  https://gy.linkedin.com/jobs/view/ruby-on-rail...
# 1022  https://gy.linkedin.com/jobs/view/data-enginee...
#
#                              Postulaciones  \
# 0                                      NaN
# 1     \n          42 solicitudes\n
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ...                                    ...
# 1018                                   NaN
# 1019                                   NaN
# 1020                                   NaN
# 1021                                   NaN
# 1022                                   NaN
#
#                                      Jornada  \
# 0     \n          Jornada completa\n
# 1     \n          Jornada completa\n
# 2     \n          Jornada completa\n
# 3     \n          Jornada completa\n
# 4     \n          Jornada completa\n
# ...                                      ...
# 1018                                     NaN
# 1019         \n          Full-time\n
# 1020         \n          Full-time\n
# 1021         \n          Full-time\n
# 1022         \n          Full-time\n
#
#                                       Antiguedad
# 0       \n            No corresponde\n
# 1      \n            Sin experiencia\n
# 2      \n            Sin experiencia\n
# 3           \n            Intermedio\n
# 4       \n            No corresponde\n
# ...                                          ...
# 1018                                         NaN
# 1019       \n            Entry level\n
# 1020  \n            Mid-Senior level\n
# 1021       \n            Entry level\n
# 1022       \n            Entry level\n
#
# [1023 rows x 8 columns]

# %% [markdown]
# ### 3. Tratamiento de datos duplicados.
# **a)** ¿Existen datos duplicados en su dataframe? En caso afirmativo, ¿cuántos son, y se trata de duplicados totales o parciales? Justifique.
#
# **b)** En caso de existir duplicados, defina qué medida de corrección le parece apropiada (eliminar, corregir, combinar registros, etc), y aplíquela.
#
# *Funciones útiles*: `pandas.duplicated()`,`pandas.drop_duplicates()`

# %% [markdown]
# ### a) Hay datos duplicados? cuantos son y son duplicados parciales o totales?

# %% [markdown]
# Revisamos según las diferentes columnas que tenemos en nuestro dataframe. Primero calcularemos los duplicados totales. Para esto utilizamos el método `pandas.duplicated()` y no le pasamos el parámetro `subset`, comparando para una fila el valor de todas sus columnas.

# %%
total_duplicated_rows = sum([1 if i else 0 for i in alldf.duplicated()])
print(f'Duplicados totales: {total_duplicated_rows}')
# Out:
# Duplicados totales: 23

# %% [markdown]
# Ahora calculamos duplicados parciales. Para esto, utilizaremos como llave primaria el título del trabajo, la compañía y el país, ya que consideramos que si una fila tiene estos datos similares, entonces estamos hablando del mismo empleo. Luego, esas columnas las agregaremos en el parámetro `subset` y repetimos el cálculo, pero ahora de duplicados parciales.

# %%
parcial_duplicated_rows = sum([1 if i else 0 for i in alldf.duplicated(subset=['Country', 'Title', 'Company'])])
print(f'Duplicados parciales: {total_duplicated_rows}')
# Out:
# Duplicados parciales: 23

# %% [markdown]
# Vemos que la cantidad de duplicados es la misma, por lo que podemos confirmar entonces que dicha combinación de columnas es única y que los datos duplicados totales son similares a los parciales, en que se repiten todas las columnas.

# %% [markdown]
# Finalmente, para confirmar, mostramos un dataframe de todos los duplicados, viendo así que son duplicados totales.

# %%
duplicateds = alldf[alldf.duplicated(keep=False)]
duplicateds
# Out:
#         Country                                       Location  \
# 67        Chile  Santiago, Santiago Metropolitan Region, Chile
# 75        Chile  Santiago, Santiago Metropolitan Region, Chile
# 158    Colombia                      Colombia, Huila, Colombia
# 187    Colombia       Bogota, D.C., Capital District, Colombia
# 223    Colombia       Bogota, D.C., Capital District, Colombia
# 224    Colombia                      Colombia, Huila, Colombia
# 266     Ecuador                      Italia, Los Ríos, Ecuador
# 286     Ecuador                         Cuenca, Azuay, Ecuador
# 324     Ecuador                      Italia, Los Ríos, Ecuador
# 325     Ecuador                         Cuenca, Azuay, Ecuador
# 362      Brasil                   São Paulo, São Paulo, Brazil
# 370      Brasil                        Maringá, Paraná, Brazil
# 426      Brasil                   São Paulo, São Paulo, Brazil
# 427      Brasil                        Maringá, Paraná, Brazil
# 461   Venezuela                                      Venezuela
# 494   Venezuela                    Anzoategui State, Venezuela
# 523   Venezuela                    Anzoategui State, Venezuela
# 524   Venezuela                                      Venezuela
# 527     Uruguay                Montevideo, Montevideo, Uruguay
# 596     Uruguay                Montevideo, Montevideo, Uruguay
# 625     Uruguay                Montevideo, Montevideo, Uruguay
# 626     Uruguay                Montevideo, Montevideo, Uruguay
# 669    Paraguay                                       Paraguay
# 685    Paraguay                             Asunción, Paraguay
# 721    Paraguay                                       Paraguay
# 722    Paraguay                             Asunción, Paraguay
# 735     Bolivia                                        Bolivia
# 780     Bolivia                Cochabamba, Cochabamba, Bolivia
# 788     Bolivia                Cochabamba, Cochabamba, Bolivia
# 814     Bolivia                                        Bolivia
# 843     Bolivia                Cochabamba, Cochabamba, Bolivia
# 844     Bolivia                                        Bolivia
# 845     Bolivia                Cochabamba, Cochabamba, Bolivia
# 846     Bolivia                                        Bolivia
# 908      Guyana                                         Guyana
# 927      Guyana           Georgetown, Demerara-Mahaica, Guyana
# 962      Guyana              Mahaica, Demerara-Mahaica, Guyana
# 974      Guyana                                         Guyana
# 982      Guyana           Georgetown, Demerara-Mahaica, Guyana
# 986      Guyana                 No. 3, Mahaica-Berbice, Guyana
# 1017     Guyana           Georgetown, Demerara-Mahaica, Guyana
# 1018     Guyana                                         Guyana
# 1019     Guyana           Georgetown, Demerara-Mahaica, Guyana
# 1020     Guyana              Mahaica, Demerara-Mahaica, Guyana
# 1021     Guyana                                         Guyana
# 1022     Guyana                 No. 3, Mahaica-Berbice, Guyana
#
#                                                   Title             Company  \
# 67                                       Data Scientist          PMA Design
# 75                                       Data Scientist          PMA Design
# 158                       Data Science Spark - Colombia      CINTE Colombia
# 187                                      Data Scientist               Chubb
# 223                                      Data Scientist               Chubb
# 224                       Data Science Spark - Colombia      CINTE Colombia
# 266                        DevOps Engineer Junior (m/f)        Michael Page
# 286                             Senior Python Developer       Launch Potato
# 324                        DevOps Engineer Junior (m/f)        Michael Page
# 325                             Senior Python Developer       Launch Potato
# 362                               CIENTISTA DE DADOS JR      Cogna Educação
# 370                    Cientista de Dados - Home Office    Trade Technology
# 426                               CIENTISTA DE DADOS JR      Cogna Educação
# 427                    Cientista de Dados - Home Office    Trade Technology
# 461                             software engineer mobil               TUTEN
# 494   Software Engineer, Trilogy (Remote) - $100,000...  Crossover for Work
# 523   Software Engineer, Trilogy (Remote) - $100,000...  Crossover for Work
# 524                             software engineer mobil               TUTEN
# 527                Desarrollador Junior [Python /React]            FRIEDMAN
# 596                            Test Automation Engineer             Globant
# 625                            Test Automation Engineer             Globant
# 626                Desarrollador Junior [Python /React]            FRIEDMAN
# 669         React/C# Fullstack Developer (LATAM Remote)           Qeystroke
# 685                                  Desarrollador Java    Experis Paraguay
# 721         React/C# Fullstack Developer (LATAM Remote)           Qeystroke
# 722                                  Desarrollador Java    Experis Paraguay
# 735                               Remote Perl Developer     Scopic Software
# 780                                   Software Engineer            NICE Ltd
# 788                                   Software Engineer            NICE Ltd
# 814                    Principal Statistical Programmer                DOCS
# 843                                   Software Engineer            NICE Ltd
# 844                               Remote Perl Developer     Scopic Software
# 845                                   Software Engineer            NICE Ltd
# 846                    Principal Statistical Programmer                DOCS
# 908                               Sr. Platform Engineer                Aha!
# 927   Operations Intelligence Performance Optimizati...        SBM Offshore
# 962                               Sr. Platform Engineer                Aha!
# 974                              Ruby on Rails Engineer                Aha!
# 982   Software Development Specialist, Trilogy (Remo...  Crossover for Work
# 986                                       Data Engineer           Univision
# 1017  Software Development Specialist, Trilogy (Remo...  Crossover for Work
# 1018                              Sr. Platform Engineer                Aha!
# 1019  Operations Intelligence Performance Optimizati...        SBM Offshore
# 1020                              Sr. Platform Engineer                Aha!
# 1021                             Ruby on Rails Engineer                Aha!
# 1022                                      Data Engineer           Univision
#
#                                                     Url  \
# 67    https://cl.linkedin.com/jobs/view/data-scienti...
# 75    https://cl.linkedin.com/jobs/view/data-scienti...
# 158   https://co.linkedin.com/jobs/view/data-science...
# 187   https://co.linkedin.com/jobs/view/data-scienti...
# 223   https://co.linkedin.com/jobs/view/data-scienti...
# 224   https://co.linkedin.com/jobs/view/data-science...
# 266   https://ec.linkedin.com/jobs/view/devops-engin...
# 286   https://ec.linkedin.com/jobs/view/senior-pytho...
# 324   https://ec.linkedin.com/jobs/view/devops-engin...
# 325   https://ec.linkedin.com/jobs/view/senior-pytho...
# 362   https://br.linkedin.com/jobs/view/cientista-de...
# 370   https://br.linkedin.com/jobs/view/cientista-de...
# 426   https://br.linkedin.com/jobs/view/cientista-de...
# 427   https://br.linkedin.com/jobs/view/cientista-de...
# 461   https://ve.linkedin.com/jobs/view/software-eng...
# 494   https://ve.linkedin.com/jobs/view/software-eng...
# 523   https://ve.linkedin.com/jobs/view/software-eng...
# 524   https://ve.linkedin.com/jobs/view/software-eng...
# 527   https://uy.linkedin.com/jobs/view/desarrollado...
# 596   https://uy.linkedin.com/jobs/view/test-automat...
# 625   https://uy.linkedin.com/jobs/view/test-automat...
# 626   https://uy.linkedin.com/jobs/view/desarrollado...
# 669   https://py.linkedin.com/jobs/view/react-c%23-f...
# 685   https://py.linkedin.com/jobs/view/desarrollado...
# 721   https://py.linkedin.com/jobs/view/react-c%23-f...
# 722   https://py.linkedin.com/jobs/view/desarrollado...
# 735   https://bo.linkedin.com/jobs/view/remote-perl-...
# 780   https://bo.linkedin.com/jobs/view/software-eng...
# 788   https://bo.linkedin.com/jobs/view/software-eng...
# 814   https://bo.linkedin.com/jobs/view/principal-st...
# 843   https://bo.linkedin.com/jobs/view/software-eng...
# 844   https://bo.linkedin.com/jobs/view/remote-perl-...
# 845   https://bo.linkedin.com/jobs/view/software-eng...
# 846   https://bo.linkedin.com/jobs/view/principal-st...
# 908   https://gy.linkedin.com/jobs/view/sr-platform-...
# 927   https://gy.linkedin.com/jobs/view/operations-i...
# 962   https://gy.linkedin.com/jobs/view/sr-platform-...
# 974   https://gy.linkedin.com/jobs/view/ruby-on-rail...
# 982   https://gy.linkedin.com/jobs/view/software-dev...
# 986   https://gy.linkedin.com/jobs/view/data-enginee...
# 1017  https://gy.linkedin.com/jobs/view/software-dev...
# 1018  https://gy.linkedin.com/jobs/view/sr-platform-...
# 1019  https://gy.linkedin.com/jobs/view/operations-i...
# 1020  https://gy.linkedin.com/jobs/view/sr-platform-...
# 1021  https://gy.linkedin.com/jobs/view/ruby-on-rail...
# 1022  https://gy.linkedin.com/jobs/view/data-enginee...
#
#                              Postulaciones  \
# 67                                     NaN
# 75                                     NaN
# 158                                    NaN
# 187                                    NaN
# 223                                    NaN
# 224                                    NaN
# 266                                    NaN
# 286                                    NaN
# 324                                    NaN
# 325                                    NaN
# 362                                    NaN
# 370                                    NaN
# 426                                    NaN
# 427                                    NaN
# 461   \n          25 solicitudes\n
# 494                                    NaN
# 523                                    NaN
# 524   \n          25 solicitudes\n
# 527                                    NaN
# 596                                    NaN
# 625                                    NaN
# 626                                    NaN
# 669                                    NaN
# 685                                    NaN
# 721                                    NaN
# 722                                    NaN
# 735                                    NaN
# 780                                    NaN
# 788                                    NaN
# 814                                    NaN
# 843                                    NaN
# 844                                    NaN
# 845                                    NaN
# 846                                    NaN
# 908                                    NaN
# 927                                    NaN
# 962                                    NaN
# 974                                    NaN
# 982                                    NaN
# 986                                    NaN
# 1017                                   NaN
# 1018                                   NaN
# 1019                                   NaN
# 1020                                   NaN
# 1021                                   NaN
# 1022                                   NaN
#
#                                      Jornada  \
# 67                                       NaN
# 75                                       NaN
# 158   \n          Jornada completa\n
# 187                                      NaN
# 223                                      NaN
# 224   \n          Jornada completa\n
# 266                                      NaN
# 286   \n          Jornada completa\n
# 324                                      NaN
# 325   \n          Jornada completa\n
# 362     \n          Tempo integral\n
# 370     \n          Tempo integral\n
# 426     \n          Tempo integral\n
# 427     \n          Tempo integral\n
# 461   \n          Jornada completa\n
# 494   \n          Jornada completa\n
# 523   \n          Jornada completa\n
# 524   \n          Jornada completa\n
# 527                                      NaN
# 596                                      NaN
# 625                                      NaN
# 626                                      NaN
# 669                                      NaN
# 685                                      NaN
# 721                                      NaN
# 722                                      NaN
# 735   \n          Jornada completa\n
# 780                                      NaN
# 788   \n          Jornada completa\n
# 814                                      NaN
# 843                                      NaN
# 844   \n          Jornada completa\n
# 845   \n          Jornada completa\n
# 846                                      NaN
# 908                                      NaN
# 927          \n          Full-time\n
# 962          \n          Full-time\n
# 974          \n          Full-time\n
# 982                                      NaN
# 986          \n          Full-time\n
# 1017                                     NaN
# 1018                                     NaN
# 1019         \n          Full-time\n
# 1020         \n          Full-time\n
# 1021         \n          Full-time\n
# 1022         \n          Full-time\n
#
#                                       Antiguedad
# 67                                           NaN
# 75                                           NaN
# 158    \n            Sin experiencia\n
# 187                                          NaN
# 223                                          NaN
# 224    \n            Sin experiencia\n
# 266                                          NaN
# 286         \n            Intermedio\n
# 324                                          NaN
# 325         \n            Intermedio\n
# 362      \n            Não aplicável\n
# 370      \n            Não aplicável\n
# 426      \n            Não aplicável\n
# 427      \n            Não aplicável\n
# 461         \n            Intermedio\n
# 494         \n            Intermedio\n
# 523         \n            Intermedio\n
# 524         \n            Intermedio\n
# 527                                          NaN
# 596                                          NaN
# 625                                          NaN
# 626                                          NaN
# 669                                          NaN
# 685                                          NaN
# 721                                          NaN
# 722                                          NaN
# 735    \n            Sin experiencia\n
# 780                                          NaN
# 788    \n            Sin experiencia\n
# 814                                          NaN
# 843                                          NaN
# 844    \n            Sin experiencia\n
# 845    \n            Sin experiencia\n
# 846                                          NaN
# 908                                          NaN
# 927        \n            Entry level\n
# 962   \n            Mid-Senior level\n
# 974        \n            Entry level\n
# 982                                          NaN
# 986        \n            Entry level\n
# 1017                                         NaN
# 1018                                         NaN
# 1019       \n            Entry level\n
# 1020  \n            Mid-Senior level\n
# 1021       \n            Entry level\n
# 1022       \n            Entry level\n

# %% [markdown]
# # b) Medida de corrección

# %% [markdown]
# Dado que el dato cuando se repite se repite totalmente, no nos aporta valor, por lo que podemos quedarnos con el primer registro. para lo anterior utilizamos el método `pandas.drop_duplicates()` con el parámetro `keep='first'`

# %%
alldf.drop_duplicates(keep='first', inplace=True)
alldf
# Out:
#      Country                                       Location  \
# 0      Chile  Santiago, Santiago Metropolitan Region, Chile
# 1      Chile  Santiago, Santiago Metropolitan Region, Chile
# 2      Chile  Santiago, Santiago Metropolitan Region, Chile
# 3      Chile              Rancagua, O'Higgins Region, Chile
# 4      Chile  Santiago, Santiago Metropolitan Region, Chile
# ...      ...                                            ...
# 1012  Guyana              Mahaica, Demerara-Mahaica, Guyana
# 1013  Guyana                                         Guyana
# 1014  Guyana                                         Guyana
# 1015  Guyana              Mahaica, Demerara-Mahaica, Guyana
# 1016  Guyana              Mahaica, Demerara-Mahaica, Guyana
#
#                                                   Title         Company  \
# 0                                        Data Scientist       BICE VIDA
# 1                                        Data Scientist      BNamericas
# 2                                       Data Scientist.  Fuerza Laboral
# 3                                        Data Scientist       Agrosuper
# 4                                        Data Scientist   MAS Analytics
# ...                                                 ...             ...
# 1012                        Lead Ruby on Rails Engineer            Aha!
# 1013  Sr. Security Engineer (Ruby on Rails experienc...            Aha!
# 1014                         Sr. Ruby on Rails Engineer            Aha!
# 1015                         Sr. Ruby on Rails Engineer            Aha!
# 1016  Sr. Security Engineer (Ruby on Rails experienc...            Aha!
#
#                                                     Url  \
# 0     https://cl.linkedin.com/jobs/view/data-scienti...
# 1     https://cl.linkedin.com/jobs/view/data-scienti...
# 2     https://cl.linkedin.com/jobs/view/data-scienti...
# 3     https://cl.linkedin.com/jobs/view/data-scienti...
# 4     https://cl.linkedin.com/jobs/view/data-scienti...
# ...                                                 ...
# 1012  https://gy.linkedin.com/jobs/view/lead-ruby-on...
# 1013  https://gy.linkedin.com/jobs/view/sr-security-...
# 1014  https://gy.linkedin.com/jobs/view/sr-ruby-on-r...
# 1015  https://gy.linkedin.com/jobs/view/sr-ruby-on-r...
# 1016  https://gy.linkedin.com/jobs/view/sr-security-...
#
#                              Postulaciones  \
# 0                                      NaN
# 1     \n          42 solicitudes\n
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ...                                    ...
# 1012                                   NaN
# 1013                                   NaN
# 1014                                   NaN
# 1015                                   NaN
# 1016                                   NaN
#
#                                      Jornada  \
# 0     \n          Jornada completa\n
# 1     \n          Jornada completa\n
# 2     \n          Jornada completa\n
# 3     \n          Jornada completa\n
# 4     \n          Jornada completa\n
# ...                                      ...
# 1012                                     NaN
# 1013                                     NaN
# 1014         \n          Full-time\n
# 1015                                     NaN
# 1016         \n          Full-time\n
#
#                                       Antiguedad
# 0       \n            No corresponde\n
# 1      \n            Sin experiencia\n
# 2      \n            Sin experiencia\n
# 3           \n            Intermedio\n
# 4       \n            No corresponde\n
# ...                                          ...
# 1012                                         NaN
# 1013                                         NaN
# 1014  \n            Mid-Senior level\n
# 1015                                         NaN
# 1016  \n            Mid-Senior level\n
#
# [1000 rows x 8 columns]

# %% [markdown]
# ### 4. Convierta la columna *Postulaciones* a un dato de tipo numérico.
#
# **a)** Chequee los valores únicos de la columna *Postulaciones*.<br>
# **b)** Realice las correcciones y operaciones de limpieza necesarias para convertir a tipo de dato numérico.<br>
# **c)** Convierta la columna a datos de tipo `float`.<br>
#
#
# *Funciones útiles*: `pandas.unique()`,`pandas.str.replace()`,`pandas.str.strip()`,`pandas.astype()`

# %%
#completar código
alldf['Postulaciones'].unique()
# Out:
# array([nan, '\n          42 solicitudes\n        ',
#        '\n          38 solicitudes\n        ',
#        '\n          135 solicitudes\n        ',
#        '\n          40 solicitudes\n        ',
#        '\n          104 solicitudes\n        ',
#        '\n          91 solicitudes\n        ',
#        '\n          80 solicitudes\n        ',
#        '\n          106 solicitudes\n        ',
#        '\n          174 solicitudes\n        ',
#        '\n          53 solicitudes\n        ',
#        '\n          32 solicitudes\n        ',
#        '\n          85 solicitudes\n        ',
#        '\n          43 solicitudes\n        ',
#        '\n          44 solicitudes\n        ',
#        '\n          47 solicitudes\n        ',
#        '\n          33 solicitudes\n        ',
#        '\n          55 solicitudes\n        ',
#        '\n          58 solicitudes\n        ',
#        '\n          29 solicitudes\n        ',
#        '\n          153 solicitudes\n        ',
#        '\n          95 solicitudes\n        ',
#        '\n          54 applicants\n        ',
#        '\n          41 solicitudes\n        ',
#        '\n          83 solicitudes\n        ',
#        '\n          111 applicants\n        ',
#        '\n          150 solicitudes\n        ',
#        '\n          30 solicitudes\n        ',
#        '\n          124 solicitudes\n        ',
#        '\n          72 solicitudes\n        ',
#        '\n          92 solicitudes\n        ',
#        '\n          35 solicitudes\n        ',
#        '\n          36 solicitudes\n        ',
#        '\n          27 solicitudes\n        ',
#        '\n          81 solicitudes\n        ',
#        '\n          76 solicitudes\n        ',
#        '\n          112 solicitudes\n        ',
#        '\n          57 solicitudes\n        ',
#        '\n          39 solicitudes\n        ',
#        '\n          60 solicitudes\n        ',
#        '\n          59 applicants\n        ',
#        '\n          94 applicants\n        ',
#        '\n          60 applicants\n        ',
#        '\n          191 applicants\n        ',
#        '\n          129 applicants\n        ',
#        '\n          151 applicants\n        ',
#        '\n          178 applicants\n        ',
#        '\n          180 applicants\n        ',
#        '\n          77 applicants\n        ',
#        '\n          194 applicants\n        ',
#        '\n          187 applicants\n        ',
#        '\n          53 applicants\n        ',
#        '\n          35 candidaturas\n        ',
#        '\n          151 candidaturas\n        ',
#        '\n          165 candidaturas\n        ',
#        '\n          116 candidaturas\n        ',
#        '\n          41 applicants\n        ',
#        '\n          43 applicants\n        ',
#        '\n          119 applicants\n        ',
#        '\n          62 applicants\n        ',
#        '\n          115 candidaturas\n        ',
#        '\n          106 candidaturas\n        ',
#        '\n          110 candidaturas\n        ',
#        '\n          185 candidaturas\n        ',
#        '\n          64 candidaturas\n        ',
#        '\n          29 candidaturas\n        ',
#        '\n          25 solicitudes\n        ',
#        '\n          65 solicitudes\n        ',
#        '\n          49 solicitudes\n        ',
#        '\n          51 solicitudes\n        ',
#        '\n          28 solicitudes\n        ',
#        '\n          26 solicitudes\n        ',
#        '\n          156 solicitudes\n        ',
#        '\n          52 solicitudes\n        ',
#        '\n          67 solicitudes\n        ',
#        '\n          56 solicitudes\n        ',
#        '\n          152 solicitudes\n        ',
#        '\n          82 solicitudes\n        ',
#        '\n          155 solicitudes\n        ',
#        '\n          37 solicitudes\n        ',
#        '\n          71 solicitudes\n        ',
#        '\n          79 solicitudes\n        ',
#        '\n          34 solicitudes\n        '], dtype=object)

# %% [markdown]
# Vemos que hay muchos espacios en blanco y saltos de líneas. Primero partimos corrigiendo esto:

# %%
alldf['Postulaciones'] = alldf['Postulaciones'].str.strip()
alldf['Postulaciones'].unique()
# Out:
# array([nan, '42 solicitudes', '38 solicitudes', '135 solicitudes',
#        '40 solicitudes', '104 solicitudes', '91 solicitudes',
#        '80 solicitudes', '106 solicitudes', '174 solicitudes',
#        '53 solicitudes', '32 solicitudes', '85 solicitudes',
#        '43 solicitudes', '44 solicitudes', '47 solicitudes',
#        '33 solicitudes', '55 solicitudes', '58 solicitudes',
#        '29 solicitudes', '153 solicitudes', '95 solicitudes',
#        '54 applicants', '41 solicitudes', '83 solicitudes',
#        '111 applicants', '150 solicitudes', '30 solicitudes',
#        '124 solicitudes', '72 solicitudes', '92 solicitudes',
#        '35 solicitudes', '36 solicitudes', '27 solicitudes',
#        '81 solicitudes', '76 solicitudes', '112 solicitudes',
#        '57 solicitudes', '39 solicitudes', '60 solicitudes',
#        '59 applicants', '94 applicants', '60 applicants',
#        '191 applicants', '129 applicants', '151 applicants',
#        '178 applicants', '180 applicants', '77 applicants',
#        '194 applicants', '187 applicants', '53 applicants',
#        '35 candidaturas', '151 candidaturas', '165 candidaturas',
#        '116 candidaturas', '41 applicants', '43 applicants',
#        '119 applicants', '62 applicants', '115 candidaturas',
#        '106 candidaturas', '110 candidaturas', '185 candidaturas',
#        '64 candidaturas', '29 candidaturas', '25 solicitudes',
#        '65 solicitudes', '49 solicitudes', '51 solicitudes',
#        '28 solicitudes', '26 solicitudes', '156 solicitudes',
#        '52 solicitudes', '67 solicitudes', '56 solicitudes',
#        '152 solicitudes', '82 solicitudes', '155 solicitudes',
#        '37 solicitudes', '71 solicitudes', '79 solicitudes',
#        '34 solicitudes'], dtype=object)

# %% [markdown]
# Ahora, reemplazamos los string ` solicitudes`, ` applicants`, ` candidaturas` por el string nulo.

# %%
alldf['Postulaciones'] = alldf['Postulaciones'].str.replace(' solicitudes', '')
alldf['Postulaciones'] = alldf['Postulaciones'].str.replace(' applicants', '')
alldf['Postulaciones'] = alldf['Postulaciones'].str.replace(' candidaturas', '')
alldf['Postulaciones'].unique()
# Out:
# array([nan, '42', '38', '135', '40', '104', '91', '80', '106', '174',
#        '53', '32', '85', '43', '44', '47', '33', '55', '58', '29', '153',
#        '95', '54', '41', '83', '111', '150', '30', '124', '72', '92',
#        '35', '36', '27', '81', '76', '112', '57', '39', '60', '59', '94',
#        '191', '129', '151', '178', '180', '77', '194', '187', '165',
#        '116', '119', '62', '115', '110', '185', '64', '25', '65', '49',
#        '51', '28', '26', '156', '52', '67', '56', '152', '82', '155',
#        '37', '71', '79', '34'], dtype=object)

# %% [markdown]
# Transformamos las filas con valores nulos a 0.

# %%
alldf['Postulaciones'] = alldf['Postulaciones'].fillna(0)
alldf['Postulaciones'].unique()
# Out:
# array([0, '42', '38', '135', '40', '104', '91', '80', '106', '174', '53',
#        '32', '85', '43', '44', '47', '33', '55', '58', '29', '153', '95',
#        '54', '41', '83', '111', '150', '30', '124', '72', '92', '35',
#        '36', '27', '81', '76', '112', '57', '39', '60', '59', '94', '191',
#        '129', '151', '178', '180', '77', '194', '187', '165', '116',
#        '119', '62', '115', '110', '185', '64', '25', '65', '49', '51',
#        '28', '26', '156', '52', '67', '56', '152', '82', '155', '37',
#        '71', '79', '34'], dtype=object)

# %% [markdown]
# Finalmente casteamos los datos a float.

# %%
alldf['Postulaciones'] = alldf['Postulaciones'].astype(np.float64)
alldf['Postulaciones'].unique()
# Out:
# array([  0.,  42.,  38., 135.,  40., 104.,  91.,  80., 106., 174.,  53.,
#         32.,  85.,  43.,  44.,  47.,  33.,  55.,  58.,  29., 153.,  95.,
#         54.,  41.,  83., 111., 150.,  30., 124.,  72.,  92.,  35.,  36.,
#         27.,  81.,  76., 112.,  57.,  39.,  60.,  59.,  94., 191., 129.,
#        151., 178., 180.,  77., 194., 187., 165., 116., 119.,  62., 115.,
#        110., 185.,  64.,  25.,  65.,  49.,  51.,  28.,  26., 156.,  52.,
#         67.,  56., 152.,  82., 155.,  37.,  71.,  79.,  34.])

# %% [markdown]
# ### 5. Convierta las columnas *Jornada* y *Antiguedad* a datos de tipo categórico.
#
# **a)** Elimine los espacios en blanco sobrantes y caracteres de salto de línea ('\n') en ambas columnas.<br>
# **b)** Chequee las categorías únicas de la columna *Jornada*. ¿Cuántas son? <br>
# **c)** Para la columna *Antiguedad*, reduzca el número de categorías a sólo cuatro:`['N/A','Poca/ninguna','Intermedia','Senior/ejecutivo','Director']` (`N/A: no aplica`). <br>Para ello, defina un diccionario de equivalencias que le parezca adecuado.
#
# **d)** Convierta ambas columnas a datos de tipo `category`.<br>
#
# *Funciones útiles*: `pandas.unique()`,`pandas.str.strip()`,`pandas.map()`,`pandas.astype()`

# %% [markdown]
# Borramos espacios en blanco y saltos de línea

# %%
alldf['Jornada'] = alldf['Jornada'].str.strip()
alldf['Antiguedad'] = alldf['Antiguedad'].str.strip()

# %% [markdown]
# Categorías únicas de *Jornada*

# %%
total_jornadas = len(alldf['Jornada'].unique())
print(f'Total de categorías unicas: {total_jornadas}')
alldf['Jornada'].unique()
# Out:
# Total de categorías unicas: 6
# array(['Jornada completa', nan, 'Full-time', 'Tempo integral', 'Contract',
#        'Contrato por obra'], dtype=object)

# %% [markdown]
# Vemos las categorías de *Antiguedad*:

# %%
alldf['Antiguedad'].unique()
# Out:
# array(['No corresponde', 'Sin experiencia', 'Intermedio', nan,
#        'Algo de responsabilidad', 'Ejecutivo', 'Entry level',
#        'Jornada completa', 'Director', 'Associate', 'Not Applicable',
#        'Mid-Senior level', 'Assistente', 'Não aplicável', 'Pleno-sênior',
#        'Júnior', 'Media jornada', 'Full-time'], dtype=object)

# %% [markdown]
# Construimos el diccionario para mapear a cualquiera de las cinco categorías: `['N/A','Poca/ninguna','Intermedia','Senior/ejecutivo','Director']` y lo aplicamos en la columna de antiguedad.

# %%
field_mapper = {
    'No corresponde': 'N/A',
    'Sin experiencia': 'Poca/ninguna',
    'Intermedio': 'Intermedia',
    'Algo de responsabilidad': 'Intermedia',
    'Ejecutivo': 'Senior/ejecutivo',
    'Entry level': 'Poca/ninguna',
    'Jornada completa': 'N/A',
    'Director': 'Director',
    'Associate': 'Intermedia',
    'Not Applicable': 'N/A',
    'Mid-Senior level': 'Intermedia',
    'Assistente': 'Intermedia',
    'Não aplicável': 'N/A',
    'Pleno-sênior': 'Senior/ejecutivo',
    'Júnior': 'Poca/ninguna',
    'Media jornada': 'N/A',
    'Full-time': 'N/A'
    }

alldf['Antiguedad'] = alldf['Antiguedad'].map(field_mapper)
alldf['Antiguedad'].unique()
# Out:
# array(['N/A', 'Poca/ninguna', 'Intermedia', nan, 'Senior/ejecutivo',
#        'Director'], dtype=object)

# %% [markdown]
# Consideramos que si el dato es NaN, es el nivel más júnior, por lo que llenamos los NaN con la categoría *Poca/ninguna*

# %%
alldf['Antiguedad'] = alldf['Antiguedad'].fillna('Poca/ninguna')
alldf['Antiguedad'].unique()
# Out:
# array(['N/A', 'Poca/ninguna', 'Intermedia', 'Senior/ejecutivo',
#        'Director'], dtype=object)

# %% [markdown]
# Finalmente, convertimos las columnas a categoría *Category*.

# %%
alldf['Jornada'] = alldf['Jornada'].astype('category')
alldf['Antiguedad'] = alldf['Antiguedad'].astype('category')
alldf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 0 to 1016
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Country        1000 non-null   object
#  1   Location       1000 non-null   object
#  2   Title          1000 non-null   object
#  3   Company        1000 non-null   object
#  4   Url            1000 non-null   object
#  5   Postulaciones  1000 non-null   float64
#  6   Jornada        681 non-null    category
#  7   Antiguedad     1000 non-null   category
# dtypes: category(2), float64(1), object(5)
# memory usage: 57.1+ KB

# %%
alldf.head()
# Out:
#   Country                                       Location            Title  \
# 0   Chile  Santiago, Santiago Metropolitan Region, Chile   Data Scientist
# 1   Chile  Santiago, Santiago Metropolitan Region, Chile   Data Scientist
# 2   Chile  Santiago, Santiago Metropolitan Region, Chile  Data Scientist.
# 3   Chile              Rancagua, O'Higgins Region, Chile   Data Scientist
# 4   Chile  Santiago, Santiago Metropolitan Region, Chile   Data Scientist
#
#           Company                                                Url  \
# 0       BICE VIDA  https://cl.linkedin.com/jobs/view/data-scienti...
# 1      BNamericas  https://cl.linkedin.com/jobs/view/data-scienti...
# 2  Fuerza Laboral  https://cl.linkedin.com/jobs/view/data-scienti...
# 3       Agrosuper  https://cl.linkedin.com/jobs/view/data-scienti...
# 4   MAS Analytics  https://cl.linkedin.com/jobs/view/data-scienti...
#
#    Postulaciones           Jornada    Antiguedad
# 0            0.0  Jornada completa           N/A
# 1           42.0  Jornada completa  Poca/ninguna
# 2            0.0  Jornada completa  Poca/ninguna
# 3            0.0  Jornada completa    Intermedia
# 4            0.0  Jornada completa           N/A

# %% [markdown]
# ### 6. Lea el conjunto de datos de Índice de Innovación por país y renombre la columna *Economy* a *Country*.

# %%
innovation_csv = 'https://raw.githubusercontent.com/paguirre-uc/mds3020_2022/main/tarea2/indiceInnovacionPaises.csv'
innovationdf = pd.read_csv(innovation_csv, sep=',')
innovationdf
# Out:
#      rank                   Economy Income Group(Strength/Weakness)  \
# 0       1               Switzerland                        Strength
# 1       2  United States of America                        Strength
# 2       3                    Sweden                        Strength
# 3       4            United Kingdom                        Strength
# 4       5               Netherlands                             NaN
# ..    ...                       ...                             ...
# 127   128                     Yemen                             NaN
# 128   129                Mauritania                        Weakness
# 129   130                   Burundi                        Weakness
# 130   131                      Iraq                        Weakness
# 131   132                    Guinea                        Weakness
#
#     Strength / Weakness  Score
# 0              Strength   64.6
# 1              Strength   61.8
# 2              Strength   61.6
# 3              Strength   59.7
# 4              Strength   58.0
# ..                  ...    ...
# 127                 NaN   13.8
# 128                 NaN   12.4
# 129                 NaN   12.3
# 130            Weakness   11.9
# 131            Weakness   11.6
#
# [132 rows x 5 columns]

# %%
innovationdf.rename(columns={'Economy': 'Country'}, inplace=True)
innovationdf.head()
# Out:
#    rank                   Country Income Group(Strength/Weakness)  \
# 0     1               Switzerland                        Strength
# 1     2  United States of America                        Strength
# 2     3                    Sweden                        Strength
# 3     4            United Kingdom                        Strength
# 4     5               Netherlands                             NaN
#
#   Strength / Weakness  Score
# 0            Strength   64.6
# 1            Strength   61.8
# 2            Strength   61.6
# 3            Strength   59.7
# 4            Strength   58.0

# %% [markdown]
# ### 7. Combinación de conjuntos de datos.
# **a)** Del dataframe de Índice de Innovación por País, seleccione sólo las columnas *Country* y *Score*. <br>
# **b)** Combine estos datos con el dataframe de ofertas laborales, de manera de agregarle a éste una columna *Score* con el índice de innovación del país dónde se publicó el anuncio: <br>
#
# |Country | Location|Title | Company | Url | Postulaciones | Jornada |Antiguedad |Score |
# |---|---|---|---|---|---|---|---|---|
#
# Este dataframe debe tener el mismo número de registros que el dataframe de ofertas laborales.
#
# **b)** Determine si en este dataframe final, existen registros para los cuales la columna *Score* es un dato faltante o nulo. ¿A qué se deben estos datos nulos, si es que existen?
#
# *Funciones útiles*: `pandas.merge()`

# %% [markdown]
# Seleccionamos solo las columnas *Country* y *Score*.

# %%
innovationdf = innovationdf[['Country', 'Score']]
innovationdf
# Out:
#                       Country  Score
# 0                 Switzerland   64.6
# 1    United States of America   61.8
# 2                      Sweden   61.6
# 3              United Kingdom   59.7
# 4                 Netherlands   58.0
# ..                        ...    ...
# 127                     Yemen   13.8
# 128                Mauritania   12.4
# 129                   Burundi   12.3
# 130                      Iraq   11.9
# 131                    Guinea   11.6
#
# [132 rows x 2 columns]

# %% [markdown]
# Podemos ver que los nombres de los países están en inglés, lo que podría generar un problema al momento de hacer el cruce con el dataset de oportunidades laborales. En dicho caso, vemos el caso de Brasil, que en el dataset de innovación aparece como 'Brazil'. Hacemos este cambio.

# %%
innovationdf[innovationdf['Country'] == 'Brazil']
# Out:
#    Country  Score
# 53  Brazil   32.5

# %%
innovationdf['Country'] = innovationdf['Country'].map({'Brazil': 'Brasil'}).fillna(innovationdf['Country'])
innovationdf[innovationdf['Country'] == 'Brasil']
# Out:
# /var/folders/5x/tlp5fd614dv9y_wn8nmtqv4rqq_frn/T/ipykernel_84112/3110514903.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   innovationdf['Country'] = innovationdf['Country'].map({'Brazil': 'Brasil'}).fillna(innovationdf['Country'])
#    Country  Score
# 53  Brasil   32.5

# %%
innovationdf
# Out:
#                       Country  Score
# 0                 Switzerland   64.6
# 1    United States of America   61.8
# 2                      Sweden   61.6
# 3              United Kingdom   59.7
# 4                 Netherlands   58.0
# ..                        ...    ...
# 127                     Yemen   13.8
# 128                Mauritania   12.4
# 129                   Burundi   12.3
# 130                      Iraq   11.9
# 131                    Guinea   11.6
#
# [132 rows x 2 columns]

# %% [markdown]
# Combinamos ambos dataset utilizando la columna *Country* como condición de igualdad del JOIN. Hacemos un LEFT JOIN en el que el dataset de la izquierda será el de ofertas laborales, manteniendo al menos su cardinalidad.

# %%
alldf
# Out:
#      Country                                       Location  \
# 0      Chile  Santiago, Santiago Metropolitan Region, Chile
# 1      Chile  Santiago, Santiago Metropolitan Region, Chile
# 2      Chile  Santiago, Santiago Metropolitan Region, Chile
# 3      Chile              Rancagua, O'Higgins Region, Chile
# 4      Chile  Santiago, Santiago Metropolitan Region, Chile
# ...      ...                                            ...
# 1012  Guyana              Mahaica, Demerara-Mahaica, Guyana
# 1013  Guyana                                         Guyana
# 1014  Guyana                                         Guyana
# 1015  Guyana              Mahaica, Demerara-Mahaica, Guyana
# 1016  Guyana              Mahaica, Demerara-Mahaica, Guyana
#
#                                                   Title         Company  \
# 0                                        Data Scientist       BICE VIDA
# 1                                        Data Scientist      BNamericas
# 2                                       Data Scientist.  Fuerza Laboral
# 3                                        Data Scientist       Agrosuper
# 4                                        Data Scientist   MAS Analytics
# ...                                                 ...             ...
# 1012                        Lead Ruby on Rails Engineer            Aha!
# 1013  Sr. Security Engineer (Ruby on Rails experienc...            Aha!
# 1014                         Sr. Ruby on Rails Engineer            Aha!
# 1015                         Sr. Ruby on Rails Engineer            Aha!
# 1016  Sr. Security Engineer (Ruby on Rails experienc...            Aha!
#
#                                                     Url  Postulaciones  \
# 0     https://cl.linkedin.com/jobs/view/data-scienti...            0.0
# 1     https://cl.linkedin.com/jobs/view/data-scienti...           42.0
# 2     https://cl.linkedin.com/jobs/view/data-scienti...            0.0
# 3     https://cl.linkedin.com/jobs/view/data-scienti...            0.0
# 4     https://cl.linkedin.com/jobs/view/data-scienti...            0.0
# ...                                                 ...            ...
# 1012  https://gy.linkedin.com/jobs/view/lead-ruby-on...            0.0
# 1013  https://gy.linkedin.com/jobs/view/sr-security-...            0.0
# 1014  https://gy.linkedin.com/jobs/view/sr-ruby-on-r...            0.0
# 1015  https://gy.linkedin.com/jobs/view/sr-ruby-on-r...            0.0
# 1016  https://gy.linkedin.com/jobs/view/sr-security-...            0.0
#
#                Jornada    Antiguedad
# 0     Jornada completa           N/A
# 1     Jornada completa  Poca/ninguna
# 2     Jornada completa  Poca/ninguna
# 3     Jornada completa    Intermedia
# 4     Jornada completa           N/A
# ...                ...           ...
# 1012               NaN  Poca/ninguna
# 1013               NaN  Poca/ninguna
# 1014         Full-time    Intermedia
# 1015               NaN  Poca/ninguna
# 1016         Full-time    Intermedia
#
# [1000 rows x 8 columns]

# %%
df = alldf.merge(innovationdf, how='left', on=['Country'])
df
# Out:
#     Country                                       Location  \
# 0     Chile  Santiago, Santiago Metropolitan Region, Chile
# 1     Chile  Santiago, Santiago Metropolitan Region, Chile
# 2     Chile  Santiago, Santiago Metropolitan Region, Chile
# 3     Chile              Rancagua, O'Higgins Region, Chile
# 4     Chile  Santiago, Santiago Metropolitan Region, Chile
# ..      ...                                            ...
# 995  Guyana              Mahaica, Demerara-Mahaica, Guyana
# 996  Guyana                                         Guyana
# 997  Guyana                                         Guyana
# 998  Guyana              Mahaica, Demerara-Mahaica, Guyana
# 999  Guyana              Mahaica, Demerara-Mahaica, Guyana
#
#                                                  Title         Company  \
# 0                                       Data Scientist       BICE VIDA
# 1                                       Data Scientist      BNamericas
# 2                                      Data Scientist.  Fuerza Laboral
# 3                                       Data Scientist       Agrosuper
# 4                                       Data Scientist   MAS Analytics
# ..                                                 ...             ...
# 995                        Lead Ruby on Rails Engineer            Aha!
# 996  Sr. Security Engineer (Ruby on Rails experienc...            Aha!
# 997                         Sr. Ruby on Rails Engineer            Aha!
# 998                         Sr. Ruby on Rails Engineer            Aha!
# 999  Sr. Security Engineer (Ruby on Rails experienc...            Aha!
#
#                                                    Url  Postulaciones  \
# 0    https://cl.linkedin.com/jobs/view/data-scienti...            0.0
# 1    https://cl.linkedin.com/jobs/view/data-scienti...           42.0
# 2    https://cl.linkedin.com/jobs/view/data-scienti...            0.0
# 3    https://cl.linkedin.com/jobs/view/data-scienti...            0.0
# 4    https://cl.linkedin.com/jobs/view/data-scienti...            0.0
# ..                                                 ...            ...
# 995  https://gy.linkedin.com/jobs/view/lead-ruby-on...            0.0
# 996  https://gy.linkedin.com/jobs/view/sr-security-...            0.0
# 997  https://gy.linkedin.com/jobs/view/sr-ruby-on-r...            0.0
# 998  https://gy.linkedin.com/jobs/view/sr-ruby-on-r...            0.0
# 999  https://gy.linkedin.com/jobs/view/sr-security-...            0.0
#
#               Jornada    Antiguedad  Score
# 0    Jornada completa           N/A   34.0
# 1    Jornada completa  Poca/ninguna   34.0
# 2    Jornada completa  Poca/ninguna   34.0
# 3    Jornada completa    Intermedia   34.0
# 4    Jornada completa           N/A   34.0
# ..                ...           ...    ...
# 995               NaN  Poca/ninguna    NaN
# 996               NaN  Poca/ninguna    NaN
# 997         Full-time    Intermedia    NaN
# 998               NaN  Poca/ninguna    NaN
# 999         Full-time    Intermedia    NaN
#
# [1000 rows x 9 columns]

# %% [markdown]
# Vemos la columna *Score*, chequeando si hay nulos.

# %%
df.groupby('Score', dropna=False).agg('count')
# Out:
#        Country  Location  Title  Company  Url  Postulaciones  Jornada  \
# Score
# 20.3        99        99     99       99   99             99       78
# 22.6        94        94     94       94   94             94       47
# 28.6        75        75     75       75   75             75       49
# 29.2       172       172    172      172  172            172      121
# 32.5       100       100    100      100  100            100       88
# 34.0        75        75     75       75   75             75       61
# NaN        385       385    385      385  385            385      237
#
#        Antiguedad
# Score
# 20.3           99
# 22.6           94
# 28.6           75
# 29.2          172
# 32.5          100
# 34.0           75
# NaN           385

# %% [markdown]
# Vemos que hay un total de 385 datos con valor nulo de Score

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Country        1000 non-null   object
#  1   Location       1000 non-null   object
#  2   Title          1000 non-null   object
#  3   Company        1000 non-null   object
#  4   Url            1000 non-null   object
#  5   Postulaciones  1000 non-null   float64
#  6   Jornada        681 non-null    category
#  7   Antiguedad     1000 non-null   category
#  8   Score          615 non-null    float64
# dtypes: category(2), float64(2), object(5)
# memory usage: 64.9+ KB

# %% [markdown]
# Lo anterior tiene bastante lógica: si comparamos la cantidad de países de la base de datos de innovacion, obtenemos que son 132.

# %%
len(innovationdf['Country'].unique())
# Out:
# 132

# %% [markdown]
# Mientras, en la base de datos de ofertas laborales, tenemos un total de 11 países.

# %%
len(alldf['Country'].unique())
# Out:
# 11

# %% [markdown]
# Dado lo anterior y que requeríamos que el dataset de oportunidades laborales tenga la misma cantidad de datos utilizamos un LEFT JOIN, en el que si un país no era encontrado en dicho dataset, las columnas de Score se seteaban como nulas. Dado lo anterior, es que existen ciertos países del dataset de oportunidades laborales que no se encontraban en el de innovación, por lo que en tales casos, el score se seteó como nulo. Lo vemos gráficamente para concluir.

# %%
job_countries = df[df['Score'].isnull()]['Country'].unique().tolist()
job_countries
# Out:
# ['Venezuela', 'Bolivia', 'Suriname', 'Guyana']

# %%
all_countries_innov = innovationdf['Country'].unique().tolist()
all_countries_innov
# Out:
# ['Switzerland',
#  'United States of America',
#  'Sweden',
#  'United Kingdom',
#  'Netherlands',
#  'Republic of Korea',
#  'Singapore',
#  'Germany',
#  'Finland',
#  'Denmark',
#  'China',
#  'France',
#  'Japan',
#  'Hong Kong',
#  'Canada',
#  'Israel',
#  'Austria',
#  'Estonia',
#  'Luxembourg',
#  'Iceland',
#  'Malta',
#  'Norway',
#  'Ireland',
#  'New Zealand',
#  'Australia',
#  'Belgium',
#  'Cyprus',
#  'Italy',
#  'Spain',
#  'Czech Republic',
#  'United Arab Emirates',
#  'Portugal',
#  'Slovenia',
#  'Hungary',
#  'Bulgaria',
#  'Malaysia',
#  'T\x81rkiye',
#  'Poland',
#  'Lithuania',
#  'India',
#  'Latvia',
#  'Croatia',
#  'Thailand',
#  'Greece',
#  'Mauritius',
#  'Slovakia',
#  'Russian Federation',
#  'Viet Nam',
#  'Romania',
#  'Chile',
#  'Saudi Arabia',
#  'Qatar',
#  'Iran (Islamic Republic of)',
#  'Brasil',
#  'Serbia',
#  'Republic of Moldova',
#  'Ukraine',
#  'Mexico',
#  'Philippines',
#  'Montenegro',
#  'South Africa',
#  'Kuwait',
#  'Colombia',
#  'Uruguay',
#  'Peru',
#  'North Macedonia',
#  'Morocco',
#  'Costa Rica',
#  'Argentina',
#  'Bosnia and Herzegovina',
#  'Mongolia',
#  'Bahrain',
#  'Tunisia',
#  'Georgia',
#  'Indonesia',
#  'Jamaica',
#  'Belarus',
#  'Jordan',
#  'Oman',
#  'Armenia',
#  'Panama',
#  'Uzbekistan',
#  'Kazakhstan',
#  'Albania',
#  'Sri Lanka',
#  'Botswana',
#  'Pakistan',
#  'Kenya',
#  'Egypt',
#  'Dominican Republic',
#  'Paraguay',
#  'Brunei Darussalam',
#  'Azerbaijan',
#  'Kyrgyzstan',
#  'Ghana',
#  'Namibia',
#  'Cambodia',
#  'Ecuador',
#  'Senegal',
#  'El Salvador',
#  'Trinidad and Tobago',
#  'Bangladesh',
#  'United Republic of Tanzania',
#  'Tajikistan',
#  'Rwanda',
#  'Madagascar',
#  'Zimbabwe',
#  'Nicaragua',
#  "C?te d'Ivoire",
#  'Guatemala',
#  'Nepal',
#  "Lao People's Democratic Republic",
#  'Honduras',
#  'Nigeria',
#  'Algeria',
#  'Myanmar',
#  'Ethiopia',
#  'Zambia',
#  'Uganda',
#  'Burkina Faso',
#  'Cameroon',
#  'Togo',
#  'Mozambique',
#  'Benin',
#  'Niger',
#  'Mali',
#  'Angola',
#  'Yemen',
#  'Mauritania',
#  'Burundi',
#  'Iraq',
#  'Guinea']

# %% [markdown]
# Chequeamos que el subconjunto de países no se encuentra en el listado de países con el score de innovación.

# %%
set(job_countries).intersection(set(all_countries_innov))
# Out:
# set()
