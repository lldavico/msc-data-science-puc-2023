# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# # <img style="float: left; padding: 0px 10px 0px 0px;" src="https://upload.wikimedia.org/wikipedia/commons/thumb/8/84/Escudo_de_la_Pontificia_Universidad_Cat%C3%B3lica_de_Chile.svg/1920px-Escudo_de_la_Pontificia_Universidad_Cat%C3%B3lica_de_Chile.svg.png"  width="80" /> MCD3020 - Introducción a Ciencia de Datos
# **Pontificia Universidad Católica de Chile**<br>
# **Profesora:** Paula Aguirre <br>
#
# ## Tutorial 4: Limpieza de Datos, conceptos básicos.
#
# La ciencia de datos parte por definir un problema o pregunta y por recolectar conjuntos de datos variados y lo más completos posibles para abordar dicho problema. En un mundo ideal, los datos que obtenemos vendrían perfectamente ordenados y listos para ser analizados, pero en la práctica, se requiere un trabajo significativo para convertir nuestra materia prima en un conjunto de datos bien estructurado, realmente apto para el modelamiento matemático o computacional.
#
# En este tutorial, demostraremos algunas operaciones comunes de limpieza de datos, que suelen ser necesarias en cualquier proceso de ciencia de datos.

# %%
import pandas as pd

# %% [markdown]
# ## 1. Inspección de datos.

# %%
df=pd.read_csv('https://raw.githubusercontent.com/paguirre-uc/mds3020_2022/main/semana3/productos.csv',delimiter=';')
#df=pd.read_csv('productos.csv',delimiter=';')


df.head(15)
# Out:
#     Unnamed: 0   scraped                  nombre del producto:nombre:nombre  \
# 0            0  05-04-22    Tablet Space 7" 1GB 16GB WiFi Quad Core Android
# 1            1  05-04-22  Tablet Space Kids 7" 1GB 16GB WiFi Quad Core A...
# 2            2  05-04-22  Tablet SoyMomo Lite 2.0 7" 2GB 16GB Wifi Quad ...
# 3            3  05-04-22     Tablet Tab M7 7" HD 1GB 16GB 4G LTE Onix Black
# 4            4  05-04-22              Tablet M7 2 32GB 7" HD Wifi Iron grey
# 5            5  05-04-22  Tablet  Tab M8 8" 2GB 32GB WiFi Quad Core Andr...
# 6            6  05-04-22  Kindle Touch 6" 8GB Luz frontal ajustable WiFi...
# 7            7  05-04-22  Kindle Touch 6" 8GB Luz frontal ajustable WiFi...
# 8            8  05-04-22                                           ERROR101
# 9            9  05-04-22  Kindle Touch 6" 8GB Luz frontal ajustable WiFi...
# 10          10  05-04-22  Kindle Touch 6" 8GB Luz frontal ajustable WiFi...
# 11          11  05-04-22    Kindle Touch Luz incorporada 6" 8GB WiFi  Negro
# 12          12  05-04-22  Tablet SoyMomo Pro 8" 2GB 32GB WiFi Octa Core ...
# 13          13  05-04-22  Tablet SoyMomo Pro 8" 2GB 32GB WiFi Octa Core ...
# 14          14  05-04-22  Tablet Pro T310 10,1" 2GB 32GB WiFi Quad Core ...
#
#          id      clp marca fabricante  variant       lista
# 0   43812.0  $46,390             Gear      NaN  Categorías
# 1   43813.0    51590             Gear      NaN  Categorías
# 2       NaN    61890          SoyMomo      NaN  Categorías
# 3   41836.0  $72,190           Lenovo      NaN  Categorías
# 4   45200.0    82490           Lenovo      NaN  Categorías
# 5   36684.0      NaN           Lenovo      NaN  Categorías
# 6   44765.0    92790           Kindle      NaN  Categorías
# 7   44765.0    92790           Kindle      NaN  Categorías
# 8   43205.0    92790           Lenovo      NaN  Categorías
# 9   40917.0    92790           Kindle      NaN  Categorías
# 10  40918.0      NaN           Kindle      NaN  Categorías
# 11      NaN    97890           Kindle      NaN  Categorías
# 12  45067.0   103090          SoyMomo      NaN  Categorías
# 13  45067.0   120090          SoyMomo      NaN  Categorías
# 14  43421.0   103090             Gear      NaN  Categorías

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 8 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Unnamed: 0                         48 non-null     int64
#  1   scraped                            48 non-null     object
#  2   nombre del producto:nombre:nombre  48 non-null     object
#  3   id                                 46 non-null     float64
#  4   clp                                46 non-null     object
#  5   marca fabricante                   48 non-null     object
#  6   variant                            0 non-null      float64
#  7   lista                              48 non-null     object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 3.1+ KB

# %% [markdown]
# ## 2. Columnas innecesarias o mal etiquetadas.

# %%
df=df.drop(columns=['Unnamed: 0','scraped','variant','lista'])

#Alternativa: inplace
#df.drop(columns=['Unnamed: 0','scraped','variant','lista'],inplace=True)

# %%
df=df.rename(columns={'nombre del producto:nombre:nombre':'nombre_producto',
                      'clp':'precio_clp',
                      'marca fabricante':'fabricante'})

# %%
df.head()
# Out:
#                                      nombre_producto       id precio_clp  \
# 0    Tablet Space 7" 1GB 16GB WiFi Quad Core Android  43812.0    $46,390
# 1  Tablet Space Kids 7" 1GB 16GB WiFi Quad Core A...  43813.0      51590
# 2  Tablet SoyMomo Lite 2.0 7" 2GB 16GB Wifi Quad ...      NaN      61890
# 3     Tablet Tab M7 7" HD 1GB 16GB 4G LTE Onix Black  41836.0    $72,190
# 4              Tablet M7 2 32GB 7" HD Wifi Iron grey  45200.0      82490
#
#   fabricante
# 0       Gear
# 1       Gear
# 2    SoyMomo
# 3     Lenovo
# 4     Lenovo

# %% [markdown]
# ## 3. Datos duplicados.
#
# La función `df.duplicated()` entrega una lista de valores booleans True/False que indica si un dato está duplicado o no.
#
# El argumentp `keep` define si se marca sólo el primer duplicado, el último, o todos. Para identificar duplicados parciales, se utiliza el argumento `subset`, definido como un nombre o lista de nombres de columnas a utilizar para la comparación:

# %%
#encontrar duplicados totales (sólo la primera repetición)
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7      True
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# dtype: bool

# %%
#encontrar duplicados totales (todas las repeticiones)
df.duplicated(keep=False)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6      True
# 7      True
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# dtype: bool

# %%
#ver los registros repetidos
df[df.duplicated(keep=False)]
# Out:
#                                      nombre_producto       id precio_clp  \
# 6  Kindle Touch 6" 8GB Luz frontal ajustable WiFi...  44765.0      92790
# 7  Kindle Touch 6" 8GB Luz frontal ajustable WiFi...  44765.0      92790
#
#   fabricante
# 6     Kindle
# 7     Kindle

# %%
#eliminar duplicado total (conservar sólo el primero)
df.drop_duplicates(keep='first', inplace=True)
df.head(15)
# Out:
#                                       nombre_producto       id precio_clp  \
# 0     Tablet Space 7" 1GB 16GB WiFi Quad Core Android  43812.0    $46,390
# 1   Tablet Space Kids 7" 1GB 16GB WiFi Quad Core A...  43813.0      51590
# 2   Tablet SoyMomo Lite 2.0 7" 2GB 16GB Wifi Quad ...      NaN      61890
# 3      Tablet Tab M7 7" HD 1GB 16GB 4G LTE Onix Black  41836.0    $72,190
# 4               Tablet M7 2 32GB 7" HD Wifi Iron grey  45200.0      82490
# 5   Tablet  Tab M8 8" 2GB 32GB WiFi Quad Core Andr...  36684.0        NaN
# 6   Kindle Touch 6" 8GB Luz frontal ajustable WiFi...  44765.0      92790
# 8                                            ERROR101  43205.0      92790
# 9   Kindle Touch 6" 8GB Luz frontal ajustable WiFi...  40917.0      92790
# 10  Kindle Touch 6" 8GB Luz frontal ajustable WiFi...  40918.0        NaN
# 11    Kindle Touch Luz incorporada 6" 8GB WiFi  Negro      NaN      97890
# 12  Tablet SoyMomo Pro 8" 2GB 32GB WiFi Octa Core ...  45067.0     103090
# 13  Tablet SoyMomo Pro 8" 2GB 32GB WiFi Octa Core ...  45067.0     120090
# 14  Tablet Pro T310 10,1" 2GB 32GB WiFi Quad Core ...  43421.0     103090
# 15  Tablet Smart M8 8" 2GB 32GB WiFi con Estación ...  37245.0     103090
#
#    fabricante
# 0        Gear
# 1        Gear
# 2     SoyMomo
# 3      Lenovo
# 4      Lenovo
# 5      Lenovo
# 6      Kindle
# 8      Lenovo
# 9      Kindle
# 10     Kindle
# 11     Kindle
# 12    SoyMomo
# 13    SoyMomo
# 14       Gear
# 15     Lenovo

# %%
#encontrar duplicado parcial, marcar toda las repeticiones
df.duplicated(subset='id', keep=False)
# Out:
# 0     False
# 1     False
# 2      True
# 3     False
# 4     False
# 5     False
# 6     False
# 8     False
# 9     False
# 10    False
# 11     True
# 12     True
# 13     True
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# dtype: bool

# %%
df[df.duplicated(subset=['nombre_producto','id'], keep=False)]
# Out:
#                                       nombre_producto       id precio_clp  \
# 12  Tablet SoyMomo Pro 8" 2GB 32GB WiFi Octa Core ...  45067.0     103090
# 13  Tablet SoyMomo Pro 8" 2GB 32GB WiFi Octa Core ...  45067.0     120090
#
#    fabricante
# 12    SoyMomo
# 13    SoyMomo

# %%
#reemplazamos el precio por valor promedio de los dos duplicados, y eliminamos uno de ellos
df.at[12,'precio_clp']='111590'
df.drop(index=13,inplace=True)
df
# Out:
#                                       nombre_producto       id precio_clp  \
# 0     Tablet Space 7" 1GB 16GB WiFi Quad Core Android  43812.0    $46,390
# 1   Tablet Space Kids 7" 1GB 16GB WiFi Quad Core A...  43813.0      51590
# 2   Tablet SoyMomo Lite 2.0 7" 2GB 16GB Wifi Quad ...      NaN      61890
# 3      Tablet Tab M7 7" HD 1GB 16GB 4G LTE Onix Black  41836.0    $72,190
# 4               Tablet M7 2 32GB 7" HD Wifi Iron grey  45200.0      82490
# 5   Tablet  Tab M8 8" 2GB 32GB WiFi Quad Core Andr...  36684.0        NaN
# 6   Kindle Touch 6" 8GB Luz frontal ajustable WiFi...  44765.0      92790
# 8                                            ERROR101  43205.0      92790
# 9   Kindle Touch 6" 8GB Luz frontal ajustable WiFi...  40917.0      92790
# 10  Kindle Touch 6" 8GB Luz frontal ajustable WiFi...  40918.0        NaN
# 11    Kindle Touch Luz incorporada 6" 8GB WiFi  Negro      NaN      97890
# 12  Tablet SoyMomo Pro 8" 2GB 32GB WiFi Octa Core ...  45067.0     111590
# 14  Tablet Pro T310 10,1" 2GB 32GB WiFi Quad Core ...  43421.0     103090
# 15  Tablet Smart M8 8" 2GB 32GB WiFi con Estación ...  37245.0     103090
# 16  Tablet MatePad T10 9.7" 2GB 32GB WiFi Deepsea ...  41923.0     103090
# 17  Tablet MatePad T10 LTE 9.7" 2GB 32GB WiFi Deep...  45659.0     113390
# 18  Tablet  Pro T618 10,1" 4GB 64GB WiFi Octa Core...  43420.0     118590
# 19  Tablet Galaxy Tab A7 Lite 8.7" 3GB 32GB WIFI O...  41832.0     123690
# 20     Kindle Paperwhite Waterproof 6” WiFi  8GB Azul  43360.0     133990
# 21  Tablet Matepad T10s 10.1" 4GB 64GB WiFi Deepse...  44740.0     133990
# 22     Kindle Paperwhite Waterproof 6" WiFi 8GB Negro  44768.0     133990
# 23    Tablet Matepad T8 8" 2GB 32GB WiFi Deepsea Blue  38071.0     133990
# 24  Tablet Smart Tab M10 10.1" HD 4GB 64GB Octa Co...  41837.0     133990
# 25    Kindle Paperwhite Waterproof 6" WiFi 8GB  Negro  40916.0     133990
# 26  Tablet MatePad T10 Kid 9.7" 2GB 32GB WiFi Deep...  42704.0     133990
# 27    Kindle Paperwhite Waterproof 6” WiFi 32GB Negro  43359.0     139190
# 28  Tablet Galaxy Tab A7 Lite 8.7" 3GB 32GB WIFI +...  41830.0     139190
# 29  Tablet SoyMomo Pro 2.0 8" 4GB 64GB Wifi Octa C...  45069.0     144290
# 30  Tablet Tab M10 Plus 10.3" 4GB 64GB WiFi  Plati...  37868.0     144290
# 31  Tablet Galaxy Tab A8 10.5" 3GB 32GB WiFi con B...  44882.0     159790
# 32  Tablet M10 Plus 4GB 128GB 10.3" FHD WiFi plati...  45203.0     180390
# 33  Tablet Yoga Smart 10.1" 4GB 64GB WiFi OctaCore...  37732.0     185590
# 34  Tablet Galaxy Tab A8 Lite 10.5" 3GB 32GB WiFi ...  44884.0     206190
# 35  Tablet MatePad T10S 10,1" 4GB 128GB WiFi Deeps...  45658.0     206190
# 36  Tablet Galaxy Tab S6 Lite 10.4" 4GB 64GB WiFi ...  37217.0     278390
# 37  Tablet Galaxy Tab S6 Lite 10.4" 4GB 64GB WiFi ...  37632.0     278390
# 38  Tablet Tab IdeaPad Duet Chromebook 4GB 128GB e...  43036.0     299990
# 39  Tablet Tab P11 Teclado+Lapiz 11" 6GB 128GB Wif...  40795.0     309290
# 40  Tablet MatePad 10.4" 4GB 128GB Wifi con Keyboa...  44739.0     319590
# 41  iPad 10,2" (9a Generación, Wi-Fi, 64GB) - Gris...  43590.0     350490
# 42  iPad 10,2" (9a Generación, Wi-Fi, 64GB) - Colo...  43591.0     350490
# 43  Tablet Pad 5 11" WQHD+ 6GB 128GB  Octa Core Co...  45065.0     360790
# 44  Tablet Pad 5 11" WQHD+ 6GB 128GB Octa Core Pea...  45066.0     360790
# 45  Tablet Matepad 10.4" Con Cover + Lapiz 4GB 64G...  41922.0     360790
# 46  Tablet Tab P11 6GB 128GB 11" 2K 4G LTE + Tecla...  42111.0     381490
# 47  Tablet MatePad 11" 6GB 128GB WiFi con Teclado ...  44186.0     443290
#
#    fabricante
# 0        Gear
# 1        Gear
# 2     SoyMomo
# 3      Lenovo
# 4      Lenovo
# 5      Lenovo
# 6      Kindle
# 8      Lenovo
# 9      Kindle
# 10     Kindle
# 11     Kindle
# 12    SoyMomo
# 14       Gear
# 15     Lenovo
# 16     Huawei
# 17     Huawei
# 18       Gear
# 19    Samsung
# 20     Kindle
# 21     Huawei
# 22     Kindle
# 23     Huawei
# 24     Lenovo
# 25     Kindle
# 26     Huawei
# 27     Kindle
# 28    Samsung
# 29    SoyMomo
# 30     Lenovo
# 31    Samsung
# 32     Lenovo
# 33     Lenovo
# 34    Samsung
# 35     Huawei
# 36    Samsung
# 37    Samsung
# 38     Lenovo
# 39     Lenovo
# 40     Huawei
# 41      Apple
# 42      Apple
# 43     Xiaomi
# 44     Xiaomi
# 45     Huawei
# 46     Lenovo
# 47     Huawei

# %%
#reiniciar índice para mantener orden correlativo
df.reset_index(inplace=True,drop=True)
df
# Out:
#                                       nombre_producto       id precio_clp  \
# 0     Tablet Space 7" 1GB 16GB WiFi Quad Core Android  43812.0    $46,390
# 1   Tablet Space Kids 7" 1GB 16GB WiFi Quad Core A...  43813.0      51590
# 2   Tablet SoyMomo Lite 2.0 7" 2GB 16GB Wifi Quad ...      NaN      61890
# 3      Tablet Tab M7 7" HD 1GB 16GB 4G LTE Onix Black  41836.0    $72,190
# 4               Tablet M7 2 32GB 7" HD Wifi Iron grey  45200.0      82490
# 5   Tablet  Tab M8 8" 2GB 32GB WiFi Quad Core Andr...  36684.0        NaN
# 6   Kindle Touch 6" 8GB Luz frontal ajustable WiFi...  44765.0      92790
# 7                                            ERROR101  43205.0      92790
# 8   Kindle Touch 6" 8GB Luz frontal ajustable WiFi...  40917.0      92790
# 9   Kindle Touch 6" 8GB Luz frontal ajustable WiFi...  40918.0        NaN
# 10    Kindle Touch Luz incorporada 6" 8GB WiFi  Negro      NaN      97890
# 11  Tablet SoyMomo Pro 8" 2GB 32GB WiFi Octa Core ...  45067.0     111590
# 12  Tablet Pro T310 10,1" 2GB 32GB WiFi Quad Core ...  43421.0     103090
# 13  Tablet Smart M8 8" 2GB 32GB WiFi con Estación ...  37245.0     103090
# 14  Tablet MatePad T10 9.7" 2GB 32GB WiFi Deepsea ...  41923.0     103090
# 15  Tablet MatePad T10 LTE 9.7" 2GB 32GB WiFi Deep...  45659.0     113390
# 16  Tablet  Pro T618 10,1" 4GB 64GB WiFi Octa Core...  43420.0     118590
# 17  Tablet Galaxy Tab A7 Lite 8.7" 3GB 32GB WIFI O...  41832.0     123690
# 18     Kindle Paperwhite Waterproof 6” WiFi  8GB Azul  43360.0     133990
# 19  Tablet Matepad T10s 10.1" 4GB 64GB WiFi Deepse...  44740.0     133990
# 20     Kindle Paperwhite Waterproof 6" WiFi 8GB Negro  44768.0     133990
# 21    Tablet Matepad T8 8" 2GB 32GB WiFi Deepsea Blue  38071.0     133990
# 22  Tablet Smart Tab M10 10.1" HD 4GB 64GB Octa Co...  41837.0     133990
# 23    Kindle Paperwhite Waterproof 6" WiFi 8GB  Negro  40916.0     133990
# 24  Tablet MatePad T10 Kid 9.7" 2GB 32GB WiFi Deep...  42704.0     133990
# 25    Kindle Paperwhite Waterproof 6” WiFi 32GB Negro  43359.0     139190
# 26  Tablet Galaxy Tab A7 Lite 8.7" 3GB 32GB WIFI +...  41830.0     139190
# 27  Tablet SoyMomo Pro 2.0 8" 4GB 64GB Wifi Octa C...  45069.0     144290
# 28  Tablet Tab M10 Plus 10.3" 4GB 64GB WiFi  Plati...  37868.0     144290
# 29  Tablet Galaxy Tab A8 10.5" 3GB 32GB WiFi con B...  44882.0     159790
# 30  Tablet M10 Plus 4GB 128GB 10.3" FHD WiFi plati...  45203.0     180390
# 31  Tablet Yoga Smart 10.1" 4GB 64GB WiFi OctaCore...  37732.0     185590
# 32  Tablet Galaxy Tab A8 Lite 10.5" 3GB 32GB WiFi ...  44884.0     206190
# 33  Tablet MatePad T10S 10,1" 4GB 128GB WiFi Deeps...  45658.0     206190
# 34  Tablet Galaxy Tab S6 Lite 10.4" 4GB 64GB WiFi ...  37217.0     278390
# 35  Tablet Galaxy Tab S6 Lite 10.4" 4GB 64GB WiFi ...  37632.0     278390
# 36  Tablet Tab IdeaPad Duet Chromebook 4GB 128GB e...  43036.0     299990
# 37  Tablet Tab P11 Teclado+Lapiz 11" 6GB 128GB Wif...  40795.0     309290
# 38  Tablet MatePad 10.4" 4GB 128GB Wifi con Keyboa...  44739.0     319590
# 39  iPad 10,2" (9a Generación, Wi-Fi, 64GB) - Gris...  43590.0     350490
# 40  iPad 10,2" (9a Generación, Wi-Fi, 64GB) - Colo...  43591.0     350490
# 41  Tablet Pad 5 11" WQHD+ 6GB 128GB  Octa Core Co...  45065.0     360790
# 42  Tablet Pad 5 11" WQHD+ 6GB 128GB Octa Core Pea...  45066.0     360790
# 43  Tablet Matepad 10.4" Con Cover + Lapiz 4GB 64G...  41922.0     360790
# 44  Tablet Tab P11 6GB 128GB 11" 2K 4G LTE + Tecla...  42111.0     381490
# 45  Tablet MatePad 11" 6GB 128GB WiFi con Teclado ...  44186.0     443290
#
#    fabricante
# 0        Gear
# 1        Gear
# 2     SoyMomo
# 3      Lenovo
# 4      Lenovo
# 5      Lenovo
# 6      Kindle
# 7      Lenovo
# 8      Kindle
# 9      Kindle
# 10     Kindle
# 11    SoyMomo
# 12       Gear
# 13     Lenovo
# 14     Huawei
# 15     Huawei
# 16       Gear
# 17    Samsung
# 18     Kindle
# 19     Huawei
# 20     Kindle
# 21     Huawei
# 22     Lenovo
# 23     Kindle
# 24     Huawei
# 25     Kindle
# 26    Samsung
# 27    SoyMomo
# 28     Lenovo
# 29    Samsung
# 30     Lenovo
# 31     Lenovo
# 32    Samsung
# 33     Huawei
# 34    Samsung
# 35    Samsung
# 36     Lenovo
# 37     Lenovo
# 38     Huawei
# 39      Apple
# 40      Apple
# 41     Xiaomi
# 42     Xiaomi
# 43     Huawei
# 44     Lenovo
# 45     Huawei

# %% [markdown]
# ## 4. Datos Faltantes o Nulos.
#
# Los métodos `df.isna()`y `dr.dropna()` permiten identificar y eliminar los registros con datos nulos (NaN), respectivamente.

# %%
df.isna()
# Out:
#     nombre_producto     id  precio_clp  fabricante
# 0             False  False       False       False
# 1             False  False       False       False
# 2             False   True       False       False
# 3             False  False       False       False
# 4             False  False       False       False
# 5             False  False        True       False
# 6             False  False       False       False
# 7             False  False       False       False
# 8             False  False       False       False
# 9             False  False        True       False
# 10            False   True       False       False
# 11            False  False       False       False
# 12            False  False       False       False
# 13            False  False       False       False
# 14            False  False       False       False
# 15            False  False       False       False
# 16            False  False       False       False
# 17            False  False       False       False
# 18            False  False       False       False
# 19            False  False       False       False
# 20            False  False       False       False
# 21            False  False       False       False
# 22            False  False       False       False
# 23            False  False       False       False
# 24            False  False       False       False
# 25            False  False       False       False
# 26            False  False       False       False
# 27            False  False       False       False
# 28            False  False       False       False
# 29            False  False       False       False
# 30            False  False       False       False
# 31            False  False       False       False
# 32            False  False       False       False
# 33            False  False       False       False
# 34            False  False       False       False
# 35            False  False       False       False
# 36            False  False       False       False
# 37            False  False       False       False
# 38            False  False       False       False
# 39            False  False       False       False
# 40            False  False       False       False
# 41            False  False       False       False
# 42            False  False       False       False
# 43            False  False       False       False
# 44            False  False       False       False
# 45            False  False       False       False

# %%
df.dropna(inplace=True)
df.head(10)
# Out:
#                                       nombre_producto       id precio_clp  \
# 0     Tablet Space 7" 1GB 16GB WiFi Quad Core Android  43812.0    $46,390
# 1   Tablet Space Kids 7" 1GB 16GB WiFi Quad Core A...  43813.0      51590
# 3      Tablet Tab M7 7" HD 1GB 16GB 4G LTE Onix Black  41836.0    $72,190
# 4               Tablet M7 2 32GB 7" HD Wifi Iron grey  45200.0      82490
# 6   Kindle Touch 6" 8GB Luz frontal ajustable WiFi...  44765.0      92790
# 7                                            ERROR101  43205.0      92790
# 8   Kindle Touch 6" 8GB Luz frontal ajustable WiFi...  40917.0      92790
# 11  Tablet SoyMomo Pro 8" 2GB 32GB WiFi Octa Core ...  45067.0     111590
# 12  Tablet Pro T310 10,1" 2GB 32GB WiFi Quad Core ...  43421.0     103090
# 13  Tablet Smart M8 8" 2GB 32GB WiFi con Estación ...  37245.0     103090
#
#    fabricante
# 0        Gear
# 1        Gear
# 3      Lenovo
# 4      Lenovo
# 6      Kindle
# 7      Lenovo
# 8      Kindle
# 11    SoyMomo
# 12       Gear
# 13     Lenovo

# %% [markdown]
# ¿Hay más datos "nulos" que no estén identificados como NaN? Por ejemplo, el dato `ERROR101`.
#
# ¿Cómo se corrigen o eliminan? Para que Python los trate como datos nulos, es necesario reemplazar por el valor `np.nan`.

# %%
import numpy as np
df.replace('ERROR101',np.nan,inplace=True)

# %%
df
# Out:
#                                       nombre_producto       id precio_clp  \
# 0     Tablet Space 7" 1GB 16GB WiFi Quad Core Android  43812.0    $46,390
# 1   Tablet Space Kids 7" 1GB 16GB WiFi Quad Core A...  43813.0      51590
# 3      Tablet Tab M7 7" HD 1GB 16GB 4G LTE Onix Black  41836.0    $72,190
# 4               Tablet M7 2 32GB 7" HD Wifi Iron grey  45200.0      82490
# 6   Kindle Touch 6" 8GB Luz frontal ajustable WiFi...  44765.0      92790
# 7                                                 NaN  43205.0      92790
# 8   Kindle Touch 6" 8GB Luz frontal ajustable WiFi...  40917.0      92790
# 11  Tablet SoyMomo Pro 8" 2GB 32GB WiFi Octa Core ...  45067.0     111590
# 12  Tablet Pro T310 10,1" 2GB 32GB WiFi Quad Core ...  43421.0     103090
# 13  Tablet Smart M8 8" 2GB 32GB WiFi con Estación ...  37245.0     103090
# 14  Tablet MatePad T10 9.7" 2GB 32GB WiFi Deepsea ...  41923.0     103090
# 15  Tablet MatePad T10 LTE 9.7" 2GB 32GB WiFi Deep...  45659.0     113390
# 16  Tablet  Pro T618 10,1" 4GB 64GB WiFi Octa Core...  43420.0     118590
# 17  Tablet Galaxy Tab A7 Lite 8.7" 3GB 32GB WIFI O...  41832.0     123690
# 18     Kindle Paperwhite Waterproof 6” WiFi  8GB Azul  43360.0     133990
# 19  Tablet Matepad T10s 10.1" 4GB 64GB WiFi Deepse...  44740.0     133990
# 20     Kindle Paperwhite Waterproof 6" WiFi 8GB Negro  44768.0     133990
# 21    Tablet Matepad T8 8" 2GB 32GB WiFi Deepsea Blue  38071.0     133990
# 22  Tablet Smart Tab M10 10.1" HD 4GB 64GB Octa Co...  41837.0     133990
# 23    Kindle Paperwhite Waterproof 6" WiFi 8GB  Negro  40916.0     133990
# 24  Tablet MatePad T10 Kid 9.7" 2GB 32GB WiFi Deep...  42704.0     133990
# 25    Kindle Paperwhite Waterproof 6” WiFi 32GB Negro  43359.0     139190
# 26  Tablet Galaxy Tab A7 Lite 8.7" 3GB 32GB WIFI +...  41830.0     139190
# 27  Tablet SoyMomo Pro 2.0 8" 4GB 64GB Wifi Octa C...  45069.0     144290
# 28  Tablet Tab M10 Plus 10.3" 4GB 64GB WiFi  Plati...  37868.0     144290
# 29  Tablet Galaxy Tab A8 10.5" 3GB 32GB WiFi con B...  44882.0     159790
# 30  Tablet M10 Plus 4GB 128GB 10.3" FHD WiFi plati...  45203.0     180390
# 31  Tablet Yoga Smart 10.1" 4GB 64GB WiFi OctaCore...  37732.0     185590
# 32  Tablet Galaxy Tab A8 Lite 10.5" 3GB 32GB WiFi ...  44884.0     206190
# 33  Tablet MatePad T10S 10,1" 4GB 128GB WiFi Deeps...  45658.0     206190
# 34  Tablet Galaxy Tab S6 Lite 10.4" 4GB 64GB WiFi ...  37217.0     278390
# 35  Tablet Galaxy Tab S6 Lite 10.4" 4GB 64GB WiFi ...  37632.0     278390
# 36  Tablet Tab IdeaPad Duet Chromebook 4GB 128GB e...  43036.0     299990
# 37  Tablet Tab P11 Teclado+Lapiz 11" 6GB 128GB Wif...  40795.0     309290
# 38  Tablet MatePad 10.4" 4GB 128GB Wifi con Keyboa...  44739.0     319590
# 39  iPad 10,2" (9a Generación, Wi-Fi, 64GB) - Gris...  43590.0     350490
# 40  iPad 10,2" (9a Generación, Wi-Fi, 64GB) - Colo...  43591.0     350490
# 41  Tablet Pad 5 11" WQHD+ 6GB 128GB  Octa Core Co...  45065.0     360790
# 42  Tablet Pad 5 11" WQHD+ 6GB 128GB Octa Core Pea...  45066.0     360790
# 43  Tablet Matepad 10.4" Con Cover + Lapiz 4GB 64G...  41922.0     360790
# 44  Tablet Tab P11 6GB 128GB 11" 2K 4G LTE + Tecla...  42111.0     381490
# 45  Tablet MatePad 11" 6GB 128GB WiFi con Teclado ...  44186.0     443290
#
#    fabricante
# 0        Gear
# 1        Gear
# 3      Lenovo
# 4      Lenovo
# 6      Kindle
# 7      Lenovo
# 8      Kindle
# 11    SoyMomo
# 12       Gear
# 13     Lenovo
# 14     Huawei
# 15     Huawei
# 16       Gear
# 17    Samsung
# 18     Kindle
# 19     Huawei
# 20     Kindle
# 21     Huawei
# 22     Lenovo
# 23     Kindle
# 24     Huawei
# 25     Kindle
# 26    Samsung
# 27    SoyMomo
# 28     Lenovo
# 29    Samsung
# 30     Lenovo
# 31     Lenovo
# 32    Samsung
# 33     Huawei
# 34    Samsung
# 35    Samsung
# 36     Lenovo
# 37     Lenovo
# 38     Huawei
# 39      Apple
# 40      Apple
# 41     Xiaomi
# 42     Xiaomi
# 43     Huawei
# 44     Lenovo
# 45     Huawei

# %%
#ahora podemos utilizar el método dropna, si es que decidimos eliminar estos registros del dataframe.
df.dropna(inplace=True)
df
# Out:
#                                       nombre_producto       id precio_clp  \
# 0     Tablet Space 7" 1GB 16GB WiFi Quad Core Android  43812.0    $46,390
# 1   Tablet Space Kids 7" 1GB 16GB WiFi Quad Core A...  43813.0      51590
# 3      Tablet Tab M7 7" HD 1GB 16GB 4G LTE Onix Black  41836.0    $72,190
# 4               Tablet M7 2 32GB 7" HD Wifi Iron grey  45200.0      82490
# 6   Kindle Touch 6" 8GB Luz frontal ajustable WiFi...  44765.0      92790
# 8   Kindle Touch 6" 8GB Luz frontal ajustable WiFi...  40917.0      92790
# 11  Tablet SoyMomo Pro 8" 2GB 32GB WiFi Octa Core ...  45067.0     111590
# 12  Tablet Pro T310 10,1" 2GB 32GB WiFi Quad Core ...  43421.0     103090
# 13  Tablet Smart M8 8" 2GB 32GB WiFi con Estación ...  37245.0     103090
# 14  Tablet MatePad T10 9.7" 2GB 32GB WiFi Deepsea ...  41923.0     103090
# 15  Tablet MatePad T10 LTE 9.7" 2GB 32GB WiFi Deep...  45659.0     113390
# 16  Tablet  Pro T618 10,1" 4GB 64GB WiFi Octa Core...  43420.0     118590
# 17  Tablet Galaxy Tab A7 Lite 8.7" 3GB 32GB WIFI O...  41832.0     123690
# 18     Kindle Paperwhite Waterproof 6” WiFi  8GB Azul  43360.0     133990
# 19  Tablet Matepad T10s 10.1" 4GB 64GB WiFi Deepse...  44740.0     133990
# 20     Kindle Paperwhite Waterproof 6" WiFi 8GB Negro  44768.0     133990
# 21    Tablet Matepad T8 8" 2GB 32GB WiFi Deepsea Blue  38071.0     133990
# 22  Tablet Smart Tab M10 10.1" HD 4GB 64GB Octa Co...  41837.0     133990
# 23    Kindle Paperwhite Waterproof 6" WiFi 8GB  Negro  40916.0     133990
# 24  Tablet MatePad T10 Kid 9.7" 2GB 32GB WiFi Deep...  42704.0     133990
# 25    Kindle Paperwhite Waterproof 6” WiFi 32GB Negro  43359.0     139190
# 26  Tablet Galaxy Tab A7 Lite 8.7" 3GB 32GB WIFI +...  41830.0     139190
# 27  Tablet SoyMomo Pro 2.0 8" 4GB 64GB Wifi Octa C...  45069.0     144290
# 28  Tablet Tab M10 Plus 10.3" 4GB 64GB WiFi  Plati...  37868.0     144290
# 29  Tablet Galaxy Tab A8 10.5" 3GB 32GB WiFi con B...  44882.0     159790
# 30  Tablet M10 Plus 4GB 128GB 10.3" FHD WiFi plati...  45203.0     180390
# 31  Tablet Yoga Smart 10.1" 4GB 64GB WiFi OctaCore...  37732.0     185590
# 32  Tablet Galaxy Tab A8 Lite 10.5" 3GB 32GB WiFi ...  44884.0     206190
# 33  Tablet MatePad T10S 10,1" 4GB 128GB WiFi Deeps...  45658.0     206190
# 34  Tablet Galaxy Tab S6 Lite 10.4" 4GB 64GB WiFi ...  37217.0     278390
# 35  Tablet Galaxy Tab S6 Lite 10.4" 4GB 64GB WiFi ...  37632.0     278390
# 36  Tablet Tab IdeaPad Duet Chromebook 4GB 128GB e...  43036.0     299990
# 37  Tablet Tab P11 Teclado+Lapiz 11" 6GB 128GB Wif...  40795.0     309290
# 38  Tablet MatePad 10.4" 4GB 128GB Wifi con Keyboa...  44739.0     319590
# 39  iPad 10,2" (9a Generación, Wi-Fi, 64GB) - Gris...  43590.0     350490
# 40  iPad 10,2" (9a Generación, Wi-Fi, 64GB) - Colo...  43591.0     350490
# 41  Tablet Pad 5 11" WQHD+ 6GB 128GB  Octa Core Co...  45065.0     360790
# 42  Tablet Pad 5 11" WQHD+ 6GB 128GB Octa Core Pea...  45066.0     360790
# 43  Tablet Matepad 10.4" Con Cover + Lapiz 4GB 64G...  41922.0     360790
# 44  Tablet Tab P11 6GB 128GB 11" 2K 4G LTE + Tecla...  42111.0     381490
# 45  Tablet MatePad 11" 6GB 128GB WiFi con Teclado ...  44186.0     443290
#
#    fabricante
# 0        Gear
# 1        Gear
# 3      Lenovo
# 4      Lenovo
# 6      Kindle
# 8      Kindle
# 11    SoyMomo
# 12       Gear
# 13     Lenovo
# 14     Huawei
# 15     Huawei
# 16       Gear
# 17    Samsung
# 18     Kindle
# 19     Huawei
# 20     Kindle
# 21     Huawei
# 22     Lenovo
# 23     Kindle
# 24     Huawei
# 25     Kindle
# 26    Samsung
# 27    SoyMomo
# 28     Lenovo
# 29    Samsung
# 30     Lenovo
# 31     Lenovo
# 32    Samsung
# 33     Huawei
# 34    Samsung
# 35    Samsung
# 36     Lenovo
# 37     Lenovo
# 38     Huawei
# 39      Apple
# 40      Apple
# 41     Xiaomi
# 42     Xiaomi
# 43     Huawei
# 44     Lenovo
# 45     Huawei

# %% [markdown]
# Es importante notar que no siempre es necesario eliminar datos para los cuales alguna de las columnas tienen valor nulo Si el valor nulo corresoonde a una variable que no es esencial para el análisis, entonces se puede conservar el dato y así aprovechar la información contenida en las otras columnas. El argumento `subset` permite especificar la lista de columnas a considerar para la eliminación de datos nulos.

# %% [markdown]
# ## 5. Tipos de datos.

# %%
#Revisamos los tipos de dato de cada columna
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 42 entries, 0 to 45
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   nombre_producto  42 non-null     object
#  1   id               42 non-null     float64
#  2   precio_clp       42 non-null     object
#  3   fabricante       42 non-null     object
# dtypes: float64(1), object(3)
# memory usage: 1.6+ KB

# %% [markdown]
# Hay tipos de datos que no son adecuados al tratamiento que se le quiere dar a cada columna. Por ejemplo, el `id` debería ser un número entero, y el `precio_clp` debería ser tratado como un dato numérico, de manera de poder aplicar funciones matemáticas.<br>
#
# Por ejemplo, si queremos calcular el precio promedio, obtendríamos un error, dado que no es posible calcular el promedio de una serie tipo `object`.

# %%
#Este comando arroja un error
df['precio_clp'].mean()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/nanops.py in _ensure_numeric(x)
#    1629         try:
# -> 1630             x = float(x)
#    1631         except (TypeError, ValueError):
#
# ValueError: could not convert string to float: '$46,39051590$72,19082490927909279092790111590103090103090103090113390118590123690133990133990133990133990133990133990133990139190139190144290144290159790180390185590206190206190278390278390299990309290319590350490350490360790360790360790381490443290'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/nanops.py in _ensure_numeric(x)
#    1633             try:
# -> 1634                 x = complex(x)
#    1635             except ValueError as err:
#
# ValueError: complex() arg is a malformed string
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-0ef5587e6daf> in <module>
#       1 #Este comando arroja un error
# ----> 2 df['precio_clp'].mean()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11845             **kwargs,
#   11846         ):
# > 11847             return NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11848
#   11849         setattr(cls, "mean", mean)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11399         **kwargs,
#   11400     ) -> Series | float:
# > 11401         return self._stat_function(
#   11402             "mean", nanops.nanmean, axis, skipna, level, numeric_only, **kwargs
#   11403         )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in _stat_function(self, name, func, axis, skipna, level, numeric_only, **kwargs)
#   11351                 name, axis=axis, level=level, skipna=skipna, numeric_only=numeric_only
#   11352             )
# > 11353         return self._reduce(
#   11354             func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11355         )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4814                 )
#    4815             with np.errstate(all="ignore"):
# -> 4816                 return op(delegate, skipna=skipna, **kwds)
#    4817
#    4818     def _reindex_indexer(
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/nanops.py in _f(*args, **kwargs)
#      91             try:
#      92                 with np.errstate(invalid="ignore"):
# ---> 93                     return f(*args, **kwargs)
#      94             except ValueError as e:
#      95                 # we want to transform an object array
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/nanops.py in f(values, axis, skipna, **kwds)
#     153                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     154             else:
# --> 155                 result = alt(values, axis=axis, skipna=skipna, **kwds)
#     156
#     157             return result
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/nanops.py in new_func(values, axis, skipna, mask, **kwargs)
#     416             mask = isna(values)
#     417
# --> 418         result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     419
#     420         if datetimelike:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/nanops.py in nanmean(values, axis, skipna, mask)
#     704
#     705     count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 706     the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     707
#     708     if axis is not None and getattr(the_sum, "ndim", False):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/nanops.py in _ensure_numeric(x)
#    1635             except ValueError as err:
#    1636                 # e.g. "foo"
# -> 1637                 raise TypeError(f"Could not convert {x} to numeric") from err
#    1638     return x
#    1639
#
# TypeError: Could not convert $46,39051590$72,19082490927909279092790111590103090103090103090113390118590123690133990133990133990133990133990133990133990139190139190144290144290159790180390185590206190206190278390278390299990309290319590350490350490360790360790360790381490443290 to numeric

# %% [markdown]
# Por lo tanto, se requiere convertir la variable `precio_clp` al tipo de datos `float`. Sin embargo, esto no es posible isn antes aplicar algunas operaciones de limpieza de strings, para llevar los datos a un formato numérico que puede ser convertido a `float`.

# %%
#Primero convertimos el tipo de dato de 'id'
df['id']=df['id'].astype(int)

# %% [markdown]
# El siguiente comando genera un error, ya que los datos en `precio_clp` contienen caracteres como `$` y `,` que deben ser eliminados antes de convertir a float.

# %%
#Este comando genera un error, ya que los datos en precio_clp contienen caracteres como $ y , que deben ser eliminados antes de convertir a float.
df['precio_clp']=df['precio_clp'].astype(float)

# %%
df.head()

# %% [markdown]
# ## 6. Limpieza de strings.
#
# Pandas implementa métodos de strings de Python en forma vectorizada para una serie, mediante el atributo `str`:
#
# https://pandas.pydata.org/docs/reference/api/pandas.Series.str.html

# %%
#Eliminar caracter $ reemplazando por un caracter vacío.
df['precio_clp']=df['precio_clp'].str.replace('$','')
df
# Out:
# <ipython-input-50-fa2c2503d7e9>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['precio_clp']=df['precio_clp'].str.replace('$','')
#                                       nombre_producto     id precio_clp  \
# 0     Tablet Space 7" 1GB 16GB WiFi Quad Core Android  43812     46,390
# 1   Tablet Space Kids 7" 1GB 16GB WiFi Quad Core A...  43813      51590
# 3      Tablet Tab M7 7" HD 1GB 16GB 4G LTE Onix Black  41836     72,190
# 4               Tablet M7 2 32GB 7" HD Wifi Iron grey  45200      82490
# 6   Kindle Touch 6" 8GB Luz frontal ajustable WiFi...  44765      92790
# 7                                            ERROR101  43205      92790
# 8   Kindle Touch 6" 8GB Luz frontal ajustable WiFi...  40917      92790
# 11  Tablet SoyMomo Pro 8" 2GB 32GB WiFi Octa Core ...  45067     111590
# 12  Tablet Pro T310 10,1" 2GB 32GB WiFi Quad Core ...  43421     103090
# 13  Tablet Smart M8 8" 2GB 32GB WiFi con Estación ...  37245     103090
# 14  Tablet MatePad T10 9.7" 2GB 32GB WiFi Deepsea ...  41923     103090
# 15  Tablet MatePad T10 LTE 9.7" 2GB 32GB WiFi Deep...  45659     113390
# 16  Tablet  Pro T618 10,1" 4GB 64GB WiFi Octa Core...  43420     118590
# 17  Tablet Galaxy Tab A7 Lite 8.7" 3GB 32GB WIFI O...  41832     123690
# 18     Kindle Paperwhite Waterproof 6” WiFi  8GB Azul  43360     133990
# 19  Tablet Matepad T10s 10.1" 4GB 64GB WiFi Deepse...  44740     133990
# 20     Kindle Paperwhite Waterproof 6" WiFi 8GB Negro  44768     133990
# 21    Tablet Matepad T8 8" 2GB 32GB WiFi Deepsea Blue  38071     133990
# 22  Tablet Smart Tab M10 10.1" HD 4GB 64GB Octa Co...  41837     133990
# 23    Kindle Paperwhite Waterproof 6" WiFi 8GB  Negro  40916     133990
# 24  Tablet MatePad T10 Kid 9.7" 2GB 32GB WiFi Deep...  42704     133990
# 25    Kindle Paperwhite Waterproof 6” WiFi 32GB Negro  43359     139190
# 26  Tablet Galaxy Tab A7 Lite 8.7" 3GB 32GB WIFI +...  41830     139190
# 27  Tablet SoyMomo Pro 2.0 8" 4GB 64GB Wifi Octa C...  45069     144290
# 28  Tablet Tab M10 Plus 10.3" 4GB 64GB WiFi  Plati...  37868     144290
# 29  Tablet Galaxy Tab A8 10.5" 3GB 32GB WiFi con B...  44882     159790
# 30  Tablet M10 Plus 4GB 128GB 10.3" FHD WiFi plati...  45203     180390
# 31  Tablet Yoga Smart 10.1" 4GB 64GB WiFi OctaCore...  37732     185590
# 32  Tablet Galaxy Tab A8 Lite 10.5" 3GB 32GB WiFi ...  44884     206190
# 33  Tablet MatePad T10S 10,1" 4GB 128GB WiFi Deeps...  45658     206190
# 34  Tablet Galaxy Tab S6 Lite 10.4" 4GB 64GB WiFi ...  37217     278390
# 35  Tablet Galaxy Tab S6 Lite 10.4" 4GB 64GB WiFi ...  37632     278390
# 36  Tablet Tab IdeaPad Duet Chromebook 4GB 128GB e...  43036     299990
# 37  Tablet Tab P11 Teclado+Lapiz 11" 6GB 128GB Wif...  40795     309290
# 38  Tablet MatePad 10.4" 4GB 128GB Wifi con Keyboa...  44739     319590
# 39  iPad 10,2" (9a Generación, Wi-Fi, 64GB) - Gris...  43590     350490
# 40  iPad 10,2" (9a Generación, Wi-Fi, 64GB) - Colo...  43591     350490
# 41  Tablet Pad 5 11" WQHD+ 6GB 128GB  Octa Core Co...  45065     360790
# 42  Tablet Pad 5 11" WQHD+ 6GB 128GB Octa Core Pea...  45066     360790
# 43  Tablet Matepad 10.4" Con Cover + Lapiz 4GB 64G...  41922     360790
# 44  Tablet Tab P11 6GB 128GB 11" 2K 4G LTE + Tecla...  42111     381490
# 45  Tablet MatePad 11" 6GB 128GB WiFi con Teclado ...  44186     443290
#
#    fabricante
# 0        Gear
# 1        Gear
# 3      Lenovo
# 4      Lenovo
# 6      Kindle
# 7      Lenovo
# 8      Kindle
# 11    SoyMomo
# 12       Gear
# 13     Lenovo
# 14     Huawei
# 15     Huawei
# 16       Gear
# 17    Samsung
# 18     Kindle
# 19     Huawei
# 20     Kindle
# 21     Huawei
# 22     Lenovo
# 23     Kindle
# 24     Huawei
# 25     Kindle
# 26    Samsung
# 27    SoyMomo
# 28     Lenovo
# 29    Samsung
# 30     Lenovo
# 31     Lenovo
# 32    Samsung
# 33     Huawei
# 34    Samsung
# 35    Samsung
# 36     Lenovo
# 37     Lenovo
# 38     Huawei
# 39      Apple
# 40      Apple
# 41     Xiaomi
# 42     Xiaomi
# 43     Huawei
# 44     Lenovo
# 45     Huawei

# %%
#Eliminar caracter , reemplazando por un caracter vacío.
df['precio_clp']=df['precio_clp'].str.replace(',','')
df
# Out:
#                                       nombre_producto     id precio_clp  \
# 0     Tablet Space 7" 1GB 16GB WiFi Quad Core Android  43812      46390
# 1   Tablet Space Kids 7" 1GB 16GB WiFi Quad Core A...  43813      51590
# 3      Tablet Tab M7 7" HD 1GB 16GB 4G LTE Onix Black  41836      72190
# 4               Tablet M7 2 32GB 7" HD Wifi Iron grey  45200      82490
# 6   Kindle Touch 6" 8GB Luz frontal ajustable WiFi...  44765      92790
# 7                                            ERROR101  43205      92790
# 8   Kindle Touch 6" 8GB Luz frontal ajustable WiFi...  40917      92790
# 11  Tablet SoyMomo Pro 8" 2GB 32GB WiFi Octa Core ...  45067     111590
# 12  Tablet Pro T310 10,1" 2GB 32GB WiFi Quad Core ...  43421     103090
# 13  Tablet Smart M8 8" 2GB 32GB WiFi con Estación ...  37245     103090
# 14  Tablet MatePad T10 9.7" 2GB 32GB WiFi Deepsea ...  41923     103090
# 15  Tablet MatePad T10 LTE 9.7" 2GB 32GB WiFi Deep...  45659     113390
# 16  Tablet  Pro T618 10,1" 4GB 64GB WiFi Octa Core...  43420     118590
# 17  Tablet Galaxy Tab A7 Lite 8.7" 3GB 32GB WIFI O...  41832     123690
# 18     Kindle Paperwhite Waterproof 6” WiFi  8GB Azul  43360     133990
# 19  Tablet Matepad T10s 10.1" 4GB 64GB WiFi Deepse...  44740     133990
# 20     Kindle Paperwhite Waterproof 6" WiFi 8GB Negro  44768     133990
# 21    Tablet Matepad T8 8" 2GB 32GB WiFi Deepsea Blue  38071     133990
# 22  Tablet Smart Tab M10 10.1" HD 4GB 64GB Octa Co...  41837     133990
# 23    Kindle Paperwhite Waterproof 6" WiFi 8GB  Negro  40916     133990
# 24  Tablet MatePad T10 Kid 9.7" 2GB 32GB WiFi Deep...  42704     133990
# 25    Kindle Paperwhite Waterproof 6” WiFi 32GB Negro  43359     139190
# 26  Tablet Galaxy Tab A7 Lite 8.7" 3GB 32GB WIFI +...  41830     139190
# 27  Tablet SoyMomo Pro 2.0 8" 4GB 64GB Wifi Octa C...  45069     144290
# 28  Tablet Tab M10 Plus 10.3" 4GB 64GB WiFi  Plati...  37868     144290
# 29  Tablet Galaxy Tab A8 10.5" 3GB 32GB WiFi con B...  44882     159790
# 30  Tablet M10 Plus 4GB 128GB 10.3" FHD WiFi plati...  45203     180390
# 31  Tablet Yoga Smart 10.1" 4GB 64GB WiFi OctaCore...  37732     185590
# 32  Tablet Galaxy Tab A8 Lite 10.5" 3GB 32GB WiFi ...  44884     206190
# 33  Tablet MatePad T10S 10,1" 4GB 128GB WiFi Deeps...  45658     206190
# 34  Tablet Galaxy Tab S6 Lite 10.4" 4GB 64GB WiFi ...  37217     278390
# 35  Tablet Galaxy Tab S6 Lite 10.4" 4GB 64GB WiFi ...  37632     278390
# 36  Tablet Tab IdeaPad Duet Chromebook 4GB 128GB e...  43036     299990
# 37  Tablet Tab P11 Teclado+Lapiz 11" 6GB 128GB Wif...  40795     309290
# 38  Tablet MatePad 10.4" 4GB 128GB Wifi con Keyboa...  44739     319590
# 39  iPad 10,2" (9a Generación, Wi-Fi, 64GB) - Gris...  43590     350490
# 40  iPad 10,2" (9a Generación, Wi-Fi, 64GB) - Colo...  43591     350490
# 41  Tablet Pad 5 11" WQHD+ 6GB 128GB  Octa Core Co...  45065     360790
# 42  Tablet Pad 5 11" WQHD+ 6GB 128GB Octa Core Pea...  45066     360790
# 43  Tablet Matepad 10.4" Con Cover + Lapiz 4GB 64G...  41922     360790
# 44  Tablet Tab P11 6GB 128GB 11" 2K 4G LTE + Tecla...  42111     381490
# 45  Tablet MatePad 11" 6GB 128GB WiFi con Teclado ...  44186     443290
#
#    fabricante
# 0        Gear
# 1        Gear
# 3      Lenovo
# 4      Lenovo
# 6      Kindle
# 7      Lenovo
# 8      Kindle
# 11    SoyMomo
# 12       Gear
# 13     Lenovo
# 14     Huawei
# 15     Huawei
# 16       Gear
# 17    Samsung
# 18     Kindle
# 19     Huawei
# 20     Kindle
# 21     Huawei
# 22     Lenovo
# 23     Kindle
# 24     Huawei
# 25     Kindle
# 26    Samsung
# 27    SoyMomo
# 28     Lenovo
# 29    Samsung
# 30     Lenovo
# 31     Lenovo
# 32    Samsung
# 33     Huawei
# 34    Samsung
# 35    Samsung
# 36     Lenovo
# 37     Lenovo
# 38     Huawei
# 39      Apple
# 40      Apple
# 41     Xiaomi
# 42     Xiaomi
# 43     Huawei
# 44     Lenovo
# 45     Huawei

# %% [markdown]
# Ahora sí es posible convertir a `float`:

# %%
df['precio_clp']=df['precio_clp'].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 42 entries, 0 to 45
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   nombre_producto  42 non-null     object
#  1   id               42 non-null     int64
#  2   precio_clp       42 non-null     float64
#  3   fabricante       42 non-null     object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 1.6+ KB

# %%
#Y podemos calcular el precio promedio de un Tablet.
df['precio_clp'].mean()
# Out:
# 186770.95238095237
