# %% [markdown]
# # Instalar librería darts si es necesario

# %%
# %pip install darts
# Out:
# Collecting darts
#   Downloading darts-0.31.0-py3-none-any.whl (934 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 934.2/934.2 kB 8.0 MB/s eta 0:00:0000:0100:01
# Collecting holidays>=0.11.1
#   Downloading holidays-0.59-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 20.3 MB/s eta 0:00:0000:01
# Requirement already satisfied: joblib>=0.16.0 in /opt/homebrew/lib/python3.11/site-packages (from darts) (1.2.0)
# Requirement already satisfied: matplotlib>=3.3.0 in /opt/homebrew/lib/python3.11/site-packages (from darts) (3.7.1)
# Collecting nfoursid>=1.0.0
#   Downloading nfoursid-1.0.1-py3-none-any.whl (16 kB)
# Requirement already satisfied: numpy<2.0.0,>=1.19.0 in /opt/homebrew/lib/python3.11/site-packages (from darts) (1.23.5)
# Requirement already satisfied: pmdarima>=1.8.0 in /opt/homebrew/lib/python3.11/site-packages (from darts) (2.0.4)
# Requirement already satisfied: pyod>=0.9.5 in /opt/homebrew/lib/python3.11/site-packages (from darts) (1.1.0)
# Requirement already satisfied: requests>=2.22.0 in /opt/homebrew/lib/python3.11/site-packages (from darts) (2.31.0)
# Requirement already satisfied: scikit-learn>=1.0.1 in /opt/homebrew/lib/python3.11/site-packages (from darts) (1.2.2)
# Requirement already satisfied: scipy>=1.3.2 in /opt/homebrew/lib/python3.11/site-packages (from darts) (1.10.1)
# Collecting shap>=0.40.0
#   Downloading shap-0.46.0-cp311-cp311-macosx_11_0_arm64.whl (455 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 455.8/455.8 kB 21.1 MB/s eta 0:00:00
# Collecting statsforecast>=1.4
#   Downloading statsforecast-1.7.8-cp311-cp311-macosx_11_0_arm64.whl (275 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 275.1/275.1 kB 11.8 MB/s eta 0:00:00
# Requirement already satisfied: statsmodels>=0.14.0 in /opt/homebrew/lib/python3.11/site-packages (from darts) (0.14.0)
# Collecting tbats>=1.1.0
#   Using cached tbats-1.1.3-py3-none-any.whl (44 kB)
# Requirement already satisfied: tqdm>=4.60.0 in /opt/homebrew/lib/python3.11/site-packages (from darts) (4.65.0)
# Requirement already satisfied: typing-extensions in /opt/homebrew/lib/python3.11/site-packages (from darts) (4.8.0)
# Collecting xarray>=0.17.0
#   Downloading xarray-2024.9.0-py3-none-any.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 32.7 MB/s eta 0:00:0000:01
# Requirement already satisfied: xgboost>=1.6.0 in /opt/homebrew/lib/python3.11/site-packages (from darts) (2.0.0)
# Collecting pytorch-lightning>=1.5.0
#   Downloading pytorch_lightning-2.4.0-py3-none-any.whl (815 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 815.2/815.2 kB 22.6 MB/s eta 0:00:00
# Collecting tensorboardX>=2.1
#   Downloading tensorboardX-2.6.2.2-py2.py3-none-any.whl (101 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 10.2 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.8.0 in /opt/homebrew/lib/python3.11/site-packages (from darts) (2.1.1)
# Requirement already satisfied: pandas>=1.0.5 in /opt/homebrew/lib/python3.11/site-packages (from darts) (1.5.3)
# Requirement already satisfied: python-dateutil in /Users/ldavico/Library/Python/3.11/lib/python/site-packages (from holidays>=0.11.1->darts) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib>=3.3.0->darts) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib>=3.3.0->darts) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib>=3.3.0->darts) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib>=3.3.0->darts) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/ldavico/Library/Python/3.11/lib/python/site-packages (from matplotlib>=3.3.0->darts) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib>=3.3.0->darts) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib>=3.3.0->darts) (3.0.9)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/lib/python3.11/site-packages (from pandas>=1.0.5->darts) (2022.7.1)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /opt/homebrew/lib/python3.11/site-packages (from pmdarima>=1.8.0->darts) (0.29.35)
# Requirement already satisfied: urllib3 in /opt/homebrew/lib/python3.11/site-packages (from pmdarima>=1.8.0->darts) (2.0.7)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /opt/homebrew/lib/python3.11/site-packages (from pmdarima>=1.8.0->darts) (67.6.1)
# Requirement already satisfied: numba>=0.51 in /opt/homebrew/lib/python3.11/site-packages (from pyod>=0.9.5->darts) (0.57.1)
# Requirement already satisfied: six in /opt/homebrew/lib/python3.11/site-packages (from pyod>=0.9.5->darts) (1.16.0)
# Requirement already satisfied: PyYAML>=5.4 in /opt/homebrew/lib/python3.11/site-packages (from pytorch-lightning>=1.5.0->darts) (6.0)
# Requirement already satisfied: fsspec[http]>=2022.5.0 in /opt/homebrew/lib/python3.11/site-packages (from pytorch-lightning>=1.5.0->darts) (2023.9.2)
# Collecting torchmetrics>=0.7.0
#   Downloading torchmetrics-1.5.1-py3-none-any.whl (890 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 890.6/890.6 kB 17.4 MB/s eta 0:00:0000:01
# Collecting lightning-utilities>=0.10.0
#   Downloading lightning_utilities-0.11.8-py3-none-any.whl (26 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/homebrew/lib/python3.11/site-packages (from requests>=2.22.0->darts) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/lib/python3.11/site-packages (from requests>=2.22.0->darts) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/lib/python3.11/site-packages (from requests>=2.22.0->darts) (2022.12.7)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/homebrew/lib/python3.11/site-packages (from scikit-learn>=1.0.1->darts) (3.1.0)
# Collecting slicer==0.0.8
#   Downloading slicer-0.0.8-py3-none-any.whl (15 kB)
# Requirement already satisfied: cloudpickle in /opt/homebrew/lib/python3.11/site-packages (from shap>=0.40.0->darts) (2.2.1)
# Collecting coreforecast>=0.0.12
#   Downloading coreforecast-0.0.13.1-cp311-cp311-macosx_11_0_arm64.whl (196 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.9/196.9 kB 12.0 MB/s eta 0:00:00
# Collecting fugue>=0.8.1
#   Downloading fugue-0.9.1-py3-none-any.whl (278 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 14.4 MB/s eta 0:00:00
# Collecting utilsforecast>=0.1.4
#   Downloading utilsforecast-0.2.7-py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.4/41.4 kB 1.9 MB/s eta 0:00:00
# Requirement already satisfied: patsy>=0.5.2 in /opt/homebrew/lib/python3.11/site-packages (from statsmodels>=0.14.0->darts) (0.5.3)
# Requirement already satisfied: protobuf>=3.20 in /opt/homebrew/lib/python3.11/site-packages (from tensorboardX>=2.1->darts) (3.20.3)
# Requirement already satisfied: filelock in /opt/homebrew/lib/python3.11/site-packages (from torch>=1.8.0->darts) (3.12.4)
# Requirement already satisfied: sympy in /opt/homebrew/lib/python3.11/site-packages (from torch>=1.8.0->darts) (1.12)
# Requirement already satisfied: networkx in /opt/homebrew/lib/python3.11/site-packages (from torch>=1.8.0->darts) (3.1)
# Requirement already satisfied: jinja2 in /opt/homebrew/lib/python3.11/site-packages (from torch>=1.8.0->darts) (3.1.2)
# Collecting numpy<2.0.0,>=1.19.0
#   Downloading numpy-1.26.4-cp311-cp311-macosx_11_0_arm64.whl (14.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.0/14.0 MB 8.2 MB/s eta 0:00:0000:0100:01
# Collecting packaging>=20.0
#   Downloading packaging-24.1-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.0/54.0 kB 2.6 MB/s eta 0:00:00
# Collecting pandas>=1.0.5
#   Downloading pandas-2.2.3-cp311-cp311-macosx_11_0_arm64.whl (11.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 13.2 MB/s eta 0:00:0000:0100:01
# Collecting tzdata>=2022.7
#   Downloading tzdata-2024.2-py2.py3-none-any.whl (346 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 346.6/346.6 kB 18.4 MB/s eta 0:00:00
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /opt/homebrew/lib/python3.11/site-packages (from fsspec[http]>=2022.5.0->pytorch-lightning>=1.5.0->darts) (3.8.5)
# Collecting triad>=0.9.7
#   Downloading triad-0.9.8-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 5.0 MB/s eta 0:00:00
# Collecting adagio>=0.2.4
#   Downloading adagio-0.2.6-py3-none-any.whl (19 kB)
# Requirement already satisfied: llvmlite<0.41,>=0.40.0dev0 in /opt/homebrew/lib/python3.11/site-packages (from numba>=0.51->pyod>=0.9.5->darts) (0.40.1)
# Collecting numpy<2.0.0,>=1.19.0
#   Downloading numpy-1.24.4-cp311-cp311-macosx_11_0_arm64.whl (13.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 7.9 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/homebrew/lib/python3.11/site-packages (from jinja2->torch>=1.8.0->darts) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /opt/homebrew/lib/python3.11/site-packages (from sympy->torch>=1.8.0->darts) (1.3.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/homebrew/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=1.5.0->darts) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/homebrew/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=1.5.0->darts) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /opt/homebrew/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=1.5.0->darts) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/homebrew/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=1.5.0->darts) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/homebrew/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=1.5.0->darts) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/homebrew/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=1.5.0->darts) (1.3.1)
# Requirement already satisfied: pyarrow>=6.0.1 in /opt/homebrew/lib/python3.11/site-packages (from triad>=0.9.7->fugue>=0.8.1->statsforecast>=1.4->darts) (11.0.0)
# Collecting fs
#   Downloading fs-2.4.16-py2.py3-none-any.whl (135 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.3/135.3 kB 8.8 MB/s eta 0:00:00
# Collecting appdirs~=1.4.3
#   Using cached appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Installing collected packages: appdirs, tzdata, slicer, packaging, numpy, fs, tensorboardX, pandas, lightning-utilities, holidays, coreforecast, xarray, utilsforecast, triad, torchmetrics, shap, pytorch-lightning, nfoursid, adagio, tbats, fugue, statsforecast, darts
#   Attempting uninstall: packaging
#     Found existing installation: packaging 23.0
#     Uninstalling packaging-23.0:
#       Successfully uninstalled packaging-23.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.23.5
#     Uninstalling numpy-1.23.5:
#       Successfully uninstalled numpy-1.23.5
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.5.3
#     Uninstalling pandas-1.5.3:
#       Successfully uninstalled pandas-1.5.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# aequitas 1.0.0 requires numpy==1.23.5, but you have numpy 1.24.4 which is incompatible.
# awswrangler 3.0.0 requires pandas!=1.5.0,<2.0.0,>=1.2.0, but you have pandas 2.2.3 which is incompatible.
# torchvision 0.16.0 requires torch==2.1.0, but you have torch 2.1.1 which is incompatible.
# sktime 0.20.0 requires pandas<2.1.0,>=1.1.0, but you have pandas 2.2.3 which is incompatible.
# Successfully installed adagio-0.2.6 appdirs-1.4.4 coreforecast-0.0.13.1 darts-0.31.0 fs-2.4.16 fugue-0.9.1 holidays-0.59 lightning-utilities-0.11.8 nfoursid-1.0.1 numpy-1.24.4 packaging-24.1 pandas-2.2.3 pytorch-lightning-2.4.0 shap-0.46.0 slicer-0.0.8 statsforecast-1.7.8 tbats-1.1.3 tensorboardX-2.6.2.2 torchmetrics-1.5.1 triad-0.9.8 tzdata-2024.2 utilsforecast-0.2.7 xarray-2024.9.0
#
# [notice] A new release of pip is available: 23.0.1 -> 24.2
# [notice] To update, run: python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Importar Librerias

# %%
import pandas as pd
from darts import TimeSeries
import matplotlib.pyplot as plt
from scipy.stats import boxcox
import numpy as np
from darts.datasets import AirPassengersDataset

# %% [markdown]
# # Cargar data de libreria darts

# %%
dataset = AirPassengersDataset()
series = dataset.load()

# %%
series.plot()
plt.show()

# %% [markdown]
# # Transformación de Serie Temporal

# %% [markdown]
# ## Logaritmo

# %%
log_data = np.log(series.pd_series())
log_series = TimeSeries.from_series(log_data)

log_series.plot()
plt.show()

# %% [markdown]
# ## Diferenciación

# %%
diff_series = series.diff()
diff_series.plot()
plt.show()

# %% [markdown]
# # Box-Cox

# %%
values = series.pd_series().values
boxcox_values, lambda_value = boxcox(values)
print(f'Lambda: {lambda_value}')
# Out:
# Lambda: 0.14802265137037945

# %%
boxcox_series = TimeSeries.from_values(boxcox_values)
boxcox_series.plot()
plt.show()
