# %% [markdown]
# <center><h1> MCD - Ciencia de Datos Responsable </h1><center>
# <center><h2> Tutorial 6: AIF360 Toolkit<h2></center>
#
#
# ![AIF360](https://opengraph.githubassets.com/4b7ff9fccf4e6cafd9e59f42921b31a0f7f6696b009c8519e584be278094769d/Trusted-AI/AIF360)

# %%
#@title Instalar la librería
# !pip install aif360['all']
# Out:
# Requirement already satisfied: aif360[all] in /opt/homebrew/lib/python3.11/site-packages (0.6.0)
# Requirement already satisfied: numpy>=1.16 in /opt/homebrew/lib/python3.11/site-packages (from aif360[all]) (1.23.5)
# Requirement already satisfied: scipy>=1.2.0 in /opt/homebrew/lib/python3.11/site-packages (from aif360[all]) (1.10.1)
# Requirement already satisfied: pandas>=0.24.0 in /opt/homebrew/lib/python3.11/site-packages (from aif360[all]) (1.5.3)
# Requirement already satisfied: scikit-learn>=1.0 in /opt/homebrew/lib/python3.11/site-packages (from aif360[all]) (1.2.2)
# Requirement already satisfied: matplotlib in /opt/homebrew/lib/python3.11/site-packages (from aif360[all]) (3.7.1)
# Collecting adversarial-robustness-toolbox>=1.0.0
#   Downloading adversarial_robustness_toolbox-1.17.1-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 1.5 MB/s eta 0:00:00a 0:00:01m
# Collecting igraph[plotting]
#   Downloading igraph-0.11.4-cp39-abi3-macosx_11_0_arm64.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 5.1 MB/s eta 0:00:0000:0100:01m
# Requirement already satisfied: fairlearn~=0.7 in /opt/homebrew/lib/python3.11/site-packages (from aif360[all]) (0.9.0)
# Collecting tensorflow>=1.13.1
#   Downloading tensorflow-2.16.1-cp311-cp311-macosx_12_0_arm64.whl (227.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.0/227.0 MB 4.0 MB/s eta 0:00:0000:0100:02
# Collecting jupyter
#   Using cached jupyter-1.0.0-py2.py3-none-any.whl (2.7 kB)
# Collecting rpy2
#   Downloading rpy2-3.5.16-cp311-cp311-macosx_10_9_universal2.whl (299 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 299.9/299.9 kB 8.2 MB/s eta 0:00:0000:01
# Collecting skorch
#   Downloading skorch-0.15.0-py3-none-any.whl (239 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.3/239.3 kB 6.6 MB/s eta 0:00:00
# Collecting inFairness>=0.2.2
#   Downloading inFairness-0.2.3-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.8/45.8 kB 3.0 MB/s eta 0:00:00
# Collecting cvxpy>=1.0
#   Downloading cvxpy-1.4.2-cp311-cp311-macosx_10_9_universal2.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 3.2 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: tqdm in /opt/homebrew/lib/python3.11/site-packages (from aif360[all]) (4.65.0)
# Collecting pytest-cov>=2.8.1
#   Downloading pytest_cov-5.0.0-py3-none-any.whl (21 kB)
# Collecting sphinx
#   Downloading sphinx-7.2.6-py3-none-any.whl (3.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 7.2 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: jinja2>3.1.0 in /opt/homebrew/lib/python3.11/site-packages (from aif360[all]) (3.1.2)
# Collecting BlackBoxAuditing
#   Downloading BlackBoxAuditing-0.1.54.tar.gz (2.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 4.6 MB/s eta 0:00:00a 0:00:01m
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pytest>=3.5 in /opt/homebrew/lib/python3.11/site-packages (from aif360[all]) (7.2.2)
# Requirement already satisfied: lightgbm in /opt/homebrew/lib/python3.11/site-packages (from aif360[all]) (4.1.0)
# Requirement already satisfied: seaborn in /opt/homebrew/lib/python3.11/site-packages (from aif360[all]) (0.12.2)
# Collecting ipympl
#   Downloading ipympl-0.9.3-py2.py3-none-any.whl (511 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 511.6/511.6 kB 9.8 MB/s eta 0:00:0000:01
# Collecting lime
#   Downloading lime-0.2.0.1.tar.gz (275 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 275.7/275.7 kB 8.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting sphinx-rtd-theme
#   Downloading sphinx_rtd_theme-2.0.0-py2.py3-none-any.whl (2.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 5.6 MB/s eta 0:00:0000:0100:01m
# Collecting pot
#   Downloading POT-0.9.3-cp311-cp311-macosx_11_0_arm64.whl (290 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.9/290.9 kB 9.4 MB/s eta 0:00:00
# Requirement already satisfied: torch in /opt/homebrew/lib/python3.11/site-packages (from aif360[all]) (2.1.1)
# Requirement already satisfied: six in /opt/homebrew/lib/python3.11/site-packages (from adversarial-robustness-toolbox>=1.0.0->aif360[all]) (1.16.0)
# Requirement already satisfied: setuptools in /opt/homebrew/lib/python3.11/site-packages (from adversarial-robustness-toolbox>=1.0.0->aif360[all]) (67.6.1)
# Collecting osqp>=0.6.2
#   Downloading osqp-0.6.5.tar.gz (228 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 228.4/228.4 kB 10.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting ecos>=2
#   Downloading ecos-2.0.13.tar.gz (142 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.4/142.4 kB 6.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting clarabel>=0.5.0
#   Downloading clarabel-0.7.1-cp37-abi3-macosx_10_12_x86_64.macosx_11_0_arm64.macosx_10_12_universal2.whl (900 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 900.6/900.6 kB 8.3 MB/s eta 0:00:00a 0:00:01
# Collecting scs>=3.0
#   Downloading scs-3.2.4.post1.tar.gz (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 9.1 MB/s eta 0:00:00:00:010:01m
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting pybind11
#   Using cached pybind11-2.12.0-py3-none-any.whl (234 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/homebrew/lib/python3.11/site-packages (from jinja2>3.1.0->aif360[all]) (2.1.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/ldavico/Library/Python/3.11/lib/python/site-packages (from pandas>=0.24.0->aif360[all]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/lib/python3.11/site-packages (from pandas>=0.24.0->aif360[all]) (2022.7.1)
# Requirement already satisfied: attrs>=19.2.0 in /opt/homebrew/lib/python3.11/site-packages (from pytest>=3.5->aif360[all]) (23.1.0)
# Requirement already satisfied: iniconfig in /opt/homebrew/lib/python3.11/site-packages (from pytest>=3.5->aif360[all]) (2.0.0)
# Requirement already satisfied: packaging in /Users/ldavico/Library/Python/3.11/lib/python/site-packages (from pytest>=3.5->aif360[all]) (23.0)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /opt/homebrew/lib/python3.11/site-packages (from pytest>=3.5->aif360[all]) (1.0.0)
# Requirement already satisfied: coverage[toml]>=5.2.1 in /opt/homebrew/lib/python3.11/site-packages (from pytest-cov>=2.8.1->aif360[all]) (7.2.1)
# Requirement already satisfied: joblib>=1.1.1 in /opt/homebrew/lib/python3.11/site-packages (from scikit-learn>=1.0->aif360[all]) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/homebrew/lib/python3.11/site-packages (from scikit-learn>=1.0->aif360[all]) (3.1.0)
# Collecting absl-py>=1.0.0
#   Downloading absl_py-2.1.0-py3-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.7/133.7 kB 8.2 MB/s eta 0:00:00
# Collecting astunparse>=1.6.0
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting flatbuffers>=23.5.26
#   Downloading flatbuffers-24.3.25-py2.py3-none-any.whl (26 kB)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1
#   Downloading gast-0.5.4-py3-none-any.whl (19 kB)
# Requirement already satisfied: google-pasta>=0.1.1 in /opt/homebrew/lib/python3.11/site-packages (from tensorflow>=1.13.1->aif360[all]) (0.2.0)
# Collecting h5py>=3.10.0
#   Downloading h5py-3.10.0-cp311-cp311-macosx_11_0_arm64.whl (2.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 3.5 MB/s eta 0:00:0000:0100:01m
# Collecting libclang>=13.0.0
#   Downloading libclang-18.1.1-py2.py3-none-macosx_11_0_arm64.whl (26.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.4/26.4 MB 5.8 MB/s eta 0:00:0000:0100:01
# Collecting ml-dtypes~=0.3.1
#   Downloading ml_dtypes-0.3.2-cp311-cp311-macosx_10_9_universal2.whl (389 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 389.8/389.8 kB 7.7 MB/s eta 0:00:0000:01
# Collecting opt-einsum>=2.3.2
#   Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 3.5 MB/s eta 0:00:00
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /opt/homebrew/lib/python3.11/site-packages (from tensorflow>=1.13.1->aif360[all]) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/homebrew/lib/python3.11/site-packages (from tensorflow>=1.13.1->aif360[all]) (2.31.0)
# Collecting termcolor>=1.1.0
#   Downloading termcolor-2.4.0-py3-none-any.whl (7.7 kB)
# Requirement already satisfied: typing-extensions>=3.6.6 in /opt/homebrew/lib/python3.11/site-packages (from tensorflow>=1.13.1->aif360[all]) (4.8.0)
# Requirement already satisfied: wrapt>=1.11.0 in /opt/homebrew/lib/python3.11/site-packages (from tensorflow>=1.13.1->aif360[all]) (1.15.0)
# Collecting grpcio<2.0,>=1.24.3
#   Downloading grpcio-1.62.1-cp311-cp311-macosx_10_10_universal2.whl (10.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 5.5 MB/s eta 0:00:0000:010:01
# Collecting tensorboard<2.17,>=2.16
#   Downloading tensorboard-2.16.2-py3-none-any.whl (5.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 9.9 MB/s eta 0:00:00:00:010:01m
# Collecting keras>=3.0.0
#   Downloading keras-3.1.1-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 5.6 MB/s eta 0:00:00a 0:00:01m
# Collecting tensorflow-io-gcs-filesystem>=0.23.1
#   Downloading tensorflow_io_gcs_filesystem-0.36.0-cp311-cp311-macosx_12_0_arm64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 2.9 MB/s eta 0:00:0000:0100:01m
# Requirement already satisfied: filelock in /opt/homebrew/lib/python3.11/site-packages (from torch->aif360[all]) (3.12.4)
# Requirement already satisfied: sympy in /opt/homebrew/lib/python3.11/site-packages (from torch->aif360[all]) (1.12)
# Requirement already satisfied: networkx in /opt/homebrew/lib/python3.11/site-packages (from torch->aif360[all]) (3.1)
# Requirement already satisfied: fsspec in /opt/homebrew/lib/python3.11/site-packages (from torch->aif360[all]) (2023.9.2)
# Collecting texttable>=1.6.2
#   Downloading texttable-1.7.0-py2.py3-none-any.whl (10 kB)
# Collecting cairocffi>=1.2.0
#   Downloading cairocffi-1.6.1-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.1/75.1 kB 6.6 MB/s eta 0:00:00
# Requirement already satisfied: ipython<9 in /Users/ldavico/Library/Python/3.11/lib/python/site-packages (from ipympl->aif360[all]) (8.11.0)
# Requirement already satisfied: ipython-genutils in /opt/homebrew/lib/python3.11/site-packages (from ipympl->aif360[all]) (0.2.0)
# Requirement already satisfied: pillow in /opt/homebrew/lib/python3.11/site-packages (from ipympl->aif360[all]) (9.5.0)
# Requirement already satisfied: traitlets<6 in /Users/ldavico/Library/Python/3.11/lib/python/site-packages (from ipympl->aif360[all]) (5.9.0)
# Requirement already satisfied: ipywidgets<9,>=7.6.0 in /opt/homebrew/lib/python3.11/site-packages (from ipympl->aif360[all]) (8.0.4)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib->aif360[all]) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib->aif360[all]) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib->aif360[all]) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib->aif360[all]) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib->aif360[all]) (3.0.9)
# Requirement already satisfied: notebook in /opt/homebrew/lib/python3.11/site-packages (from jupyter->aif360[all]) (6.5.3)
# Requirement already satisfied: qtconsole in /opt/homebrew/lib/python3.11/site-packages (from jupyter->aif360[all]) (5.4.1)
# Requirement already satisfied: jupyter-console in /opt/homebrew/lib/python3.11/site-packages (from jupyter->aif360[all]) (6.6.3)
# Requirement already satisfied: nbconvert in /opt/homebrew/lib/python3.11/site-packages (from jupyter->aif360[all]) (7.2.10)
# Requirement already satisfied: ipykernel in /Users/ldavico/Library/Python/3.11/lib/python/site-packages (from jupyter->aif360[all]) (6.21.3)
# Requirement already satisfied: scikit-image>=0.12 in /opt/homebrew/lib/python3.11/site-packages (from lime->aif360[all]) (0.22.0)
# Requirement already satisfied: cffi>=1.15.1 in /opt/homebrew/lib/python3.11/site-packages (from rpy2->aif360[all]) (1.15.1)
# Collecting tzlocal
#   Downloading tzlocal-5.2-py3-none-any.whl (17 kB)
# Collecting tabulate>=0.7.7
#   Using cached tabulate-0.9.0-py3-none-any.whl (35 kB)
# Collecting sphinxcontrib-applehelp
#   Downloading sphinxcontrib_applehelp-1.0.8-py3-none-any.whl (120 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.0/120.0 kB 5.5 MB/s eta 0:00:00
# Collecting sphinxcontrib-devhelp
#   Downloading sphinxcontrib_devhelp-1.0.6-py3-none-any.whl (83 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.5/83.5 kB 3.3 MB/s eta 0:00:00
# Collecting sphinxcontrib-jsmath
#   Downloading sphinxcontrib_jsmath-1.0.1-py2.py3-none-any.whl (5.1 kB)
# Collecting sphinxcontrib-htmlhelp>=2.0.0
#   Downloading sphinxcontrib_htmlhelp-2.0.5-py3-none-any.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.2/99.2 kB 2.7 MB/s eta 0:00:00
# Collecting sphinxcontrib-serializinghtml>=1.1.9
#   Downloading sphinxcontrib_serializinghtml-1.1.10-py3-none-any.whl (92 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.7/92.7 kB 4.2 MB/s eta 0:00:00
# Collecting sphinxcontrib-qthelp
#   Downloading sphinxcontrib_qthelp-1.0.7-py3-none-any.whl (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.4/89.4 kB 3.7 MB/s eta 0:00:00
# Requirement already satisfied: Pygments>=2.14 in /opt/homebrew/lib/python3.11/site-packages (from sphinx->aif360[all]) (2.15.1)
# Collecting docutils<0.21,>=0.18.1
#   Using cached docutils-0.20.1-py3-none-any.whl (572 kB)
# Collecting snowballstemmer>=2.0
#   Downloading snowballstemmer-2.2.0-py2.py3-none-any.whl (93 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.0/93.0 kB 3.3 MB/s eta 0:00:00
# Collecting babel>=2.9
#   Downloading Babel-2.14.0-py3-none-any.whl (11.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.0/11.0 MB 10.0 MB/s eta 0:00:0000:010:01
# Collecting alabaster<0.8,>=0.7
#   Downloading alabaster-0.7.16-py3-none-any.whl (13 kB)
# Collecting imagesize>=1.3
#   Downloading imagesize-1.4.1-py2.py3-none-any.whl (8.8 kB)
# Collecting sphinxcontrib-jquery<5,>=4
#   Downloading sphinxcontrib_jquery-4.1-py2.py3-none-any.whl (121 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.1/121.1 kB 6.4 MB/s eta 0:00:00
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/homebrew/lib/python3.11/site-packages (from astunparse>=1.6.0->tensorflow>=1.13.1->aif360[all]) (0.40.0)
# Requirement already satisfied: pycparser in /opt/homebrew/lib/python3.11/site-packages (from cffi>=1.15.1->rpy2->aif360[all]) (2.21)
# Requirement already satisfied: backcall in /Users/ldavico/Library/Python/3.11/lib/python/site-packages (from ipython<9->ipympl->aif360[all]) (0.2.0)
# Requirement already satisfied: decorator in /Users/ldavico/Library/Python/3.11/lib/python/site-packages (from ipython<9->ipympl->aif360[all]) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/ldavico/Library/Python/3.11/lib/python/site-packages (from ipython<9->ipympl->aif360[all]) (0.18.2)
# Requirement already satisfied: matplotlib-inline in /Users/ldavico/Library/Python/3.11/lib/python/site-packages (from ipython<9->ipympl->aif360[all]) (0.1.6)
# Requirement already satisfied: pickleshare in /Users/ldavico/Library/Python/3.11/lib/python/site-packages (from ipython<9->ipympl->aif360[all]) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /Users/ldavico/Library/Python/3.11/lib/python/site-packages (from ipython<9->ipympl->aif360[all]) (3.0.38)
# Requirement already satisfied: stack-data in /Users/ldavico/Library/Python/3.11/lib/python/site-packages (from ipython<9->ipympl->aif360[all]) (0.6.2)
# Requirement already satisfied: pexpect>4.3 in /Users/ldavico/Library/Python/3.11/lib/python/site-packages (from ipython<9->ipympl->aif360[all]) (4.8.0)
# Requirement already satisfied: appnope in /Users/ldavico/Library/Python/3.11/lib/python/site-packages (from ipython<9->ipympl->aif360[all]) (0.1.3)
# Requirement already satisfied: widgetsnbextension~=4.0 in /opt/homebrew/lib/python3.11/site-packages (from ipywidgets<9,>=7.6.0->ipympl->aif360[all]) (4.0.5)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in /opt/homebrew/lib/python3.11/site-packages (from ipywidgets<9,>=7.6.0->ipympl->aif360[all]) (3.0.5)
# Requirement already satisfied: comm>=0.1.1 in /Users/ldavico/Library/Python/3.11/lib/python/site-packages (from ipykernel->jupyter->aif360[all]) (0.1.2)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/ldavico/Library/Python/3.11/lib/python/site-packages (from ipykernel->jupyter->aif360[all]) (1.6.6)
# Requirement already satisfied: jupyter-client>=6.1.12 in /opt/homebrew/lib/python3.11/site-packages (from ipykernel->jupyter->aif360[all]) (8.0.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /opt/homebrew/lib/python3.11/site-packages (from ipykernel->jupyter->aif360[all]) (5.3.0)
# Requirement already satisfied: nest-asyncio in /Users/ldavico/Library/Python/3.11/lib/python/site-packages (from ipykernel->jupyter->aif360[all]) (1.5.6)
# Requirement already satisfied: psutil in /Users/ldavico/Library/Python/3.11/lib/python/site-packages (from ipykernel->jupyter->aif360[all]) (5.9.4)
# Requirement already satisfied: pyzmq>=20 in /Users/ldavico/Library/Python/3.11/lib/python/site-packages (from ipykernel->jupyter->aif360[all]) (25.0.0)
# Requirement already satisfied: tornado>=6.1 in /Users/ldavico/Library/Python/3.11/lib/python/site-packages (from ipykernel->jupyter->aif360[all]) (6.2)
# Collecting rich
#   Downloading rich-13.7.1-py3-none-any.whl (240 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.7/240.7 kB 12.8 MB/s eta 0:00:00
# Collecting namex
#   Downloading namex-0.0.7-py3-none-any.whl (5.8 kB)
# Collecting optree
#   Downloading optree-0.11.0-cp311-cp311-macosx_11_0_arm64.whl (274 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 274.7/274.7 kB 12.3 MB/s eta 0:00:00
# Collecting qdldl
#   Using cached qdldl-0.1.7.post1-cp311-cp311-macosx_13_0_arm64.whl
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/homebrew/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow>=1.13.1->aif360[all]) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow>=1.13.1->aif360[all]) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/homebrew/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow>=1.13.1->aif360[all]) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow>=1.13.1->aif360[all]) (2022.12.7)
# Requirement already satisfied: imageio>=2.27 in /opt/homebrew/lib/python3.11/site-packages (from scikit-image>=0.12->lime->aif360[all]) (2.33.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /opt/homebrew/lib/python3.11/site-packages (from scikit-image>=0.12->lime->aif360[all]) (2023.12.9)
# Requirement already satisfied: lazy_loader>=0.3 in /opt/homebrew/lib/python3.11/site-packages (from scikit-image>=0.12->lime->aif360[all]) (0.3)
# Collecting markdown>=2.6.8
#   Downloading Markdown-3.6-py3-none-any.whl (105 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 kB 4.6 MB/s eta 0:00:00
# Collecting tensorboard-data-server<0.8.0,>=0.7.0
#   Downloading tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/homebrew/lib/python3.11/site-packages (from tensorboard<2.17,>=2.16->tensorflow>=1.13.1->aif360[all]) (2.2.3)
# Requirement already satisfied: beautifulsoup4 in /opt/homebrew/lib/python3.11/site-packages (from nbconvert->jupyter->aif360[all]) (4.11.2)
# Requirement already satisfied: bleach in /opt/homebrew/lib/python3.11/site-packages (from nbconvert->jupyter->aif360[all]) (6.0.0)
# Requirement already satisfied: defusedxml in /opt/homebrew/lib/python3.11/site-packages (from nbconvert->jupyter->aif360[all]) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /opt/homebrew/lib/python3.11/site-packages (from nbconvert->jupyter->aif360[all]) (0.2.2)
# Requirement already satisfied: mistune<3,>=2.0.3 in /opt/homebrew/lib/python3.11/site-packages (from nbconvert->jupyter->aif360[all]) (2.0.5)
# Requirement already satisfied: nbclient>=0.5.0 in /opt/homebrew/lib/python3.11/site-packages (from nbconvert->jupyter->aif360[all]) (0.7.2)
# Requirement already satisfied: nbformat>=5.1 in /opt/homebrew/lib/python3.11/site-packages (from nbconvert->jupyter->aif360[all]) (5.7.3)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/homebrew/lib/python3.11/site-packages (from nbconvert->jupyter->aif360[all]) (1.5.0)
# Requirement already satisfied: tinycss2 in /opt/homebrew/lib/python3.11/site-packages (from nbconvert->jupyter->aif360[all]) (1.2.1)
# Requirement already satisfied: argon2-cffi in /opt/homebrew/lib/python3.11/site-packages (from notebook->jupyter->aif360[all]) (21.3.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /opt/homebrew/lib/python3.11/site-packages (from notebook->jupyter->aif360[all]) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in /opt/homebrew/lib/python3.11/site-packages (from notebook->jupyter->aif360[all]) (0.17.1)
# Requirement already satisfied: prometheus-client in /opt/homebrew/lib/python3.11/site-packages (from notebook->jupyter->aif360[all]) (0.16.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /opt/homebrew/lib/python3.11/site-packages (from notebook->jupyter->aif360[all]) (0.5.3)
# Requirement already satisfied: qtpy>=2.0.1 in /opt/homebrew/lib/python3.11/site-packages (from qtconsole->jupyter->aif360[all]) (2.3.0)
# Requirement already satisfied: mpmath>=0.19 in /opt/homebrew/lib/python3.11/site-packages (from sympy->torch->aif360[all]) (1.3.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/ldavico/Library/Python/3.11/lib/python/site-packages (from jedi>=0.16->ipython<9->ipympl->aif360[all]) (0.8.3)
# Requirement already satisfied: platformdirs>=2.5 in /Users/ldavico/Library/Python/3.11/lib/python/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter->aif360[all]) (3.1.0)
# Requirement already satisfied: jupyter-server>=1.8 in /opt/homebrew/lib/python3.11/site-packages (from nbclassic>=0.4.7->notebook->jupyter->aif360[all]) (2.5.0)
# Requirement already satisfied: notebook-shim>=0.1.0 in /opt/homebrew/lib/python3.11/site-packages (from nbclassic>=0.4.7->notebook->jupyter->aif360[all]) (0.2.2)
# Requirement already satisfied: fastjsonschema in /opt/homebrew/lib/python3.11/site-packages (from nbformat>=5.1->nbconvert->jupyter->aif360[all]) (2.16.3)
# Requirement already satisfied: jsonschema>=2.6 in /opt/homebrew/lib/python3.11/site-packages (from nbformat>=5.1->nbconvert->jupyter->aif360[all]) (4.17.3)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/ldavico/Library/Python/3.11/lib/python/site-packages (from pexpect>4.3->ipython<9->ipympl->aif360[all]) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/ldavico/Library/Python/3.11/lib/python/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython<9->ipympl->aif360[all]) (0.2.6)
# Requirement already satisfied: argon2-cffi-bindings in /opt/homebrew/lib/python3.11/site-packages (from argon2-cffi->notebook->jupyter->aif360[all]) (21.2.0)
# Requirement already satisfied: soupsieve>1.2 in /opt/homebrew/lib/python3.11/site-packages (from beautifulsoup4->nbconvert->jupyter->aif360[all]) (2.4)
# Requirement already satisfied: webencodings in /opt/homebrew/lib/python3.11/site-packages (from bleach->nbconvert->jupyter->aif360[all]) (0.5.1)
# Collecting markdown-it-py>=2.2.0
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Requirement already satisfied: executing>=1.2.0 in /Users/ldavico/Library/Python/3.11/lib/python/site-packages (from stack-data->ipython<9->ipympl->aif360[all]) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/ldavico/Library/Python/3.11/lib/python/site-packages (from stack-data->ipython<9->ipympl->aif360[all]) (2.2.1)
# Requirement already satisfied: pure-eval in /Users/ldavico/Library/Python/3.11/lib/python/site-packages (from stack-data->ipython<9->ipympl->aif360[all]) (0.2.2)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /opt/homebrew/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter->aif360[all]) (0.19.3)
# Requirement already satisfied: anyio>=3.1.0 in /opt/homebrew/lib/python3.11/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter->aif360[all]) (3.6.2)
# Requirement already satisfied: jupyter-events>=0.4.0 in /opt/homebrew/lib/python3.11/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter->aif360[all]) (0.6.3)
# Requirement already satisfied: jupyter-server-terminals in /opt/homebrew/lib/python3.11/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter->aif360[all]) (0.4.4)
# Requirement already satisfied: websocket-client in /opt/homebrew/lib/python3.11/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter->aif360[all]) (1.5.1)
# Collecting mdurl~=0.1
#   Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Requirement already satisfied: sniffio>=1.1 in /opt/homebrew/lib/python3.11/site-packages (from anyio>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter->aif360[all]) (1.3.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /opt/homebrew/lib/python3.11/site-packages (from jupyter-events>=0.4.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter->aif360[all]) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in /opt/homebrew/lib/python3.11/site-packages (from jupyter-events>=0.4.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter->aif360[all]) (6.0)
# Requirement already satisfied: rfc3339-validator in /opt/homebrew/lib/python3.11/site-packages (from jupyter-events>=0.4.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter->aif360[all]) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /opt/homebrew/lib/python3.11/site-packages (from jupyter-events>=0.4.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter->aif360[all]) (0.1.1)
# Requirement already satisfied: fqdn in /opt/homebrew/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter->aif360[all]) (1.5.1)
# Requirement already satisfied: isoduration in /opt/homebrew/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter->aif360[all]) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /opt/homebrew/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter->aif360[all]) (2.3)
# Requirement already satisfied: uri-template in /opt/homebrew/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter->aif360[all]) (1.2.0)
# Requirement already satisfied: webcolors>=1.11 in /opt/homebrew/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter->aif360[all]) (1.12)
# Requirement already satisfied: arrow>=0.15.0 in /opt/homebrew/lib/python3.11/site-packages (from isoduration->jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter->aif360[all]) (1.2.3)
# Building wheels for collected packages: BlackBoxAuditing, lime, ecos, osqp, scs
#   Building wheel for BlackBoxAuditing (setup.py) ... done
#   Created wheel for BlackBoxAuditing: filename=BlackBoxAuditing-0.1.54-py2.py3-none-any.whl size=1394754 sha256=f3694154ae765a00fe6d4300d663fa4fe228c5cd9540f5fdea6b42a9c979bcaa
#   Stored in directory: /Users/ldavico/Library/Caches/pip/wheels/c9/8c/03/073e80e604151fb4cdc68b2e56a97f338d7723e4a4ab5e3823
#   Building wheel for lime (setup.py) ... done
#   Created wheel for lime: filename=lime-0.2.0.1-py3-none-any.whl size=283839 sha256=fdca2acf49fe8eefd2fb650b3857310973b069329a0a4e9045da901485eb8d8d
#   Stored in directory: /Users/ldavico/Library/Caches/pip/wheels/85/fa/a3/9c2d44c9f3cd77cf4e533b58900b2bf4487f2a17e8ec212a3d
#   Building wheel for ecos (pyproject.toml) ... done
#   Created wheel for ecos: filename=ecos-2.0.13-cp311-cp311-macosx_13_0_arm64.whl size=75625 sha256=f402c5c2baaa80ee291305da28bf783181a86cc06cd6d194b3d87019a8c59401
#   Stored in directory: /Users/ldavico/Library/Caches/pip/wheels/03/56/0e/c23948bd98807c0e73876d45a2fa7831e0614a1ba2dabb9b81
#   Building wheel for osqp (pyproject.toml) ... done
#   Created wheel for osqp: filename=osqp-0.6.5-cp311-cp311-macosx_13_0_arm64.whl size=182802 sha256=7136bf418ff8c6b9891e2364ac50e0d24394821923cb24aab2460863e220d017
#   Stored in directory: /Users/ldavico/Library/Caches/pip/wheels/60/bd/12/4b0a9af74a85d70963f9f51013bcc528280b6721817bcd5545
#   Building wheel for scs (pyproject.toml) ... done
#   Created wheel for scs: filename=scs-3.2.4.post1-cp311-cp311-macosx_14_0_arm64.whl size=92804 sha256=fe9f4663f173bca97cd6210e61b6a43091d59e01a4436d5c476e9483f43e4bd7
#   Stored in directory: /Users/ldavico/Library/Caches/pip/wheels/3a/35/90/883ef599bcc9a531e87701195a243e42f9b3225f164e92ce30
# Successfully built BlackBoxAuditing lime ecos osqp scs
# Installing collected packages: texttable, snowballstemmer, namex, libclang, flatbuffers, tzlocal, termcolor, tensorflow-io-gcs-filesystem, tensorboard-data-server, tabulate, sphinxcontrib-serializinghtml, sphinxcontrib-qthelp, sphinxcontrib-jsmath, sphinxcontrib-htmlhelp, sphinxcontrib-devhelp, sphinxcontrib-applehelp, pybind11, optree, opt-einsum, ml-dtypes, mdurl, markdown, imagesize, igraph, h5py, grpcio, gast, docutils, babel, astunparse, alabaster, absl-py, tensorboard, sphinx, scs, rpy2, qdldl, pytest-cov, pot, markdown-it-py, ecos, clarabel, cairocffi, sphinxcontrib-jquery, skorch, rich, osqp, lime, inFairness, BlackBoxAuditing, adversarial-robustness-toolbox, sphinx-rtd-theme, keras, cvxpy, tensorflow, ipympl, jupyter
# Successfully installed BlackBoxAuditing-0.1.54 absl-py-2.1.0 adversarial-robustness-toolbox-1.17.1 alabaster-0.7.16 astunparse-1.6.3 babel-2.14.0 cairocffi-1.6.1 clarabel-0.7.1 cvxpy-1.4.2 docutils-0.20.1 ecos-2.0.13 flatbuffers-24.3.25 gast-0.5.4 grpcio-1.62.1 h5py-3.10.0 igraph-0.11.4 imagesize-1.4.1 inFairness-0.2.3 ipympl-0.9.3 jupyter-1.0.0 keras-3.1.1 libclang-18.1.1 lime-0.2.0.1 markdown-3.6 markdown-it-py-3.0.0 mdurl-0.1.2 ml-dtypes-0.3.2 namex-0.0.7 opt-einsum-3.3.0 optree-0.11.0 osqp-0.6.5 pot-0.9.3 pybind11-2.12.0 pytest-cov-5.0.0 qdldl-0.1.7.post1 rich-13.7.1 rpy2-3.5.16 scs-3.2.4.post1 skorch-0.15.0 snowballstemmer-2.2.0 sphinx-7.2.6 sphinx-rtd-theme-2.0.0 sphinxcontrib-applehelp-1.0.8 sphinxcontrib-devhelp-1.0.6 sphinxcontrib-htmlhelp-2.0.5 sphinxcontrib-jquery-4.1 sphinxcontrib-jsmath-1.0.1 sphinxcontrib-qthelp-1.0.7 sphinxcontrib-serializinghtml-1.1.10 tabulate-0.9.0 tensorboard-2.16.2 tensorboard-data-server-0.7.2 tensorflow-2.16.1 tensorflow-io-gcs-filesystem-0.36.0 termcolor-2.4.0 texttable-1.7.0 tzlocal-5.2
#
# [notice] A new release of pip is available: 23.0.1 -> 24.0
# [notice] To update, run: python3.11 -m pip install --upgrade pip

# %%
#@title Importación de librerías


# elementales

import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

import seaborn as sns

# sklearn

from sklearn.linear_model import LogisticRegressionCV, LogisticRegression
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import accuracy_score, confusion_matrix, plot_roc_curve, recall_score, precision_score, f1_score, roc_auc_score, roc_curve

# aif360

from aif360.sklearn.datasets import fetch_german
from aif360.metrics import BinaryLabelDatasetMetric, ClassificationMetric
from aif360.datasets import BinaryLabelDataset, StandardDataset
# Out:
# Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)

# %% [markdown]
# ## Obtención y manipulación de los datos

# %% [markdown]
# Estaremos utilizando el dataset 'German Credit Data'.

# %%
# Obtenemos los datos.

X, y = fetch_german()
X.head()
# Out:
#                             checking_status  duration  \
# sex    age   foreign_worker
# male   aged  yes                         <0       6.0
# female young yes                   0<=X<200      48.0
# male   aged  yes                no checking      12.0
#              yes                         <0      42.0
#              yes                         <0      24.0
#
#                                              credit_history  \
# sex    age   foreign_worker
# male   aged  yes             critical/other existing credit
# female young yes                              existing paid
# male   aged  yes             critical/other existing credit
#              yes                              existing paid
#              yes                         delayed previously
#
#                                          purpose  credit_amount  \
# sex    age   foreign_worker
# male   aged  yes                        radio/tv         1169.0
# female young yes                        radio/tv         5951.0
# male   aged  yes                       education         2096.0
#              yes             furniture/equipment         7882.0
#              yes                         new car         4870.0
#
#                                savings_status employment  \
# sex    age   foreign_worker
# male   aged  yes             no known savings        >=7
# female young yes                         <100     1<=X<4
# male   aged  yes                         <100     4<=X<7
#              yes                         <100     4<=X<7
#              yes                         <100     1<=X<4
#
#                              installment_commitment other_parties  \
# sex    age   foreign_worker
# male   aged  yes                                4.0          none
# female young yes                                2.0          none
# male   aged  yes                                2.0          none
#              yes                                2.0     guarantor
#              yes                                3.0          none
#
#                              residence_since  ...   age  other_payment_plans  \
# sex    age   foreign_worker                   ...
# male   aged  yes                         4.0  ...  67.0                 none
# female young yes                         2.0  ...  22.0                 none
# male   aged  yes                         3.0  ...  49.0                 none
#              yes                         4.0  ...  45.0                 none
#              yes                         4.0  ...  53.0                 none
#
#                               housing existing_credits                 job  \
# sex    age   foreign_worker
# male   aged  yes                  own              2.0             skilled
# female young yes                  own              1.0             skilled
# male   aged  yes                  own              1.0  unskilled resident
#              yes             for free              1.0             skilled
#              yes             for free              2.0             skilled
#
#                             num_dependents  own_telephone foreign_worker  \
# sex    age   foreign_worker
# male   aged  yes                       1.0            yes            yes
# female young yes                       1.0           none            yes
# male   aged  yes                       2.0           none            yes
#              yes                       2.0           none            yes
#              yes                       2.0           none            yes
#
#                                 sex marital_status
# sex    age   foreign_worker
# male   aged  yes               male         single
# female young yes             female    div/dep/mar
# male   aged  yes               male         single
#              yes               male         single
#              yes               male         single
#
# [5 rows x 21 columns]

# %%
# Los manipularemos para dejarlos en el formato habitual.

df = pd.concat([X,y], axis=1).drop(columns=['sex',  'foreign_worker']).rename(columns={'age': 'age_numeric'}).reset_index()
df.head()
# Out:
#       sex    age foreign_worker checking_status  duration  \
# 0    male   aged            yes              <0       6.0
# 1  female  young            yes        0<=X<200      48.0
# 2    male   aged            yes     no checking      12.0
# 3    male   aged            yes              <0      42.0
# 4    male   aged            yes              <0      24.0
#
#                    credit_history              purpose  credit_amount  \
# 0  critical/other existing credit             radio/tv         1169.0
# 1                   existing paid             radio/tv         5951.0
# 2  critical/other existing credit            education         2096.0
# 3                   existing paid  furniture/equipment         7882.0
# 4              delayed previously              new car         4870.0
#
#      savings_status employment  ...  property_magnitude age_numeric  \
# 0  no known savings        >=7  ...         real estate        67.0
# 1              <100     1<=X<4  ...         real estate        22.0
# 2              <100     4<=X<7  ...         real estate        49.0
# 3              <100     4<=X<7  ...      life insurance        45.0
# 4              <100     1<=X<4  ...   no known property        53.0
#
#    other_payment_plans   housing  existing_credits                 job  \
# 0                 none       own               2.0             skilled
# 1                 none       own               1.0             skilled
# 2                 none       own               1.0  unskilled resident
# 3                 none  for free               1.0             skilled
# 4                 none  for free               2.0             skilled
#
#   num_dependents  own_telephone marital_status  credit-risk
# 0            1.0            yes         single         good
# 1            1.0           none    div/dep/mar          bad
# 2            2.0           none         single         good
# 3            2.0           none         single         good
# 4            2.0           none         single          bad
#
# [5 rows x 23 columns]

# %%
df = df.rename(columns={'age': 'age_cat', 'age_numeric': 'age'})
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 23 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   sex                     1000 non-null   category
#  1   age_cat                 1000 non-null   category
#  2   foreign_worker          1000 non-null   category
#  3   checking_status         1000 non-null   category
#  4   duration                1000 non-null   float64
#  5   credit_history          1000 non-null   category
#  6   purpose                 1000 non-null   category
#  7   credit_amount           1000 non-null   float64
#  8   savings_status          1000 non-null   category
#  9   employment              1000 non-null   category
#  10  installment_commitment  1000 non-null   float64
#  11  other_parties           1000 non-null   category
#  12  residence_since         1000 non-null   float64
#  13  property_magnitude      1000 non-null   category
#  14  age                     1000 non-null   float64
#  15  other_payment_plans     1000 non-null   category
#  16  housing                 1000 non-null   category
#  17  existing_credits        1000 non-null   float64
#  18  job                     1000 non-null   category
#  19  num_dependents          1000 non-null   float64
#  20  own_telephone           1000 non-null   category
#  21  marital_status          1000 non-null   category
#  22  credit-risk             1000 non-null   category
# dtypes: category(16), float64(7)
# memory usage: 71.3 KB

# %% [markdown]
# ### Descripción de las columnas.
#
# **Atributos Numéricos**
#
# - `duration`: Duración en meses. Rango (4,72).
# - `credit_amount`: Cantidad de crédito solicitada. Rango (250, 18424) en DM - Marco alemán.
# - `installment_commitment`: Tasa de cuota en porcentaje del ingreso disponible. Rango (1,4).
# - `residence_since`: Tiempo de residencia actual. Rango (1,4).
# - `age`: Edad en años. Rango (19, 75).
# - `existing_credits`: Número de créditos existentes en este banco. Rango (1,4) en DM - Marco alemán.
# - `num_dependents`: Número de personas responsables de proveer el mantenimiento. Rango (1,2).
#
# **Atributos Categóricos**
#
# - `checking_status`: Valores `'0<=X<200', '<0', '>=200', 'no checking'`.
# - `credit_history`: Historial crediticio del solicitante. Valores `['all paid', 'critical/other existing credit', 'delayed previously', 'existing paid', 'no credits/all paid']`.
# - `purpose`: Motivo por el cual el solicitante solicitó un préstamo. Valores `['business', 'domestic appliance', 'education', 'furniture/equipment', 'new car', 'other', 'radio/tv', 'repairs', 'retraining', 'used car']`.
# - `savings_status`: Cuenta de ahorros/bonos. Valores `['100<=X<500', '500<=X<1000', '<100', '>=1000', 'no known savings']`.
# - `employment`: Empleo actual desde (en años). Valores `['1<=X<4', '4<=X<7', '<1', '>=7', 'unemployed']`.
# - `other_parties`: Otros deudores / garantes. Valores `['co applicant', 'guarantor', 'none']`.
# - `property_magnitude`: Bienes del solicitante. Valores `['car', 'life insurance', 'no known property', 'real estate']`.
# - `other_payment_plans`: Otros planes de pago a plazos. Valores `['bank', 'none', 'stores']`.
# - `housing`: Situación de vivienda del solicitante. Valores `['for free', 'own', 'rent']`.
# - `job`: Categorías de empleo definidas por el banco. Valores `['high qualif/self emp/mgmt', 'skilled', 'unemp/unskilled non res', 'unskilled resident']`.
# - `own_telephone`: Si hay un teléfono registrado a nombre del cliente. Valores `['none', 'yes']`.
# - `foreign_worker`: **Atributo protegido**. Valores `['no', 'yes']`.
# - `sex`: **Atributo protegido**. Valores `['female', 'male']`.
# - `marital_status`: Estado civil. Valores `['div/dep/mar', 'div/sep', 'mar/wid', 'single']`.
#
# **Etiqueta**
#
# - `credit-risk`: `'good'` (favorable) o `'bad'` (desfavorable).

# %% [markdown]
# ## Pre-procesamiento
#
# Haremos el pre-procesamiento de nuestros datos para poder trabajar con los algoritmos.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 23 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   sex                     1000 non-null   category
#  1   age_cat                 1000 non-null   category
#  2   foreign_worker          1000 non-null   category
#  3   checking_status         1000 non-null   category
#  4   duration                1000 non-null   float64
#  5   credit_history          1000 non-null   category
#  6   purpose                 1000 non-null   category
#  7   credit_amount           1000 non-null   float64
#  8   savings_status          1000 non-null   category
#  9   employment              1000 non-null   category
#  10  installment_commitment  1000 non-null   float64
#  11  other_parties           1000 non-null   category
#  12  residence_since         1000 non-null   float64
#  13  property_magnitude      1000 non-null   category
#  14  age                     1000 non-null   float64
#  15  other_payment_plans     1000 non-null   category
#  16  housing                 1000 non-null   category
#  17  existing_credits        1000 non-null   float64
#  18  job                     1000 non-null   category
#  19  num_dependents          1000 non-null   float64
#  20  own_telephone           1000 non-null   category
#  21  marital_status          1000 non-null   category
#  22  credit-risk             1000 non-null   category
# dtypes: category(16), float64(7)
# memory usage: 71.3 KB

# %%
# Binarización de algunas variables.

df['sex'] = df['sex'].map({'male': 1, 'female': 0})
df['age_cat'] = df['age_cat'].map({'aged': 1, 'young': 0})
df['foreign_worker'] = df['foreign_worker'].map({'no': 1, 'yes': 0})
df['credit-risk'] = df['credit-risk'].map({'good': 1, 'bad': 0})

# %%
# Separamos X e Y.

X = df.loc[:, df.columns != 'credit-risk']
y = df.loc[:, df.columns == 'credit-risk']

# %%
df1 = X.copy()

# %%
# Obtenemos variables dummies

ignore = ['sex', 'age_cat', 'foreign_worker']
for catcol in df1.select_dtypes(include='category').columns:
  if catcol in ignore:
    pass
  else:
    dummies = pd.get_dummies(X[catcol])
    X = pd.concat([X, dummies], axis=1).drop(columns=[catcol])

X.head()
# Out:
#   sex age_cat foreign_worker  duration  credit_amount  installment_commitment  \
# 0   1       1              0       6.0         1169.0                     4.0
# 1   0       0              0      48.0         5951.0                     2.0
# 2   1       1              0      12.0         2096.0                     2.0
# 3   1       1              0      42.0         7882.0                     2.0
# 4   1       1              0      24.0         4870.0                     3.0
#
#    residence_since   age  existing_credits  num_dependents  ...  \
# 0              4.0  67.0               2.0             1.0  ...
# 1              2.0  22.0               1.0             1.0  ...
# 2              3.0  49.0               1.0             2.0  ...
# 3              4.0  45.0               1.0             2.0  ...
# 4              4.0  53.0               2.0             2.0  ...
#
#    unemp/unskilled non res  unskilled resident  skilled  \
# 0                        0                   0        1
# 1                        0                   0        1
# 2                        0                   1        0
# 3                        0                   0        1
# 4                        0                   0        1
#
#    high qualif/self emp/mgmt  none  yes  div/dep/mar  div/sep  mar/wid  single
# 0                          0     0    1            0        0        0       1
# 1                          0     1    0            1        0        0       0
# 2                          0     1    0            0        0        0       1
# 3                          0     1    0            0        0        0       1
# 4                          0     1    0            0        0        0       1
#
# [5 rows x 62 columns]

# %%
# Datos de entrenamiento y prueba

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=908)

# %%
# No utilizaremos la edad

X_train.drop(columns=['age'], inplace=True)
X_test.drop(columns=['age'], inplace=True)

# %% [markdown]
# ## ¿Discriminación en nuestros datos?
#
# Una forma de medir la discriminación en nuestros datos es a través de AIF360, que nos facilita el cálculo de métricas. Para ello debemos seguir una serie de pasos para instanciar un BinaryLabelDatasetMetric.
#
# - #### **Statistical Parity Difference**.
#
# Corresponde a la diferencia entre la probabilidad de pertenecer a la clase positiva dado que se pertenece a la clase no privilegiada y  la probabilidad de pertenecer a la clase positiva dado que se pertenece a la clase privilegiada, es decir:
#
# $SP = Pr(Y = 1 | D = \text{unprivileged})- Pr(Y = 1 | D = \text{privileged})$
#
# Valores negativos de esta métrica podrían indicar la presencia de sesgo.
#
# - #### **Disparate Impact**.
#
# Es una métrica para medir fairness que compara la proporción de individuos que reciben un resultado positivo para el grupo privilegiado y el grupo no privilegiado. El cálculo es la proporción del grupo no privilegiado que recibe un resultado positivo dividida por la proporción del grupo privilegiado que recibe un resultado positivo.
#
#
# $DI = \frac{Pr(Y = 1 | D = \text{unprivileged})}{Pr(Y = 1 | D = \text{privileged})}$

# %%
# Necesitamos los datos de entrenamiento en conjunto con la etiqueta.

df_train = X_train.copy()
df_train['credit-score'] = y_train

# %% [markdown]
# ### Discriminación por edad

# %%
# Debemos definir nuestros grupos privilegiados y no privilegiados.

privileged_groups = [{'age_cat': 1}]
unprivileged_groups = [{'age_cat': 0}]

# %%
# Instanciamos BinaryLabelDataset con edad como atributo protegido

attributes_params = dict(protected_attribute_names=['age_cat'], label_names=['credit-score'])
dt_train = BinaryLabelDataset(df=df_train, **attributes_params)

# %%
# Finalmente, la instancia de BinaryLabelDatasetMetric con la edad como atributo protegido.

metric_age_train = BinaryLabelDatasetMetric(dt_train,
                                             unprivileged_groups=unprivileged_groups,
                                             privileged_groups=privileged_groups)

# %% [markdown]
# #### Métricas

# %%
print(f'Train Statistical Parity Difference (age): {metric_age_train.mean_difference()}')
# Out:
# Train Statistical Parity Difference (age): -0.13278706925580863

# %%
from aif360.explainers import MetricTextExplainer

# %%
MetricTextExplainer(metric_age_train).mean_difference()
# Out:
# 'Mean difference (mean label value on unprivileged instances - mean label value on privileged instances): -0.13278706925580863'

# %%
MetricTextExplainer(metric_age_train).disparate_impact()
# Out:
# 'Disparate impact (probability of favorable outcome for unprivileged instances / probability of favorable outcome for privileged instances): 0.8178037886955184'

# %% [markdown]
# **Pregunta**: Las métricas nos indican que existe sesgo con respecto a la edad en nuestros datos de entrenamiento. Supongamos que entrenamos un modelo con estos datos. ¿Que sucederá con estos sesgos dentro del modelo? ¿Serán replicados, ignorados o amplificados?

# %%
# Regresión logística

lr = LogisticRegressionCV(solver='liblinear', cv=10, random_state=908)
lr.fit(X_train, np.ravel(y_train))
# Out:
# LogisticRegressionCV(cv=10, random_state=908, solver='liblinear')

# %%
#@title Métricas modelo base

y_pred_proba = lr.predict_proba(X_test)[:,1]
y_pred = y_pred_proba >= 0.5

print(f"Accuracy: {accuracy_score(y_test, y_pred)}")
print(f"Recall: {recall_score(y_test, y_pred)}")
print(f"F1: {f1_score(y_test, y_pred)}")
# Out:
# Accuracy: 0.735
# Recall: 0.8613138686131386
# F1: 0.8166089965397924

# %% [markdown]
# ### Sesgo del modelo

# %%
# Para facilitar el proceso

def get_aif_metrics(attr, df):

  privileged_groups = [{attr: 1}]
  unprivileged_groups = [{attr: 0}]

  attributes_params = dict(protected_attribute_names=[attr], label_names=['credit-score'])
  dt = BinaryLabelDataset(df=df, **attributes_params)

  metric = BinaryLabelDatasetMetric(dt,
                                    unprivileged_groups=unprivileged_groups,
                                    privileged_groups=privileged_groups)

  return metric, dt

# %% [markdown]
# #### Discriminación por edad

# %%
metric_age_train, train_aifdf = get_aif_metrics('age_cat', df_train)
print(f'Train Statistical Parity Difference (age): {metric_age_train.mean_difference()}')
print(f'Train Disparate Impact (age): {metric_age_train.disparate_impact()}')
# Out:
# Train Statistical Parity Difference (age): -0.13278706925580863
# Train Disparate Impact (age): 0.8178037886955184

# %%
y_train_pred_proba = lr.predict_proba(X_train)[:,1]
y_train_pred = y_train_pred_proba >= 0.5

# %%
df_pred = X_train.copy()
df_pred['credit-score'] = y_train_pred

# %%
metric_age_pred, pred_aifdf = get_aif_metrics('age_cat', df_pred)
print(f'Pred Statistical Parity Difference (age): {metric_age_pred.mean_difference()}')
print(f'Pred Disparate Impact (age): {metric_age_pred.disparate_impact()}')
# Out:
# Pred Statistical Parity Difference (age): -0.18487943754528113
# Pred Disparate Impact (age): 0.7710176431929628

# %%
orig_vs_pred = ClassificationMetric(train_aifdf, pred_aifdf,
                                                    unprivileged_groups=unprivileged_groups,
                                                    privileged_groups=privileged_groups)

# %%
print(f'Error rate difference (unprivileged error rate - privileged error rate)= {orig_vs_pred.error_rate_difference()}\n')

print(f'False negative rate for privileged groups = {orig_vs_pred.false_negative_rate(privileged=True)}')
print(f'False negative rate for unprivileged groups = {orig_vs_pred.false_negative_rate(privileged=False)}')
print(f'False negative rate ratio = {orig_vs_pred.false_negative_rate_ratio()}\n')

print(f'False positive rate for privileged groups = {orig_vs_pred.false_positive_rate(privileged=True)}')
print(f'False positive rate for unprivileged groups = {orig_vs_pred.false_positive_rate(privileged=False)}')
print(f'False positive rate ratio = {orig_vs_pred.false_positive_rate_ratio()}')
# Out:
# Error rate difference (unprivileged error rate - privileged error rate)= 0.10803171460933281
#
# False negative rate for privileged groups = 0.07188160676532769
# False negative rate for unprivileged groups = 0.2222222222222222
# False negative rate ratio = 3.0915032679738563
#
# False positive rate for privileged groups = 0.48295454545454547
# False positive rate for unprivileged groups = 0.39344262295081966
# False positive rate ratio = 0.8146576663452266
